# %% [markdown]
# # Project 4: Web Scraping Indeed.com & Predicting Salaries

# %% [markdown]
# In Project 4, we practice two major skills: collecting data via  web scraping and building a binary predictor with Logistic Regression.
#
# We will collect salary information on data science jobs in a variety of markets. Using location, title, and job summary, we'll predict the salary of the job. For job posting sites, this is extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), extrapolating expected salary can help guide negotiations.
#
# Normally, we can use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Q: Why would we want this to be a classification problem?
# - A: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Section one focuses on scraping Indeed.com; then we use listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# Scrape job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries. First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)
#
# The URL here has many query parameters
#
# - `q` for the job search
# - This is followed by "+20,000" to return results with salaries (or expected salaries >$20,000)
# - `l` for a location
# - `start` for what result number to start on

# %% [markdown]
# Problem Statement: Enter the statement here

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd

# %%
# #read site in soup
# url= "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=Atlanta%2C+GA&start=10&pp="
# r = requests.get(url)
# soup = BeautifulSoup(r.content, "lxml")

# #Append to the full set of results
# results = soup.find_all('div', { "class" :"result" })
# results
# Out:
# [<div class="row result" data-jk="e49013aeeb6925aa" id="pj_e49013aeeb6925aa">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ADQeWqYYwuRDGK7FTA-YzU7Qag1HzehP-FB7aWzkBO6FRyVCTNkBclA9FrQyCAXLjn4u9IP3mepDeJnt-BtuBzfosurWUx8dMI4PS2dnzCGDjcb1rqHXIXHxiVvQw9rfF11WZQLdcQkIzgltmPYW2VZQafuPC2qYCDBhg02A2bHP0A24khtXASaA1S4GiUPCi_qCX8fwmpMBl5iYvUTK2k1IfbboiYxA9Jxxc1naN_r5O6LViJSAqWh2ZoGRQXYWg4MTeEFnYozxgl36GzTC6DTKTxwHlr7NcAoFcNZcERVSplTnIRv2EQ4kdq5AQoMJSXjXWa2KXxOAq49Nk5AiWGvIZzCZ5dHw7Y5WNuB_9IO7yZ2w8L3bg156CWyHETNOuUnEy1uj5eBE4F7sesj2-qFetUxMzP8oqj9QtylvrXQkfLzO1KgyvMqhIYpPyzihJdvOhwBqx2JViwpGxSwsNyrDo7dRDmVzc=&amp;p=1&amp;sk=&amp;fvj=1" id="sja1" onclick="setRefineByCookie(['salest']); sjoc('sja1',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja1'); clk('sja1');" rel="nofollow" target="_blank" title="Data Scientist With Predictive Modeling"><b>Data</b> <b>Scientist</b> With Predictive Modeling</a>\n<br/>\n<div class="sjcl">\n<span class="company">\n    MobileDev Power</span>\n\n - <span class="location">Atlanta, GA 30305</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Build scalable predictive models based on <b>data</b> sets. Collaborate with others in <b>Data</b> Science and Analytics, and other adequately-prepared power users elsewhere...</span>\n</td></tr></table>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">10 days ago</span> <span class="tt_set" id="tt_set_10"></span><div class="edit_note_content" id="editsaved2_e49013aeeb6925aa" style="display:none;"></div><script>window['sj_result_e49013aeeb6925aa'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "10 days ago","jobKey": "e49013aeeb6925aa", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": false, "resultNumber": 10, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="sign-in-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class="row result" data-jk="4dd0428a36b610d7" id="pj_4dd0428a36b610d7">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0Aqmv_5JD5v6gg1ICRL12VY6BolF0XAUkQtat1DEGOKAas7v4hqpX3lzUM4h7L4VGsyuyDvf1POStkSJgHsuP2fB8YliLIijj53wvHBII5P9eQQwhBoT2Vrz0Dv0LOR9cmhA2uclIYN0yEp1L5TQNrdI9OqFCffoKUtdZ6lBdO6sPz1755OdlQAcUqQ5fvbMlJEYLrobXnayFHUwcReTar-m3Qr4nAC-9xISBz6PQ3t4lJVphPha4VjaJlyHAvICTO7Rg9axmEjLKb3yrEp14tayZteC6UVdsOESFIu_WctGAvJzY7vmcBY-pf9r5VAFIrHO_Wb7MX634YX0Y-6lOTBvqBydmQFQtJErmSKInV6vFS4YSC0uZpERmyFHscWfAtW7pB_qDjnQNeQiGr7OqsFcW6-kFcezbQduNondGLdNjhI1WEoXnkE26K48AQQiOTYLmrC_zWLNGgnaj3wUDO3EwGD4u_mGeYBD-o8PS3HJQ==&amp;p=2&amp;sk=&amp;fvj=0" id="sja2" onclick="setRefineByCookie(['salest']); sjoc('sja2',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja2'); clk('sja2');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n<br/>\n<div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Cox-Automotive" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4dd0428a36b610d7&amp;jcid=7e465a3d521b3ac3')" target="_blank">\n        Cox Automotive</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Cox-Automotive/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=4dd0428a36b610d7&amp;jcid=7e465a3d521b3ac3');" target="_blank" title="Cox Automotive reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;"><!-- --></span></span><span class="slNoUnderline">46 reviews</span></a>\n - <span class="location">Atlanta, GA</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Description Cox Automotive is hiring a <b>Data</b> <b>Scientist</b>. The <b>Data</b> <b>Scientist</b> will design and drive the creation of new standards and best practices in the use of...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">30+ days ago</span> <span class="tt_set" id="tt_set_11"></span><div class="edit_note_content" id="editsaved2_4dd0428a36b610d7" style="display:none;"></div><script>window['sj_result_4dd0428a36b610d7'] = {"showSource": false, "source": "Cox Automotive", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "4dd0428a36b610d7", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": false, "resultNumber": 11, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="sign-in-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class="row sjlast result" data-jk="f434056997dc96cb" id="pj_f434056997dc96cb">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BOtxtSuljPipcOqTsdGhy_ryU9_Bpcutm1h1zAeyLmGkIaP41iJ3MJozu0rGTiCSxrMrrqZoHYuxTeUr4fWU43RLmYgxlzm6tonZgKvd86BbFE4q6gd0aVI7Et9BPuXulPSAiMoWVzgoWkhj0HH_MFPFyMBNdoKBlRUX0z_9hfBSgdXfP7M0i_787ykgHlZoH0z244x6bWRCBQHNZqqu3_FbfyGw6lDsB4VKGV1bydQSoiOycXAvyMcbbhIP5HTnw14GZzxCMcw56mZbCtg7rwQ4TQNgSqXCnUUMhVJeed73QHuzGt0v-rfkqiCW4-7EZpZsWOWRT7LkY07fHd7MCSPTKyM8xEOYOW0YBE_bFgWmFo5tmpM9lF2nSmFr9U_sTfQqxy3mx73qUZ8Y3XwPcDAnEwf-KSMqEj87obHt_jcyOhrlu86NlkDVfrSbE22a4ObxwugRJoIwFS3tFU324fdh5a2kEBMao3mhdX3CIfznxoPbi086kW6m8jn5X1NVtKgp-Z7f5XAd8E3MQ8YYWkLWT-Sm-BOVSz728AZL3CIbIJ0icbwHAt0wq92-JozN3pGCUEnv9GIHgAR18IgMp4sKHxF9A7qSbbV9h3FtrNFyLEFYUn6MPXkTL_o1d0cH0uWRCWMBm14sUFIKRg22qc2q1mpdoKWtqF4M_1hpvoFeBUcaZfy65q5D26IiyhTfTt0d5sPhx-isnRysA4Clkxpy0mlDUlC-Qz8leTgNrBGocJVqsaj3NBiGl8p26xP7CCEHXnZ9mnmnEEHdhP9N8_OxZF9GCS_3UTDFQvl8VX6HWzg5YFct4e&amp;p=3&amp;sk=&amp;fvj=0" id="sja3" onclick="setRefineByCookie(['salest']); sjoc('sja3',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja3'); clk('sja3');" rel="nofollow" target="_blank" title="DATA SCIENTIST"><b>DATA</b> <b>SCIENTIST</b></a>\n<br/>\n<div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/The-Home-Depot" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=f434056997dc96cb&amp;jcid=16ef23d67d728b35')" target="_blank">\n        Home Depot</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/The-Home-Depot/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=DATA+SCIENTIST&amp;fromjk=f434056997dc96cb&amp;jcid=16ef23d67d728b35');" target="_blank" title="Home Depot reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span><span class="slNoUnderline">21,095 reviews</span></a>\n - <span class="location">Atlanta, GA 30354</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Strong communication and <b>data</b> presentation skills. Insights from <b>data</b> to solve business problems. The <b>Data</b> <b>Scientist</b> will develop the analytical infrastructure...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">1 day ago</span> <span class="tt_set" id="tt_set_12"></span><div class="edit_note_content" id="editsaved2_f434056997dc96cb" style="display:none;"></div><script>window['sj_result_f434056997dc96cb'] = {"showSource": false, "source": "The Home Depot", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "1 day ago","jobKey": "f434056997dc96cb", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": false, "resultNumber": 12, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"sponsorName" : "The Home Depot","reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="sign-in-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored by <b>The Home Depot</b></span>\n</div>,
#  <div class=" row result" data-jk="4a4948fe135cb354" data-tn-component="organicJob" id="p_4a4948fe135cb354" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_4a4948fe135cb354">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=4a4948fe135cb354&amp;fccid=cc35f9c14f8799a9" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[0],true,0);" onmousedown="return rclk(this,jobmap[0],0);" rel="nofollow" target="_blank" title="Scientific Data Analyst">Scientific <b>Data</b> Analyst</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Icf" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4a4948fe135cb354&amp;jcid=cc35f9c14f8799a9')" target="_blank">\n        ICF</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Icf/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Scientific+Data+Analyst&amp;fromjk=4a4948fe135cb354&amp;jcid=cc35f9c14f8799a9');" target="_blank" title="Icf reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 41.4px;"><!-- --></span></span><span class="slNoUnderline">236 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nEvaluate <b>data</b> errors and work to resolve <b>data</b> problems.*. Coordinate <b>data</b> uploads.*. Check <b>data</b> files for completeness;...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">ICF International, Inc </span>- <span class="date">7 days ago</span> <span class="tt_set" id="tt_set_0"> - <span class="savelink2" id="savelink2_4a4948fe135cb354"><a class="sl resultLink save-job-link" href="#" id="sj_4a4948fe135cb354" onclick="changeJobState('4a4948fe135cb354', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('4a4948fe135cb354'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_4a4948fe135cb354" style="display:none;"></div><script>window['result_4a4948fe135cb354'] = {"showSource": true, "source": "ICF International, Inc", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "7 days ago","jobKey": "4a4948fe135cb354", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('4a4948fe135cb354'); return false;" title="Close"></a><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/q-Icf-l-Atlan ...
#  <div class=" row result" data-jk="01ad090d112dbb83" data-tn-component="organicJob" id="p_01ad090d112dbb83" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_01ad090d112dbb83">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/company/Ashton212/jobs/Quantitative-Analyst-01ad090d112dbb83?r=1&amp;fccid=f0461620810fcde2" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Quantitative Analyst | #769">Quantitative Analyst | #769</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Ashton212</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nThe Important Stuff A leader in the payments industry our Financial Services client is seeking an experienced Quantitative Analyst to support adherence to</span>\n</div>\n<div class="iaP">\n<span class="iaLabel"> Easily apply</span>\n</div><div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">3 days ago</span> <span class="tt_set" id="tt_set_1"> - <span class="savelink2" id="savelink2_01ad090d112dbb83"><a class="sl resultLink save-job-link" href="#" id="sj_01ad090d112dbb83" onclick="changeJobState('01ad090d112dbb83', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('01ad090d112dbb83'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_01ad090d112dbb83" style="display:none;"></div><script>window['result_01ad090d112dbb83'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "3 days ago","jobKey": "01ad090d112dbb83", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('01ad090d112dbb83'); return false;" title="Close"></a><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/q-Ashton212-l-Atlanta,-GA-jobs.html" rel="nofollow">Ashton212 jobs in Atlanta, GA</a> - <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Quantitative+Analyst&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Quantitative Analyst salaries in Atlanta, GA</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Ashton212" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=01ad090d112dbb83&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=657572328deb01c1');">Ashton212</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a> - <a href="/forum/cmp/Ashton212.html">Ashton212</a> - <a href="/forum/job/Quantitative-Analyst.html">Quantitative Analyst</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tel ...
#  <div class=" row result" data-jk="27b511fcc7265dd7" data-tn-component="organicJob" id="p_27b511fcc7265dd7" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_27b511fcc7265dd7">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=27b511fcc7265dd7&amp;fccid=50208b5bf45ee3b8" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="Analytics DevOps Engineer">Analytics DevOps Engineer</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Honeywell" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=27b511fcc7265dd7&amp;jcid=50208b5bf45ee3b8')" target="_blank">\n        Honeywell</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Honeywell/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Analytics+DevOps+Engineer&amp;fromjk=27b511fcc7265dd7&amp;jcid=50208b5bf45ee3b8');" target="_blank" title="Honeywell reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span><span class="slNoUnderline">3,560 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAdvanced analytics/modelling projects, including <b>data</b> ingestion, <b>data</b> management (scripts, modelling), <b>data</b> extraction, and execution of predictive models....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">30+ days ago</span> <span class="tt_set" id="tt_set_2"> - <span class="savelink2" id="savelink2_27b511fcc7265dd7"><a class="sl resultLink save-job-link" href="#" id="sj_27b511fcc7265dd7" onclick="changeJobState('27b511fcc7265dd7', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('27b511fcc7265dd7'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_27b511fcc7265dd7" style="display:none;"></div><script>window['result_27b511fcc7265dd7'] = {"showSource": false, "source": "Honeywell", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "27b511fcc7265dd7", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('27b511fcc7265dd7'); return false;" title="Close"></a><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/q-Honeywell-l-Atlanta,-GA-jobs.h ...
#  <div class=" row result" data-jk="39bb41a507f991bd" data-tn-component="organicJob" id="p_39bb41a507f991bd" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_39bb41a507f991bd">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=39bb41a507f991bd&amp;fccid=298641a812c7e85f" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="IT Project Manager \u2013 Sourcing BI">IT Project Manager \u2013 Sourcing BI</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/GE-Power-&amp;-Water" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=39bb41a507f991bd&amp;jcid=36cd83a149f09757')" target="_blank">\n        GE Power</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/GE-Power-&amp;-Water/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=IT+Project+Manager+%5Cu2013+Sourcing+BI&amp;fromjk=39bb41a507f991bd&amp;jcid=36cd83a149f09757');" target="_blank" title="GE Power reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.6px;"><!-- --></span></span><span class="slNoUnderline">161 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nAbility to create and understand <b>data</b> models. 5 years of more progressive responsibility and experience as an engineer or <b>scientist</b>....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">GE Careers </span>- <span class="date">23 days ago</span> <span class="tt_set" id="tt_set_3"> - <span class="savelink2" id="savelink2_39bb41a507f991bd"><a class="sl resultLink save-job-link" href="#" id="sj_39bb41a507f991bd" onclick="changeJobState('39bb41a507f991bd', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('39bb41a507f991bd'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_39bb41a507f991bd" style="display:none;"></div><script>window['result_39bb41a507f991bd'] = {"showSource": true, "source": "GE Careers", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "23 days ago","jobKey": "39bb41a507f991bd", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_3" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('39bb41a507f991bd'); return false;" title="Close"></a><div class="more_actions" id="more_3"> ...
#  <div class=" row result" data-jk="09cf98bd4dad5e2d" data-tn-component="organicJob" id="p_09cf98bd4dad5e2d" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_09cf98bd4dad5e2d">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=09cf98bd4dad5e2d&amp;fccid=11619ce0d3c2c733" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="HAI Prevention Data Analyst">HAI Prevention <b>Data</b> Analyst</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Northrop-Grumman" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=09cf98bd4dad5e2d&amp;jcid=11619ce0d3c2c733')" target="_blank">\n        Northrop Grumman</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Northrop-Grumman/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=HAI+Prevention+Data+Analyst&amp;fromjk=09cf98bd4dad5e2d&amp;jcid=11619ce0d3c2c733');" target="_blank" title="Northrop Grumman reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.0px;"><!-- --></span></span><span class="slNoUnderline">2,161 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nPerform <b>data</b> entry, cleaning, and analysis (both qualitative and quantitative) from multiple <b>data</b> sources including but not limited to surveys, focus groups...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">30 days ago</span> <span class="tt_set" id="tt_set_4"> - <span class="savelink2" id="savelink2_09cf98bd4dad5e2d"><a class="sl resultLink save-job-link" href="#" id="sj_09cf98bd4dad5e2d" onclick="changeJobState('09cf98bd4dad5e2d', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('09cf98bd4dad5e2d'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_09cf98bd4dad5e2d" style="display:none;"></div><script>window['result_09cf98bd4dad5e2d'] = {"showSource": false, "source": "Northrop Grumman", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30 days ago","jobKey": "09cf98bd4dad5e2d", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_4" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('09cf98bd4dad5e2d'); return false;" title="Close"></a><div class="more_actions" id="more_4"><ul><li><span class="mat">View all <a ...
#  <div class=" row result" data-jk="fd7f3b86c36b9de6" data-tn-component="organicJob" id="p_fd7f3b86c36b9de6" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_fd7f3b86c36b9de6">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=fd7f3b86c36b9de6&amp;fccid=aeb15e43a6800b9d" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Research Scientist Senior">Research <b>Scientist</b> Senior</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Lockheed-Martin" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=fd7f3b86c36b9de6&amp;jcid=aeb15e43a6800b9d')" target="_blank">\n        Lockheed Martin</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Lockheed-Martin/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Research+Scientist+Senior&amp;fromjk=fd7f3b86c36b9de6&amp;jcid=aeb15e43a6800b9d');" target="_blank" title="Lockheed Martin reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.6px;"><!-- --></span></span><span class="slNoUnderline">3,475 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Marietta, GA 30063</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nExperience with full-scale pole model design, fabrication, testing, and <b>data</b> reduction. The candidate will support and lead efforts in Radio Frequency (RF) Low...</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">Lockheed Martin Corporation </span>- <span class="date">3 days ago</span> <span class="tt_set" id="tt_set_5"> - <span class="savelink2" id="savelink2_fd7f3b86c36b9de6"><a class="sl resultLink save-job-link" href="#" id="sj_fd7f3b86c36b9de6" onclick="changeJobState('fd7f3b86c36b9de6', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('fd7f3b86c36b9de6'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_fd7f3b86c36b9de6" style="display:none;"></div><script>window['result_fd7f3b86c36b9de6'] = {"showSource": true, "source": "Lockheed Martin Corporation", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "3 days ago","jobKey": "fd7f3b86c36b9de6", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_5" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('fd7f3b86c36b9de6'); return false;" title="Close"></a><div ...
#  <div class=" row result" data-jk="bae6f0b480955c0b" data-tn-component="organicJob" id="p_bae6f0b480955c0b" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_bae6f0b480955c0b">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=bae6f0b480955c0b&amp;fccid=d461ef0ed1c43411" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Analyst"><b>Data</b> Analyst</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Eagle Medical Services, LLC</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nComfortable in collaborating with <b>data</b> <b>scientists</b>, epidemiologists, and professionals across the board. Assist with visualization of <b>data</b>....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="result-link-source">Bristol Bay Native Corporation </span>- <span class="date">23 days ago</span> <span class="tt_set" id="tt_set_6"> - <span class="savelink2" id="savelink2_bae6f0b480955c0b"><a class="sl resultLink save-job-link" href="#" id="sj_bae6f0b480955c0b" onclick="changeJobState('bae6f0b480955c0b', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('bae6f0b480955c0b'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_bae6f0b480955c0b" style="display:none;"></div><script>window['result_bae6f0b480955c0b'] = {"showSource": true, "source": "Bristol Bay Native Corporation", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "23 days ago","jobKey": "bae6f0b480955c0b", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_6" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('bae6f0b480955c0b'); return false;" title="Close"></a><div class="more_actions" id="more_6"><ul><li><span class="mat">View all <a href="/jobs?q=Eagle+Medical+Services,+LLC&amp;l=Atlanta,+GA&amp;nc=jasx" rel="nofollow">Eagle Medical Services, LLC jobs in Atlanta, GA</a> - <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Data+Analyst&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Analyst salaries in Atlanta, GA</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Eagle-Medical-Services,-LLC" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=bae6f0b480955c0b&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=5aafa162d9c50f16');">Eagle Medical Services, LLC</a></span></li><li><span class="mat">Writer/Editor Contractor review: "Unorganized managment. Very nice company however management is very unorganized."</span></li><li><span class="mat">Related forums: <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a> - <a  ...
#  <div class=" row result" data-jk="910b5fa85c1f4be3" data-tn-component="organicJob" id="p_910b5fa85c1f4be3" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_910b5fa85c1f4be3">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=910b5fa85c1f4be3&amp;fccid=e42550d4f0f282e6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Principal Data Engineer">Principal <b>Data</b> Engineer</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n    Cardlytics Corporation</span>\n</span>\n\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\n50 concurrent <b>data</b> <b>scientists</b> and analysts. Build high performing and scalable <b>data</b> systems to support multiple internal and 3 rd party <b>data</b> pipelines and appx....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">14 days ago</span> <span class="tt_set" id="tt_set_7"> - <span class="savelink2" id="savelink2_910b5fa85c1f4be3"><a class="sl resultLink save-job-link" href="#" id="sj_910b5fa85c1f4be3" onclick="changeJobState('910b5fa85c1f4be3', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('910b5fa85c1f4be3'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_910b5fa85c1f4be3" style="display:none;"></div><script>window['result_910b5fa85c1f4be3'] = {"showSource": false, "source": "Cardlytics Corporation", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 days ago","jobKey": "910b5fa85c1f4be3", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_7" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('910b5fa85c1f4be3'); return false;" title="Close"></a><div class="more_actions" id="more_7"><ul><li><span class="mat">View all <a href="/jobs?q=Cardlytics+Corporation&amp;l=Atlanta,+GA&amp;nc=jasx" rel="nofollow">Cardlytics Corporation jobs in Atlanta, GA</a> - <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salary?q1=Principal+Data+Engineer&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Principal Data Engineer salaries in Atlanta, GA</a></span></li><li><span class="mat">Related forums: <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a> - <a href="/forum/cmp/Cardlytics-Corporation.html">Cardlytics Corporation</a></span></li></ul></div></div><div class="dya-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n<div class="sign-in-container result-tab"></div>\n<div class="notes-container result-tab"></div>\n</div>\n</td>\n</tr>\n</table>\n</div>,
#  <div class=" row result" data-jk="c0294654500f010f" data-tn-component="organicJob" id="p_c0294654500f010f" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_c0294654500f010f">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=c0294654500f010f&amp;fccid=92b6ad9b1bd886b6" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Manager, Consumer Insights &amp; Statistical Analysis">Manager, Consumer Insights &amp; Statistical Analysis</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Turner" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=c0294654500f010f&amp;jcid=92b6ad9b1bd886b6')" target="_blank">\n        Turner</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Turner/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Manager%2C+Consumer+Insights+%26+Statistical+Analysis&amp;fromjk=c0294654500f010f&amp;jcid=92b6ad9b1bd886b6');" target="_blank" title="Turner reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.0px;"><!-- --></span></span><span class="slNoUnderline">254 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA 30319</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nHas experience with SQL, R, SPSS, Tableau, Power BI and/or other software for statistical computing and <b>data</b> visualization....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">14 hours ago</span> <span class="tt_set" id="tt_set_8"> - <span class="savelink2" id="savelink2_c0294654500f010f"><a class="sl resultLink save-job-link" href="#" id="sj_c0294654500f010f" onclick="changeJobState('c0294654500f010f', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('c0294654500f010f'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_c0294654500f010f" style="display:none;"></div><script>window['result_c0294654500f010f'] = {"showSource": false, "source": "Turner", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 hours ago","jobKey": "c0294654500f010f", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_8" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('c0294654500f010f'); return false;" title="Close"></a><div class="more_actions" id="more_8"><ul><li><span class="mat">View all <a href="/q-Tur ...
#  <div class="lastRow row result" data-jk="932a2cbc29121ff8" data-tn-component="organicJob" id="p_932a2cbc29121ff8" itemscope="" itemtype="http://schema.org/JobPosting">\n<h2 class="jobtitle" id="jl_932a2cbc29121ff8">\n<a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=932a2cbc29121ff8&amp;fccid=50208b5bf45ee3b8" itemprop="title" onclick="setRefineByCookie(['salest']); return rclk(this,jobmap[9],true,0);" onmousedown="return rclk(this,jobmap[9],0);" rel="nofollow" target="_blank" title="Big Data Architect">Big <b>Data</b> Architect</a>\n</h2>\n<span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">\n<span itemprop="name">\n<a href="/cmp/Honeywell" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=932a2cbc29121ff8&amp;jcid=50208b5bf45ee3b8')" target="_blank">\n        Honeywell</a></span>\n</span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Honeywell/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Big+Data+Architect&amp;fromjk=932a2cbc29121ff8&amp;jcid=50208b5bf45ee3b8');" target="_blank" title="Honeywell reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span><span class="slNoUnderline">3,560 reviews</span></a>\n - <span itemprop="jobLocation" itemscope="" itemtype="http://schema.org/Place"><span class="location" itemprop="address" itemscope="" itemtype="http://schema.org/Postaladdress"><span itemprop="addressLocality">Atlanta, GA</span></span></span>\n<table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td class="snip">\n<div>\n<span class="summary" itemprop="description">\nWork closely with <b>data</b> <b>scientists</b> and product managers to understand their <b>data</b> requirements for existing and future projects on <b>data</b> analytics applications....</span>\n</div>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">3 days ago</span> <span class="tt_set" id="tt_set_9"> - <span class="savelink2" id="savelink2_932a2cbc29121ff8"><a class="sl resultLink save-job-link" href="#" id="sj_932a2cbc29121ff8" onclick="changeJobState('932a2cbc29121ff8', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a></span> - <a class="sl resultLink more-link " href="#" id="tog_9" onclick="toggleMoreLinks('932a2cbc29121ff8'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_932a2cbc29121ff8" style="display:none;"></div><script>window['result_932a2cbc29121ff8'] = {"showSource": false, "source": "Honeywell", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "3 days ago","jobKey": "932a2cbc29121ff8", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": true, "resultNumber": 9, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="more-links-container result-tab" id="tt_display_9" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('932a2cbc29121ff8'); return false;" title="Close"></a><div class="more_actions" id="more_9"><ul><li><span class="mat">View all <a href="/q-Honeywell-l-Atlanta,-GA-jobs.htm ...
#  <div class="row result" data-jk="78f1a9a1e62191ef" id="pj_78f1a9a1e62191ef">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BT1oD7gxL4d4q7k2XK_xqJz55UkLlcqeX4XFuXt5iz9snYfsSUT3YCjhoIHnNQ-5Dn3WpSwV_to5gRmnY1dWxevmGFzqLqqlIFz_9Edyh1_IXncaR6MCLo7f5ouI8dmb8itt_eVEZ5tkkDyAWm8yF_zqzynYwkLGutmvph_syXoUY92h2h3JM52XJVGZTSvezCOruNTDCy2Q1aa-_ioOAkU-CUgYr9iqBETL1U52MdIGNTenZkiXeWSKojm35S9fFqfhnJMhIqfwGDypL6gnLP1AbbDNvrwmvD162R8-L5EPBqOx4nvcI6zwe84MkCvoqoee2TRrHreajhaNQVMiQ7qWgB3cOmzyt9oGm-3rvzLJinds2GMLd4RyCJ9ZAkAr3Yj9wp2RYkBTaJmCyquTv0oEuqCPerDtaamOcmHkPH54_Tcqr5j-4SqC4QjrvyZl7SP1xLhoqpmvJ-9t5iI824WWBtW0-dq9FPRd6iY5HfsspoiPy4HfNXC4lCUoSIyvOZuWGM_KCo206c8tAwLPr8&amp;p=4&amp;sk=&amp;fvj=0" id="sja4" onclick="setRefineByCookie(['salest']); sjoc('sja4',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja4'); clk('sja4');" rel="nofollow" target="_blank" title="Principal Data Scientist - Atlanta, GA">Principal <b>Data</b> <b>Scientist</b> - Atlanta, GA</a>\n<br/>\n<div class="sjcl">\n<span class="company">\n<a class="turnstileLink" data-tn-element="companyName" href="/cmp/Honeywell" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=78f1a9a1e62191ef&amp;jcid=50208b5bf45ee3b8')" target="_blank">\n        Honeywell</a></span>\n\n - <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Honeywell/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Principal+Data+Scientist+-+Atlanta%2C+GA&amp;fromjk=78f1a9a1e62191ef&amp;jcid=50208b5bf45ee3b8');" target="_blank" title="Honeywell reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span><span class="slNoUnderline">3,560 reviews</span></a>\n - <span class="location">Atlanta, GA</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">Support and mentor <b>data</b> <b>scientists</b>. Experience with <b>data</b> architectures, <b>data</b> warehousing, and <b>data</b> modeling. As a Principal <b>Data</b> <b>Scientist</b> in the Aero Services...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">30+ days ago</span> <span class="tt_set" id="tt_set_13"></span><div class="edit_note_content" id="editsaved2_78f1a9a1e62191ef" style="display:none;"></div><script>window['sj_result_78f1a9a1e62191ef'] = {"showSource": false, "source": "Honeywell", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "78f1a9a1e62191ef", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": false, "resultNumber": 13, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="sign-in-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>,
#  <div class="row sjlast result" data-jk="989c3af317d739f1" id="pj_989c3af317d739f1">\n<a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0Bcgobz-t7weSGYTjoRWMIqcV9t0akB45B3k8NFJVZb5kkFpxn8bhfjltbVDjvx0bn0noTLqpSBW77839Ubfh4eL2ZvByfFlPegJkfgxbap4qbKzQXknClXAKQmaD18uRE6WyuXyxO_e1mveWMTPzA6Ti1H8XIR9VoIlCN5VAQSiXIzNVaM8508EInx-CHChQJfaGy_cH2EboJPJWPPMH-4SkubdfUBaB00wZssiEYbEMZXg01qe6a57qG_ENAQNr1RF5KhRCjbHYV0t-M3F83SED1daXflmsiCktiVHIUdG00ket_E8FGL3KSjxxiV3YSoKqAlcGC4maiXtD8ElD_Vpcj-EcYcMx5zEJoeahRVrR7imONymktNzg8z_IsfUEH63oeN1t5vHll-7pjug1zUZtOk3z5izQNWIG5SJdDeeezwUtPXVPho&amp;p=5&amp;sk=&amp;fvj=0" id="sja5" onclick="setRefineByCookie(['salest']); sjoc('sja5',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja5'); clk('sja5');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>\n<br/>\n<div class="sjcl">\n<span class="company">\n    Predictive Science</span>\n\n - <span class="location">United States</span>\n</div>\n<table border="0" cellpadding="0" cellspacing="0"><tr><td class="snip">\n<span class="summary">This is a freelance <b>data</b> <b>scientist</b> position who will work with other senior <b>data</b> <b>scientists</b> to consult with executives and <b>data</b> <b>scientists</b> who are a part of the...</span>\n</td></tr></table>\n<div class="result-link-bar-container">\n<div class="result-link-bar"><span class="date">9 days ago</span> <span class="tt_set" id="tt_set_14"></span><div class="edit_note_content" id="editsaved2_989c3af317d739f1" style="display:none;"></div><script>window['sj_result_989c3af317d739f1'] = {"showSource": false, "source": "Predictive Science", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "9 days ago","jobKey": "989c3af317d739f1", "myIndeedAvailable": true, "tellAFriendEnabled": false, "showMoreActionsLink": false, "resultNumber": 14, "jobStateChangedToSaved": false, "searchState": "q=data scientist $20,000&amp;l=Atlanta%2C+GA&amp;start=10", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"reportJobButtonEnabled": false, "showMyJobsHired": false, "showSaveForSponsored": false};</script></div></div>\n<div class="tab-container">\n<div class="sign-in-container result-tab"></div>\n<div class="tellafriend-container result-tab email_job_content"></div>\n</div>\n<span class="sdn">Sponsored</span>\n</div>]

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some of the more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %%
# results = soup.find_all('div', { "class" : "result" })
# df = pd.DataFrame()
# for element in range(len(results)):
#     title=results[element].find("a",{'data-tn-element' : 'jobTitle'}).get_text().strip()
#     company=results[element].find("span",{"class":"company"}).get_text().strip()
#     location=results[element].find("span",{"class":"location"}).get_text().strip()
#     salary=results[element].find("td",{"class":"snip"}).get_text().strip()
#     df=df.append({"Title":title, "Company":company, "Location": location,"Salary": salary},ignore_index=True)
    
# df
# Out:
#                         Company            Location  \
# 0               MobileDev Power   Atlanta, GA 30305
# 1                Cox Automotive         Atlanta, GA
# 2                    Home Depot   Atlanta, GA 30354
# 3                           ICF         Atlanta, GA
# 4                     Ashton212         Atlanta, GA
# 5                     Honeywell         Atlanta, GA
# 6                      GE Power         Atlanta, GA
# 7              Northrop Grumman         Atlanta, GA
# 8               Lockheed Martin  Marietta, GA 30063
# 9   Eagle Medical Services, LLC         Atlanta, GA
# 10       Cardlytics Corporation         Atlanta, GA
# 11                       Turner   Atlanta, GA 30319
# 12                    Honeywell         Atlanta, GA
# 13                    Honeywell         Atlanta, GA
# 14           Predictive Science       United States
#
#                                                Salary  \
# 0   Build scalable predictive models based on data...
# 1   Description Cox Automotive is hiring a Data Sc...
# 2   Strong communication and data presentation ski...
# 3   Evaluate data errors and work to resolve data ...
# 4   The Important Stuff A leader in the payments i...
# 5   Advanced analytics/modelling projects, includi...
# 6   Ability to create and understand data models. ...
# 7   Perform data entry, cleaning, and analysis (bo...
# 8   Experience with full-scale pole model design, ...
# 9   Comfortable in collaborating with data scienti...
# 10  50 concurrent data scientists and analysts. Bu...
# 11  Has experience with SQL, R, SPSS, Tableau, Pow...
# 12  Work closely with data scientists and product ...
# 13  Support and mentor data scientists. Experience...
# 14  This is a freelance data scientist position wh...
#
#                                                 Title
# 0             Data Scientist With Predictive Modeling
# 1                                      Data Scientist
# 2                                      DATA SCIENTIST
# 3                             Scientific Data Analyst
# 4                         Quantitative Analyst | #769
# 5                           Analytics DevOps Engineer
# 6                    IT Project Manager – Sourcing BI
# 7                         HAI Prevention Data Analyst
# 8                           Research Scientist Senior
# 9                                        Data Analyst
# 10                            Principal Data Engineer
# 11  Manager, Consumer Insights & Statistical Analysis
# 12                                 Big Data Architect
# 13             Principal Data Scientist - Atlanta, GA
# 14                                     Data Scientist

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available
# - Test the functions on the results above

# %%
# get text
# def extract_text(el):
#     if el:
#         return el.text.strip()
#     else:
#         return ''
        
# # company
# def get_company_from_result(result):
#     return extract_text(result.find('span', {'class' : 'company'}))

# # location
# def get_location_from_result(result):
#     return extract_text(result.find('span', {'class' : 'location'}))
# # summary
# def get_summary_from_result(result):
#     return extract_text(result.find('span', {'class' : 'sumamry'}))
# # title
# def get_title_from_result(result):
#     return extract_text(result.find('a', {'data-tn-element' : 'jobTitle'}))
# # get salary if exists
# def get_salary_from_result(result):
#     salary_table = result.find('td', {'class' : 'snip'})
#     if salary_table:
#         snip = salary_table.find('nobr')
#         if snip:
#             return snip.text.strip()   
#     return None

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results: the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try different city). The second controls where in the results to start and gives 10 results (so we can keep incrementing this by 10 to move further within the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and start points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
# # create template URL and max number of results (pages) to pull
# url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}&pp="

# cities=['atlanta','charlotte','newark','chicago','los+angeles','seattle',
#         'richmond','raleigh','miami','new+york','detroit','san+francisco','boston',
#         'dallas','houston','']

# df=pd.DataFrame()
# # for loop to pull data with bs4
# for city in cities: 
#     for i in range (0,500,10):
#         link=url_template.format(city,i)
#         r=requests.get(link)
#         soup=BeautifulSoup(r.content,'lxml')
#         results = soup.find_all('div', { "class" : "result" })
        
#         for result in results:
#             if result:
#                 company = get_company_from_result(result)
#                 title = get_title_from_result(result)
#                 location = get_location_from_result(result)
#                 salary = get_salary_from_result(result)
#                 df=df.append({"Company Name": company, "Job Title": title, "Location": location,
#                              "Salary": salary}, ignore_index=True)
            
# df
# Out:
#                                             Company Name  \
# 0                                     Predictive Science
# 1                                        MobileDev Power
# 2                                             Home Depot
# 3                                 Vision3 Solutions, Inc
# 4                                 eTek IT Services, Inc.
# 5                                               Deloitte
# 6                                             LexisNexis
# 7                                                 Google
# 8                                          Reed Elsevier
# 9                                      Vesta Corporation
# 10                                        Cox Automotive
# 11                                      Northrop Grumman
# 12                          Wiser Wealth Management, Inc
# 13                                        Cox Automotive
# 14                                             Honeywell
# 15                                       MobileDev Power
# 16                                        Cox Automotive
# 17                                            Home Depot
# 18                                                   ICF
# 19                                             Ashton212
# 20                                             Honeywell
# 21                                              GE Power
# 22                                      Northrop Grumman
# 23                                       Lockheed Martin
# 24                           Eagle Medical Services, LLC
# 25                                Cardlytics Corporation
# 26                                                Turner
# 27                                             Honeywell
# 28                                             Honeywell
# 29                                    Predictive Science
# ...                                                  ...
# 11810                                 Riverside Research
# 11811                                              Intel
# 11812                           Source Select Group, LLC
# 11813                                  EOIR Technologies
# 11814                                           Celmatix
# 11815                                          TutorCare
# 11816                                             Aetion
# 11817                                                 3M
# 11818                               Elite WorkForce, Inc
# 11819                    Georgia Tech Research Institute
# 11820             Fred Hutchinson Cancer Research Center
# 11821                                         ResearchDx
# 11822                                   Rapid Temps, Inc
# 11823                                              Intel
# 11824                                              Intel
# 11825                                              Intel
# 11826                                   Rapid Temps, Inc
# 11827                                            DbTemps
# 11828                                     Morgan Stanley
# 11829                                              Apple
# 11830                                           MaxPoint
# 11831                     Synchronoss Technologies, Inc.
# 11832                                                 LT
# 11833                                    IPG Mediabrands
# 11834                                               IXIS
# 11835  The Henry M. Jackson Foundation for the Advanc...
# 11836                                      Bluefusioninc
# 11837                                              Intel
# 11838                                 Riverside Research
# 11839                                              Intel
#
#                                                Job Title  \
# 0                                         Data Scientist
# 1                Data Scientist With Predictive Modeling
# 2                                         DATA SCIENTIST
# 3                               Data Scientist- Big Data
# 4                                      Big Data Engineer
# 5      Federal Mission Analytics Data Scientist - Sen...
# 6                          Associate Statistical Modeler
# 7      Cloud Instructor (Big Data, Machine Learning),...
# 8                          Associate Statistical Modeler
# 9                                  Senior Data Scientist
# 10                                 Senior Data Scientist
# 11                               Scientific Data Analyst
# 12                   Research / Financial Analyst Intern
# 13                                        Data Scientist
# 14                Principal Data Scientist - Atlanta, GA
# 15               Data Scientist With Predictive Modeling
# 16                                        Data Scientist
# 17                                        DATA SCIENTIST
# 18                               Scientific Data Analyst
# 19                           Quantitative Analyst | #769
# 20                             Analytics DevOps Engineer
# 21                      IT Project Manager – Sourcing BI
# 22                           HAI Prevention Data Analyst
# 23                             Research Scientist Senior
# 24                                          Data Analyst
# 25                               Principal Data Engineer
# 26     Manager, Consumer Insights & Statistical Analysis
# 27                                    Big Data Architect
# 28                Principal Data Scientist - Atlanta, GA
# 29                                        Data Scientist
# ...                                                  ...
# 11810                                     Data Scientist
# 11811                        Data Scientist_CG Evergreen
# 11812                           Statistical Data Analyst
# 11813                                   Senior Scientist
# 11814                                 Clinical Data Lead
# 11815  Data Analysis for Criminal Justice tutor neede...
# 11816                                      Data Engineer
# 11817  3M HIS Specialist, Algorithm Data Engineers (M...
# 11818                              Senior Data Scientist
# 11819  Data Model Development Engineer Dayton,OH ACL-...
# 11820            Data Scientist - Systems Analyst/Prog V
# 11821                               Research Scientist I
# 11822                      Clinical Laboratory Scientist
# 11823                    Data Scientist_Intern Evergreen
# 11824           Data Scientist/Machine Learning Engineer
# 11825                        Data Scientist_CG Evergreen
# 11826                      Clinical Laboratory Scientist
# 11827                 Data Analysis & Reporting Services
# 11828  Global Financial Crimes Quantitative Data Analyst
# 11829                     Siri Reliability Data Engineer
# 11830                           Director of Data Science
# 11831         Data Scientist – Quality Assurance Analyst
# 11832                              Senior Data Scientist
# 11833                    Magna Global - Research Analyst
# 11834          DIGITAL ANALYTICS IMPLEMENTATION ENGINEER
# 11835                                   Research Analyst
# 11836                        Operations Research Analyst
# 11837                    Data Scientist_Intern Evergreen
# 11838                                     Data Scientist
# 11839           Data Scientist/Machine Learning Engineer
#
#                                            Location             Salary
# 0                                     United States               None
# 1                                 Atlanta, GA 30305               None
# 2                                 Atlanta, GA 30354               None
# 3                                       Atlanta, GA        $90 an hour
# 4                                       Atlanta, GA        $67 an hour
# 5                                       Atlanta, GA               None
# 6                              Alpharetta, GA 30005               None
# 7                                       Atlanta, GA               None
# 8                                    Alpharetta, GA               None
# 9              Atlanta, GA 30303 (Five Points area)               None
# 10                                      Atlanta, GA               None
# 11                                      Atlanta, GA               None
# 12                               Marietta, GA 30060               None
# 13                                      Atlanta, GA               None
# 14                                      Atlanta, GA               None
# 15                                Atlanta, GA 30305               None
# 16                                      Atlanta, GA               None
# 17                                Atlanta, GA 30354               None
# 18                                      Atlanta, GA               None
# 19                                      Atlanta, GA               None
# 20                                      Atlanta, GA               None
# 21                                      Atlanta, GA               None
# 22                                      Atlanta, GA               None
# 23                               Marietta, GA 30063               None
# 24                                      Atlanta, GA               None
# 25                                      Atlanta, GA               None
# 26                                Atlanta, GA 30319               None
# 27                                      Atlanta, GA               None
# 28                                      Atlanta, GA               None
# 29                                    United States               None
# ...                                             ...                ...
# 11810                               Buckley AFB, CO               None
# 11811                         Santa Clara, CA 95052               None
# 11812                                Clearwater, FL               None
# 11813                         Springfield, VA 22150               None
# 11814  New York, NY 10005 (Financial District area)               None
# 11815                                   Orlando, FL  $16 - $18 an hour
# 11816                                  New York, NY               None
# 11817         Austin, TX 78753 (Windsor Hills area)               None
# 11818                               Tampa, FL 33615               None
# 11819                                    Dayton, OH               None
# 11820             Seattle, WA 98109 (Westlake area)               None
# 11821                              Irvine, CA 92618               None
# 11822                          Fall River Mills, CA               None
# 11823                         Santa Clara, CA 95052               None
# 11824                           San Diego, CA 92129               None
# 11825                         Santa Clara, CA 95052               None
# 11826                          Fall River Mills, CA               None
# 11827                             Santa Barbara, CA               None
# 11828                                 Baltimore, MD               None
# 11829                        Santa Clara Valley, CA               None
# 11830                         Morrisville, NC 27560               None
# 11831                                    Reston, VA               None
# 11832                               Los Angeles, CA    $180,000 a year
# 11833                             San Francisco, CA               None
# 11834                          Burlington, VT 05401               None
# 11835                                  Bethesda, MD               None
# 11836                                   Atlanta, GA               None
# 11837                         Santa Clara, CA 95052               None
# 11838                               Buckley AFB, CO               None
# 11839                           San Diego, CA 92129               None
#
# [11840 rows x 4 columns]

# %%
# df.to_csv("indeed_file.csv",encoding='utf-8')

# %%
df=pd.read_csv("indeed_file.csv")
df.head()
# Out:
#    Unnamed: 0            Company Name  \
# 0           0      Predictive Science
# 1           1         MobileDev Power
# 2           2              Home Depot
# 3           3  Vision3 Solutions, Inc
# 4           4  eTek IT Services, Inc.
#
#                                  Job Title           Location       Salary
# 0                           Data Scientist      United States          NaN
# 1  Data Scientist With Predictive Modeling  Atlanta, GA 30305          NaN
# 2                           DATA SCIENTIST  Atlanta, GA 30354          NaN
# 3                 Data Scientist- Big Data        Atlanta, GA  $90 an hour
# 4                        Big Data Engineer        Atlanta, GA  $67 an hour

# %%
len(df) # total of 11840 rows
# Out:
# 11840

# %%
df.shape
# Out:
# (11840, 5)

# %% [markdown]
# Lastly, we need to clean up salary data.
#
# 1. Only a small number of the scraped results have salary information - only these will be used for modeling.
# 1. Some of the salaries are not yearly but hourly or weekly, these will not be useful to us for now
# 1. Some of the entries may be duplicated
# 1. The salaries are given as text and usually with ranges.
#
# #### Find the entries with annual salary entries, by filtering the entries without salaries or salaries that are not yearly (filter those that refer to hour or week). Also, remove duplicate entries

# %%
df.set_index(["Unnamed: 0"])
# Out:
#                                                  Company Name  \
# Unnamed: 0
# 0                                          Predictive Science
# 1                                             MobileDev Power
# 2                                                  Home Depot
# 3                                      Vision3 Solutions, Inc
# 4                                      eTek IT Services, Inc.
# 5                                                    Deloitte
# 6                                                  LexisNexis
# 7                                                      Google
# 8                                               Reed Elsevier
# 9                                           Vesta Corporation
# 10                                             Cox Automotive
# 11                                           Northrop Grumman
# 12                               Wiser Wealth Management, Inc
# 13                                             Cox Automotive
# 14                                                  Honeywell
# 15                                            MobileDev Power
# 16                                             Cox Automotive
# 17                                                 Home Depot
# 18                                                        ICF
# 19                                                  Ashton212
# 20                                                  Honeywell
# 21                                                   GE Power
# 22                                           Northrop Grumman
# 23                                            Lockheed Martin
# 24                                Eagle Medical Services, LLC
# 25                                     Cardlytics Corporation
# 26                                                     Turner
# 27                                                  Honeywell
# 28                                                  Honeywell
# 29                                         Predictive Science
# ...                                                       ...
# 11810                                      Riverside Research
# 11811                                                   Intel
# 11812                                Source Select Group, LLC
# 11813                                       EOIR Technologies
# 11814                                                Celmatix
# 11815                                               TutorCare
# 11816                                                  Aetion
# 11817                                                      3M
# 11818                                    Elite WorkForce, Inc
# 11819                         Georgia Tech Research Institute
# 11820                  Fred Hutchinson Cancer Research Center
# 11821                                              ResearchDx
# 11822                                        Rapid Temps, Inc
# 11823                                                   Intel
# 11824                                                   Intel
# 11825                                                   Intel
# 11826                                        Rapid Temps, Inc
# 11827                                                 DbTemps
# 11828                                          Morgan Stanley
# 11829                                                   Apple
# 11830                                                MaxPoint
# 11831                          Synchronoss Technologies, Inc.
# 11832                                                      LT
# 11833                                         IPG Mediabrands
# 11834                                                    IXIS
# 11835       The Henry M. Jackson Foundation for the Advanc...
# 11836                                           Bluefusioninc
# 11837                                                   Intel
# 11838                                      Riverside Research
# 11839                                                   Intel
#
#                                                     Job Title  \
# Unnamed: 0
# 0                                              Data Scientist
# 1                     Data Scientist With Predictive Modeling
# 2                                              DATA SCIENTIST
# 3                                    Data Scientist- Big Data
# 4                                           Big Data Engineer
# 5           Federal Mission Analytics Data Scientist - Sen...
# 6                               Associate Statistical Modeler
# 7           Cloud Instructor (Big Data, Machine Learning),...
# 8                               Associate Statistical Modeler
# 9                                       Senior Data Scientist
# 10                                      Senior Data Scientist
# 11                                    Scientific Data Analyst
# 12                        Research / Financial Analyst Intern
# 13                                             Data Scientist
# 14                     Principal Data Scientist - Atlanta, GA
# 15                    Data Scientist With Predictive Modeling
# 16                                             Data Scientist
# 17                                             DATA SCIENTIST
# 18                                    Scientific Data Analyst
# 19                                Quantitative Analyst | #769
# 20                                  Analytics DevOps Engineer
# 21                           IT Project Manager – Sourcing BI
# 22                                HAI Prevention Data Analyst
# 23                                  Research Scientist Senior
# 24                                               Data Analyst
# 25                                    Principal Data Engineer
# 26          Manager, Consumer Insights & Statistical Analysis
# 27                                         Big Data Architect
# 28                     Principal Data Scientist - Atlanta, GA
# 29                                             Data Scientist
# ...                                                       ...
# 11810                                          Data Scientist
# 11811                             Data Scientist_CG Evergreen
# 11812                                Statistical Data Analyst
# 11813                                        Senior Scientist
# 11814                                      Clinical Data Lead
# 11815       Data Analysis for Criminal Justice tutor neede...
# 11816                                           Data Engineer
# 11817       3M HIS Specialist, Algorithm Data Engineers (M...
# 11818                                   Senior Data Scientist
# 11819       Data Model Development Engineer Dayton,OH ACL-...
# 11820                 Data Scientist - Systems Analyst/Prog V
# 11821                                    Research Scientist I
# 11822                           Clinical Laboratory Scientist
# 11823                         Data Scientist_Intern Evergreen
# 11824                Data Scientist/Machine Learning Engineer
# 11825                             Data Scientist_CG Evergreen
# 11826                           Clinical Laboratory Scientist
# 11827                      Data Analysis & Reporting Services
# 11828       Global Financial Crimes Quantitative Data Analyst
# 11829                          Siri Reliability Data Engineer
# 11830                                Director of Data Science
# 11831              Data Scientist – Quality Assurance Analyst
# 11832                                   Senior Data Scientist
# 11833                         Magna Global - Research Analyst
# 11834               DIGITAL ANALYTICS IMPLEMENTATION ENGINEER
# 11835                                        Research Analyst
# 11836                             Operations Research Analyst
# 11837                         Data Scientist_Intern Evergreen
# 11838                                          Data Scientist
# 11839                Data Scientist/Machine Learning Engineer
#
#                                                 Location             Salary
# Unnamed: 0
# 0                                          United States                NaN
# 1                                      Atlanta, GA 30305                NaN
# 2                                      Atlanta, GA 30354                NaN
# 3                                            Atlanta, GA        $90 an hour
# 4                                            Atlanta, GA        $67 an hour
# 5                                            Atlanta, GA                NaN
# 6                                   Alpharetta, GA 30005                NaN
# 7                                            Atlanta, GA                NaN
# 8                                         Alpharetta, GA                NaN
# 9                   Atlanta, GA 30303 (Five Points area)                NaN
# 10                                           Atlanta, GA                NaN
# 11                                           Atlanta, GA                NaN
# 12                                    Marietta, GA 30060                NaN
# 13                                           Atlanta, GA                NaN
# 14                                           Atlanta, GA                NaN
# 15                                     Atlanta, GA 30305                NaN
# 16                                           Atlanta, GA                NaN
# 17                                     Atlanta, GA 30354                NaN
# 18                                           Atlanta, GA                NaN
# 19                                           Atlanta, GA                NaN
# 20                                           Atlanta, GA                NaN
# 21                                           Atlanta, GA                NaN
# 22                                           Atlanta, GA                NaN
# 23                                    Marietta, GA 30063                NaN
# 24                                           Atlanta, GA                NaN
# 25                                           Atlanta, GA                NaN
# 26                                     Atlanta, GA 30319                NaN
# 27                                           Atlanta, GA                NaN
# 28                                           Atlanta, GA                NaN
# 29                                         United States                NaN
# ...                                                  ...                ...
# 11810                                    Buckley AFB, CO                NaN
# 11811                              Santa Clara, CA 95052                NaN
# 11812                                     Clearwater, FL                NaN
# 11813                              Springfield, VA 22150                NaN
# 11814       New York, NY 10005 (Financial District area)                NaN
# 11815                                        Orlando, FL  $16 - $18 an hour
# 11816                                       New York, NY                NaN
# 11817              Austin, TX 78753 (Windsor Hills area)                NaN
# 11818                                    Tampa, FL 33615                NaN
# 11819                                         Dayton, OH                NaN
# 11820                  Seattle, WA 98109 (Westlake area)                NaN
# 11821                                   Irvine, CA 92618                NaN
# 11822                               Fall River Mills, CA                NaN
# 11823                              Santa Clara, CA 95052                NaN
# 11824                                San Diego, CA 92129                NaN
# 11825                              Santa Clara, CA 95052                NaN
# 11826                               Fall River Mills, CA                NaN
# 11827                                  Santa Barbara, CA                NaN
# 11828                                      Baltimore, MD                NaN
# 11829                             Santa Clara Valley, CA                NaN
# 11830                              Morrisville, NC 27560                NaN
# 11831                                         Reston, VA                NaN
# 11832                                    Los Angeles, CA    $180,000 a year
# 11833                                  San Francisco, CA                NaN
# 11834                               Burlington, VT 05401                NaN
# 11835                                       Bethesda, MD                NaN
# 11836                                        Atlanta, GA                NaN
# 11837                              Santa Clara, CA 95052                NaN
# 11838                                    Buckley AFB, CO                NaN
# 11839                                San Diego, CA 92129                NaN
#
# [11840 rows x 4 columns]

# %%
df2=df[['Company Name','Job Title','Location','Salary']]
df2 #11840 rows
# Out:
#                                             Company Name  \
# 0                                     Predictive Science
# 1                                        MobileDev Power
# 2                                             Home Depot
# 3                                 Vision3 Solutions, Inc
# 4                                 eTek IT Services, Inc.
# 5                                               Deloitte
# 6                                             LexisNexis
# 7                                                 Google
# 8                                          Reed Elsevier
# 9                                      Vesta Corporation
# 10                                        Cox Automotive
# 11                                      Northrop Grumman
# 12                          Wiser Wealth Management, Inc
# 13                                        Cox Automotive
# 14                                             Honeywell
# 15                                       MobileDev Power
# 16                                        Cox Automotive
# 17                                            Home Depot
# 18                                                   ICF
# 19                                             Ashton212
# 20                                             Honeywell
# 21                                              GE Power
# 22                                      Northrop Grumman
# 23                                       Lockheed Martin
# 24                           Eagle Medical Services, LLC
# 25                                Cardlytics Corporation
# 26                                                Turner
# 27                                             Honeywell
# 28                                             Honeywell
# 29                                    Predictive Science
# ...                                                  ...
# 11810                                 Riverside Research
# 11811                                              Intel
# 11812                           Source Select Group, LLC
# 11813                                  EOIR Technologies
# 11814                                           Celmatix
# 11815                                          TutorCare
# 11816                                             Aetion
# 11817                                                 3M
# 11818                               Elite WorkForce, Inc
# 11819                    Georgia Tech Research Institute
# 11820             Fred Hutchinson Cancer Research Center
# 11821                                         ResearchDx
# 11822                                   Rapid Temps, Inc
# 11823                                              Intel
# 11824                                              Intel
# 11825                                              Intel
# 11826                                   Rapid Temps, Inc
# 11827                                            DbTemps
# 11828                                     Morgan Stanley
# 11829                                              Apple
# 11830                                           MaxPoint
# 11831                     Synchronoss Technologies, Inc.
# 11832                                                 LT
# 11833                                    IPG Mediabrands
# 11834                                               IXIS
# 11835  The Henry M. Jackson Foundation for the Advanc...
# 11836                                      Bluefusioninc
# 11837                                              Intel
# 11838                                 Riverside Research
# 11839                                              Intel
#
#                                                Job Title  \
# 0                                         Data Scientist
# 1                Data Scientist With Predictive Modeling
# 2                                         DATA SCIENTIST
# 3                               Data Scientist- Big Data
# 4                                      Big Data Engineer
# 5      Federal Mission Analytics Data Scientist - Sen...
# 6                          Associate Statistical Modeler
# 7      Cloud Instructor (Big Data, Machine Learning),...
# 8                          Associate Statistical Modeler
# 9                                  Senior Data Scientist
# 10                                 Senior Data Scientist
# 11                               Scientific Data Analyst
# 12                   Research / Financial Analyst Intern
# 13                                        Data Scientist
# 14                Principal Data Scientist - Atlanta, GA
# 15               Data Scientist With Predictive Modeling
# 16                                        Data Scientist
# 17                                        DATA SCIENTIST
# 18                               Scientific Data Analyst
# 19                           Quantitative Analyst | #769
# 20                             Analytics DevOps Engineer
# 21                      IT Project Manager – Sourcing BI
# 22                           HAI Prevention Data Analyst
# 23                             Research Scientist Senior
# 24                                          Data Analyst
# 25                               Principal Data Engineer
# 26     Manager, Consumer Insights & Statistical Analysis
# 27                                    Big Data Architect
# 28                Principal Data Scientist - Atlanta, GA
# 29                                        Data Scientist
# ...                                                  ...
# 11810                                     Data Scientist
# 11811                        Data Scientist_CG Evergreen
# 11812                           Statistical Data Analyst
# 11813                                   Senior Scientist
# 11814                                 Clinical Data Lead
# 11815  Data Analysis for Criminal Justice tutor neede...
# 11816                                      Data Engineer
# 11817  3M HIS Specialist, Algorithm Data Engineers (M...
# 11818                              Senior Data Scientist
# 11819  Data Model Development Engineer Dayton,OH ACL-...
# 11820            Data Scientist - Systems Analyst/Prog V
# 11821                               Research Scientist I
# 11822                      Clinical Laboratory Scientist
# 11823                    Data Scientist_Intern Evergreen
# 11824           Data Scientist/Machine Learning Engineer
# 11825                        Data Scientist_CG Evergreen
# 11826                      Clinical Laboratory Scientist
# 11827                 Data Analysis & Reporting Services
# 11828  Global Financial Crimes Quantitative Data Analyst
# 11829                     Siri Reliability Data Engineer
# 11830                           Director of Data Science
# 11831         Data Scientist – Quality Assurance Analyst
# 11832                              Senior Data Scientist
# 11833                    Magna Global - Research Analyst
# 11834          DIGITAL ANALYTICS IMPLEMENTATION ENGINEER
# 11835                                   Research Analyst
# 11836                        Operations Research Analyst
# 11837                    Data Scientist_Intern Evergreen
# 11838                                     Data Scientist
# 11839           Data Scientist/Machine Learning Engineer
#
#                                            Location             Salary
# 0                                     United States                NaN
# 1                                 Atlanta, GA 30305                NaN
# 2                                 Atlanta, GA 30354                NaN
# 3                                       Atlanta, GA        $90 an hour
# 4                                       Atlanta, GA        $67 an hour
# 5                                       Atlanta, GA                NaN
# 6                              Alpharetta, GA 30005                NaN
# 7                                       Atlanta, GA                NaN
# 8                                    Alpharetta, GA                NaN
# 9              Atlanta, GA 30303 (Five Points area)                NaN
# 10                                      Atlanta, GA                NaN
# 11                                      Atlanta, GA                NaN
# 12                               Marietta, GA 30060                NaN
# 13                                      Atlanta, GA                NaN
# 14                                      Atlanta, GA                NaN
# 15                                Atlanta, GA 30305                NaN
# 16                                      Atlanta, GA                NaN
# 17                                Atlanta, GA 30354                NaN
# 18                                      Atlanta, GA                NaN
# 19                                      Atlanta, GA                NaN
# 20                                      Atlanta, GA                NaN
# 21                                      Atlanta, GA                NaN
# 22                                      Atlanta, GA                NaN
# 23                               Marietta, GA 30063                NaN
# 24                                      Atlanta, GA                NaN
# 25                                      Atlanta, GA                NaN
# 26                                Atlanta, GA 30319                NaN
# 27                                      Atlanta, GA                NaN
# 28                                      Atlanta, GA                NaN
# 29                                    United States                NaN
# ...                                             ...                ...
# 11810                               Buckley AFB, CO                NaN
# 11811                         Santa Clara, CA 95052                NaN
# 11812                                Clearwater, FL                NaN
# 11813                         Springfield, VA 22150                NaN
# 11814  New York, NY 10005 (Financial District area)                NaN
# 11815                                   Orlando, FL  $16 - $18 an hour
# 11816                                  New York, NY                NaN
# 11817         Austin, TX 78753 (Windsor Hills area)                NaN
# 11818                               Tampa, FL 33615                NaN
# 11819                                    Dayton, OH                NaN
# 11820             Seattle, WA 98109 (Westlake area)                NaN
# 11821                              Irvine, CA 92618                NaN
# 11822                          Fall River Mills, CA                NaN
# 11823                         Santa Clara, CA 95052                NaN
# 11824                           San Diego, CA 92129                NaN
# 11825                         Santa Clara, CA 95052                NaN
# 11826                          Fall River Mills, CA                NaN
# 11827                             Santa Barbara, CA                NaN
# 11828                                 Baltimore, MD                NaN
# 11829                        Santa Clara Valley, CA                NaN
# 11830                         Morrisville, NC 27560                NaN
# 11831                                    Reston, VA                NaN
# 11832                               Los Angeles, CA    $180,000 a year
# 11833                             San Francisco, CA                NaN
# 11834                          Burlington, VT 05401                NaN
# 11835                                  Bethesda, MD                NaN
# 11836                                   Atlanta, GA                NaN
# 11837                         Santa Clara, CA 95052                NaN
# 11838                               Buckley AFB, CO                NaN
# 11839                           San Diego, CA 92129                NaN
#
# [11840 rows x 4 columns]

# %%
df2.drop_duplicates()
# Out:
#                                             Company Name  \
# 0                                     Predictive Science
# 1                                        MobileDev Power
# 2                                             Home Depot
# 3                                 Vision3 Solutions, Inc
# 4                                 eTek IT Services, Inc.
# 5                                               Deloitte
# 6                                             LexisNexis
# 7                                                 Google
# 8                                          Reed Elsevier
# 9                                      Vesta Corporation
# 10                                        Cox Automotive
# 11                                      Northrop Grumman
# 12                          Wiser Wealth Management, Inc
# 13                                        Cox Automotive
# 14                                             Honeywell
# 15                                       MobileDev Power
# 16                                        Cox Automotive
# 17                                            Home Depot
# 18                                                   ICF
# 19                                             Ashton212
# 20                                             Honeywell
# 21                                              GE Power
# 22                                      Northrop Grumman
# 23                                       Lockheed Martin
# 24                           Eagle Medical Services, LLC
# 25                                Cardlytics Corporation
# 26                                                Turner
# 27                                             Honeywell
# 28                                             Honeywell
# 29                                    Predictive Science
# ...                                                  ...
# 11810                                 Riverside Research
# 11811                                              Intel
# 11812                           Source Select Group, LLC
# 11813                                  EOIR Technologies
# 11814                                           Celmatix
# 11815                                          TutorCare
# 11816                                             Aetion
# 11817                                                 3M
# 11818                               Elite WorkForce, Inc
# 11819                    Georgia Tech Research Institute
# 11820             Fred Hutchinson Cancer Research Center
# 11821                                         ResearchDx
# 11822                                   Rapid Temps, Inc
# 11823                                              Intel
# 11824                                              Intel
# 11825                                              Intel
# 11826                                   Rapid Temps, Inc
# 11827                                            DbTemps
# 11828                                     Morgan Stanley
# 11829                                              Apple
# 11830                                           MaxPoint
# 11831                     Synchronoss Technologies, Inc.
# 11832                                                 LT
# 11833                                    IPG Mediabrands
# 11834                                               IXIS
# 11835  The Henry M. Jackson Foundation for the Advanc...
# 11836                                      Bluefusioninc
# 11837                                              Intel
# 11838                                 Riverside Research
# 11839                                              Intel
#
#                                                Job Title  \
# 0                                         Data Scientist
# 1                Data Scientist With Predictive Modeling
# 2                                         DATA SCIENTIST
# 3                               Data Scientist- Big Data
# 4                                      Big Data Engineer
# 5      Federal Mission Analytics Data Scientist - Sen...
# 6                          Associate Statistical Modeler
# 7      Cloud Instructor (Big Data, Machine Learning),...
# 8                          Associate Statistical Modeler
# 9                                  Senior Data Scientist
# 10                                 Senior Data Scientist
# 11                               Scientific Data Analyst
# 12                   Research / Financial Analyst Intern
# 13                                        Data Scientist
# 14                Principal Data Scientist - Atlanta, GA
# 15               Data Scientist With Predictive Modeling
# 16                                        Data Scientist
# 17                                        DATA SCIENTIST
# 18                               Scientific Data Analyst
# 19                           Quantitative Analyst | #769
# 20                             Analytics DevOps Engineer
# 21                      IT Project Manager – Sourcing BI
# 22                           HAI Prevention Data Analyst
# 23                             Research Scientist Senior
# 24                                          Data Analyst
# 25                               Principal Data Engineer
# 26     Manager, Consumer Insights & Statistical Analysis
# 27                                    Big Data Architect
# 28                Principal Data Scientist - Atlanta, GA
# 29                                        Data Scientist
# ...                                                  ...
# 11810                                     Data Scientist
# 11811                        Data Scientist_CG Evergreen
# 11812                           Statistical Data Analyst
# 11813                                   Senior Scientist
# 11814                                 Clinical Data Lead
# 11815  Data Analysis for Criminal Justice tutor neede...
# 11816                                      Data Engineer
# 11817  3M HIS Specialist, Algorithm Data Engineers (M...
# 11818                              Senior Data Scientist
# 11819  Data Model Development Engineer Dayton,OH ACL-...
# 11820            Data Scientist - Systems Analyst/Prog V
# 11821                               Research Scientist I
# 11822                      Clinical Laboratory Scientist
# 11823                    Data Scientist_Intern Evergreen
# 11824           Data Scientist/Machine Learning Engineer
# 11825                        Data Scientist_CG Evergreen
# 11826                      Clinical Laboratory Scientist
# 11827                 Data Analysis & Reporting Services
# 11828  Global Financial Crimes Quantitative Data Analyst
# 11829                     Siri Reliability Data Engineer
# 11830                           Director of Data Science
# 11831         Data Scientist – Quality Assurance Analyst
# 11832                              Senior Data Scientist
# 11833                    Magna Global - Research Analyst
# 11834          DIGITAL ANALYTICS IMPLEMENTATION ENGINEER
# 11835                                   Research Analyst
# 11836                        Operations Research Analyst
# 11837                    Data Scientist_Intern Evergreen
# 11838                                     Data Scientist
# 11839           Data Scientist/Machine Learning Engineer
#
#                                            Location             Salary
# 0                                     United States                NaN
# 1                                 Atlanta, GA 30305                NaN
# 2                                 Atlanta, GA 30354                NaN
# 3                                       Atlanta, GA        $90 an hour
# 4                                       Atlanta, GA        $67 an hour
# 5                                       Atlanta, GA                NaN
# 6                              Alpharetta, GA 30005                NaN
# 7                                       Atlanta, GA                NaN
# 8                                    Alpharetta, GA                NaN
# 9              Atlanta, GA 30303 (Five Points area)                NaN
# 10                                      Atlanta, GA                NaN
# 11                                      Atlanta, GA                NaN
# 12                               Marietta, GA 30060                NaN
# 13                                      Atlanta, GA                NaN
# 14                                      Atlanta, GA                NaN
# 15                                Atlanta, GA 30305                NaN
# 16                                      Atlanta, GA                NaN
# 17                                Atlanta, GA 30354                NaN
# 18                                      Atlanta, GA                NaN
# 19                                      Atlanta, GA                NaN
# 20                                      Atlanta, GA                NaN
# 21                                      Atlanta, GA                NaN
# 22                                      Atlanta, GA                NaN
# 23                               Marietta, GA 30063                NaN
# 24                                      Atlanta, GA                NaN
# 25                                      Atlanta, GA                NaN
# 26                                Atlanta, GA 30319                NaN
# 27                                      Atlanta, GA                NaN
# 28                                      Atlanta, GA                NaN
# 29                                    United States                NaN
# ...                                             ...                ...
# 11810                               Buckley AFB, CO                NaN
# 11811                         Santa Clara, CA 95052                NaN
# 11812                                Clearwater, FL                NaN
# 11813                         Springfield, VA 22150                NaN
# 11814  New York, NY 10005 (Financial District area)                NaN
# 11815                                   Orlando, FL  $16 - $18 an hour
# 11816                                  New York, NY                NaN
# 11817         Austin, TX 78753 (Windsor Hills area)                NaN
# 11818                               Tampa, FL 33615                NaN
# 11819                                    Dayton, OH                NaN
# 11820             Seattle, WA 98109 (Westlake area)                NaN
# 11821                              Irvine, CA 92618                NaN
# 11822                          Fall River Mills, CA                NaN
# 11823                         Santa Clara, CA 95052                NaN
# 11824                           San Diego, CA 92129                NaN
# 11825                         Santa Clara, CA 95052                NaN
# 11826                          Fall River Mills, CA                NaN
# 11827                             Santa Barbara, CA                NaN
# 11828                                 Baltimore, MD                NaN
# 11829                        Santa Clara Valley, CA                NaN
# 11830                         Morrisville, NC 27560                NaN
# 11831                                    Reston, VA                NaN
# 11832                               Los Angeles, CA    $180,000 a year
# 11833                             San Francisco, CA                NaN
# 11834                          Burlington, VT 05401                NaN
# 11835                                  Bethesda, MD                NaN
# 11836                                   Atlanta, GA                NaN
# 11837                         Santa Clara, CA 95052                NaN
# 11838                               Buckley AFB, CO                NaN
# 11839                           San Diego, CA 92129                NaN
#
# [11840 rows x 4 columns]

# %%
# Dropping rows that have NA values
df3=df2.dropna()
len(df3) #533 rows after dropping NA and duplicates
# Out:
# 533

# %%
# Filter out salary entries referring to week, hour or month
df3 = df3[~(df3.Salary.astype('str').str.contains('hour'))]
df3 = df3[~(df3.Salary.astype('str').str.contains('month'))]
print df3.shape
df3.head()
# Out:
# (367, 4)
#                                   Company Name               Job Title  \
# 37  Centers for Disease Control and Prevention    Behavioral Scientist
# 48                         Analytic Recruiting   Junior Data Scientist
# 50                     Smith Hanley Associates  Marketing Statistician
# 84                         Analytic Recruiting   Senior Data Scientist
# 98                                  Stackfolio     Lead Data Scientist
#
#                                     Location                      Salary
# 37                               Atlanta, GA    $74,260 - $96,538 a year
# 48                            Alpharetta, GA    $75,000 - $90,000 a year
# 50                               Atlanta, GA   $75,000 - $100,000 a year
# 84                               Atlanta, GA  $100,000 - $125,000 a year
# 98  Atlanta, GA 30308 (Old Fourth Ward area)              $80,000 a year

# %%
df2['Sal_range'] = [df2['Salary'].replace('a year','') for salry in df2['Salary']]
del df2["Sal_range"]
df2['ayear'] = df2['Salary'].str.extract('(. ....)', expand=True)
del df2['ayear']
df2['new_year1'] = df2['Salary'].str.extract('([0-9]+,[0-9]+)', expand=True)
df2['new_year2'] = df2['Salary'].str.extract('-([0-9]+,[0-9]+)', expand=True)
df2.head()
# Out:
#                                           Company Name  \
# Unnamed: 0
# 7           Centers for Disease Control and Prevention
# 23                                    Emory University
# 26          Centers for Disease Control and Prevention
# 36                                 Analytic Recruiting
# 71                                          Stackfolio
#
#                                              Job Title  \
# Unnamed: 0
# 7           Centers for Disease Control and Prevention
# 23                                    Emory University
# 26          Centers for Disease Control and Prevention
# 36                                 Analytic Recruiting
# 71                                          Stackfolio
#
#                                             Location  \
# Unnamed: 0
# 7                                        Atlanta, GA
# 23                                       Atlanta, GA
# 26                                       Atlanta, GA
# 36                                    Alpharetta, GA
# 71          Atlanta, GA 30308 (Old Fourth Ward area)
#
#                                Salary new_year new_year2 new_year1
# Unnamed: 0
# 7           $88,305 - $114,802 a year   88,305       NaN    88,305
# 23                     $85,500 a year   85,500       NaN    85,500
# 26           $74,260 - $96,538 a year   74,260       NaN    74,260
# 36           $75,000 - $90,000 a year   75,000       NaN    75,000
# 71                     $80,000 a year   80,000       NaN    80,000

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
import re
import numpy as np
def extract_salary_average(salary_string):
    regex = r'\$([0-9]+,[0-9]+)'
    matches = re.findall(regex, salary_string)
    return np.mean([float(salary.replace(',', '')) for salary in matches ])

# %%
#extract_salary_average
sal = df2[['Salary']]
sal_col = extract_salary_average(sal)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-217-e3391c675c3e> in <module>()
#       1 #extract_salary_average
#       2 sal = df2[['Salary']]
# ----> 3 sal_col = extract_salary_average(sal)
#
# <ipython-input-209-a76c7d5c6ada> in extract_salary_average(salary_string)
#       3 def extract_salary_average(salary_string):
#       4     regex = r'\$([0-9]+,[0-9]+)'
# ----> 5     matches = re.findall(regex, salary_string)
#       6     return np.mean([float(salary.replace(',', '')) for salary in matches ])
#
# //anaconda/lib/python2.7/re.pyc in findall(pattern, string, flags)
#     179
#     180     Empty matches are included in the result."""
# --> 181     return _compile(pattern, flags).findall(string)
#     182
#     183 if sys.hexversion >= 0x02020000:
#
# TypeError: expected string or buffer

# %%
# use '.map' to transform salary to new feature

# %%
# save scraped results as a CSV for Tableau/external viz

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %%
# load in the the data of scraped salaries

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
# calculate median and create feature with 1 as high salary

# %% [markdown]
# ### Q: What is the baseline accuracy for this model?

# %% [markdown]
# It is 50% if we guess randomly, half the salaries will be below the median and half will be above.

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
# create statsmodel and summary
import statsmodels.formula.api as sm

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' or 'Manager' is in the title
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
# create senior, director, and manager dummies
salary_data['is_senior'] = salary_data['title'].str.contains('Senior').astype(int) # example

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
# scale, (patsy optional), and fit
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from patsy import dmatrix

scaler = StandardScaler()
model = LogisticRegression(penalty = 'l2', C=0.1)

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
from sklearn.cross_validation import cross_val_score

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']: # example

# %% [markdown]
# ### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
model = LogisticRegression(penalty = 'l1', C=1.0)

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:

# %%
model.fit(X_scaled, y)

df = pd.DataFrame({'features' : X.design_info.column_names, 'coef': model.coef_[0,:]})
df.sort_values('coef', ascending=False, inplace=True)
df

# %% [markdown]
# #### Optional: Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients. Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary. Which entries have the highest predicted salaries?

# %% [markdown]
# # Bonus Section: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are most valuable?

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform()

for metric in ['accuracy', 'precision', 'recall', 'roc_auc']:
    scores = cross_val_score(model, X_scaled, y, cv=3, scoring=metric)
    print(metric, scores.mean(), scores.std())

# %%
model.fit(X_scaled, y)

df = pd.DataFrame({'features' : vectorizer.get_feature_names(), 'coef': model.coef_[0,:]})
df.sort_values('coef', ascending=False, inplace=True)

# %%
df.head()

# %%
df.tail()

# %%
# retest L1 and L2 regularization
from sklearn.linear_model import LogisticRegressionCV

model = LogisticRegressionCV()

# %% [markdown]
# Score: | /24
# ------|-------
# Identify: Problem Statement and Hypothesis |
# Acquire: Import Data using BeautifulSoup|
# Parse: Clean and Organize Data|
# Model: Perform Logistic Regression|
# Evaluate: Logistic Regression Results	|
# Present: Blog Report with Findings and Recommendations		|
# Interactive Tableau visualizations |
# Regularization |
# Bonus: Countvectorizer  |
