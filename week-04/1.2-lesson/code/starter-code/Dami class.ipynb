# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url='https://www.yelp.com/search?find_desc=&find_loc=Atlanta%2C+GA&ns=1'
r=requests.get(url)
r.content
# Out:
# '<!DOCTYPE HTML>\n\n<!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="no-js" lang="en"> <!--<![endif]-->\n    <head>\n            <script>\n            (function() {\n                var main = null;\n\n                var main=function(a){window.onerror=(function(){var c=function(e){return function(){var f;if(Array.prototype.toJSON){f=Array.prototype.toJSON;delete Array.prototype.toJSON}e.apply(this,arguments);if(f){Array.prototype.toJSON=f}}};var d=function()
# ...

# %%
soup=BeautifulSoup(r.content)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE HTML>
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <!--<![endif]-->
#  <head>
#   <script>
#    (function() {
#                 var main = null;
#
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="#header_find_form" rel="nofollow">\n                        Skip to Search Form\n                    </a>,
#  <a href="qqysasef.html" rel="file" style="display: none;">yvdetyezqqyvcvuuttvvyv</a>,
#  <a href="#header-nav" rel="nofollow">\n                        Skip to Navigation\n                    </a>,
#  <a href="#page-content" rel="nofollow">\n                        Skip to Page Content\n                    </a>,
#  <a href="/">Yelp</a>,
#  <a class="ybtn ybtn--primary main-header_button js-search-close main-search_close">\n                        Cancel\n    </a>,
#  <a class="header-nav_link" href="/">\n                            Home\n                        </a>,
#  <a class="header-nav_link" href="/user_details">\n                            About Me\n                        </a>,
#  <a class="header-nav_link" href="/writeareview">\n                            Write a Review\n                        </a>,
# ...

# %%
for element in soup.find_all("a"):
    print element.get("href")
# Out:
# #header_find_form
# qqysasef.html
# #header-nav
# #page-content
# /
# None
# /
# /user_details
# /writeareview
# /find_friends
# /mail
# /talk
# /events
# /signup
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3D%26find_loc%3DAtlanta%252C%2BGA%26ns%3D1
# javascript:;
# https://www.yelp.com/login?return_url=%2Fsearch%3Ffind_desc%3D%26find_loc%3DAtlanta%252C%2BGA%26ns%3D1
# /signup
# /user_details
# /talk
# /search?find_loc=Atlanta%2C+GA&cflt=active
# /search?find_loc=Atlanta%2C+GA&cflt=arts
# /search?find_loc=Atlanta%2C+GA&cflt=auto
# /search?find_loc=Atlanta%2C+GA&cflt=beautysvc
# /search?find_loc=Atlanta%2C+GA&cflt=education
# /search?find_loc=Atlanta%2C+GA&cflt=eventservices
# /search?find_loc=Atlanta%2C+GA&cflt=financialservices
# /search?find_loc=Atlanta%2C+GA&cflt=food
# /search?find_loc=Atlanta%2C+GA&cflt=health
# /search?find_loc=Atlanta%2C+GA&cflt=homeservices
# /search?find_loc=Atlanta%2C+GA&cflt=hotelstravel
# ...

# %%
data=soup.find_all('div',{"class":'biz-listing-large'})
data
# Out:
# [<div class="biz-listing-large">\n<div class="main-attributes">\n<div class="media-block media-block--12">\n<div class="media-avatar">\n<div class="photo-box pb-90s">\n<a class="js-analytics-click" data-analytics-label="biz-photo" href="/adredir?ad_business_id=9c_i9dclp2-ODS5foIgAxg&amp;campaign_id=8bl_BCbrTJNmqtpPUNqivg&amp;click_origin=search_results&amp;placement=above_search&amp;redirect_url=https%3A%2F%2Fwww.yelp.com%2Fbiz%2Fjersey-mikes-mcdonough&amp;request_id=58b04d8e7d1b51c9&amp;signature=26b7f83264ca2018fe8c1721dfa1ef681a42e9dafb8cef613e7c41d511de89aa&amp;slot=0">\n<img alt="Jersey Mike's" class="photo-box-img" height="90" src="https://s3-media3.fl.yelpcdn.com/bphoto/xFSNlGZrK46iSqVzs4F1WQ/90s.jpg" width="90"/>\n</a>\n</div>\n</div>\n<div class="media-story">\n<span aria-hidden="true" class="icon icon--18-info icon--size-18 icon--currentColor yloca-info" data-hovercard-id="1" style="width: 18px; height: 18px;">\n<svg class="icon_svg">\n<use xlink:href="#18x18_info"></use>\n
# ...

# %%
data=soup.find_all('div',{"class":'biz-listing-large'})

df=pd.DataFrame()
for element in range(len(data)):
    Name=data[element].find('a',{'class': 'biz-name js-analytics-click'}).get_text().strip()
    Phone= data[element].find('span',{'class':'biz-phone'}).get_text().strip()
    Address=data[element].find('address').get_text().strip()
    df=df.append({"Name":Name, "Phone":Phone,"Address":Address},ignore_index=True)
df
# Out:
#                                       Address                          Name  \
# 0         2348 Cascade Rd SWAtlanta, GA 30311          JR Crickets Halftime
# 1       1811 Piedmont Ave NEAtlanta, GA 30324          Fat Matt’s Rib Shack
# 2   782 Ponce De Leon Ave NEAtlanta, GA 30306                        gusto!
# 3   2072 Defoors Ferry Rd NWAtlanta, GA 30318                   Ssam Burger
# 4         500 Amsterdam WalkAtlanta, GA 30306         Sean’s Harvest Market
# 5     4199 Paces Ferry Rd SEAtlanta, GA 30339                         Canoe
# 6        1393 N Highland AveAtlanta, GA 30306                    Casseroles
# 7         968 Memorial Dr SEAtlanta, GA 30316                    Home Grown
# 8             349 14th St NWAtlanta, GA 30318                   Better Half
# 9        209 Edgewood Ave SEAtlanta, GA 30303                     Arepa Mia
# 10    1085 Howell Mill Rd NWAtlanta, GA 30318  Barcelona Westside Ironworks
#
#              Phone
# 0   (404) 330-8874
# ...

# %%
url='https://www.yelp.com/search?find_desc=Restauarnt&find_loc=atlanta&start={}'

df=pd.DataFrame()
for i in range(0,20,10):
    link = url.format(i)
    r=requests.get(link)
    soup=BeautifulSoup(r.content)
    data=soup.find_all('div',{"class":'biz-listing-large'})
    
    for element in range(len(data)):
        Name=data[element].find('a',{'class': 'biz-name js-analytics-click'}).get_text().strip()
        Phone= data[element].find('span',{'class':'biz-phone'}).get_text().strip()
        Address=data[element].find('address').get_text().strip()
        df=df.append({"Name":Name, "Phone":Phone,"Address":Address},ignore_index=True)
df
# Out:
#                                         Address                          Name  \
# 0           2348 Cascade Rd SWAtlanta, GA 30311          JR Crickets Halftime
# 1         1819 Peachtree Rd NEAtlanta, GA 30309             Neighborhood Eats
# 2   225 Peachtree St, Ste B-30Atlanta, GA 30303               Aviva by Kameel
# 3         1935 Peachtree Rd NEAtlanta, GA 30309                        gusto!
# 4          381 Edgewood Ave SEAtlanta, GA 30312                   Cafe + Velo
# 5         1144 Crescent Ave NEAtlanta, GA 30309  South City Kitchen - Midtown
# 6   351 Peachtree Hills Ave NEAtlanta, GA 30305              The Hungry Peach
# 7          510 Piedmont Ave NEAtlanta, GA 30308                 Poor Calvin’s
# 8         2277 Peachtree Rd NEAtlanta, GA 30309               Holeman & Finch
# 9       477 Flat Shoals Ave SEAtlanta, GA 30316            Mai Kind of Brunch
# 10         1468 Mecaslin St NWAtlanta, GA 30309           endive Publik house
# ...

# %%
url='https://www.yelp.com/search?find_desc=restaurants&find_loc={}&start={}'
cities=['oklahoma city','atlanta','new york','miami','nashville','Rex']

df=pd.DataFrame()
for city in cities:
    for i in range(0,20,10):
        link = url.format(city,i)
        r=requests.get(link)
        soup=BeautifulSoup(r.content)
        data=soup.find_all('div',{"class":'biz-listing-large'})
    
        for element in range(len(data)):
            Name=data[element].find('a',{'class': 'biz-name js-analytics-click'}).get_text().strip()
            Phone= data[element].find('span',{'class':'biz-phone'}).get_text().strip()
            Address=data[element].find('address')
            if Address !=None:
                Address2=Address.get_text().strip()
                df=df.append({"Name":Name, "Phone":Phone,"Address":Address2,"city":city},ignore_index=True)
df
# Out:
#                                             Address  \
# 0           6447 Avondale DrOklahoma City, OK 73116
# 1    1201 N Pennsylvania AveOklahoma City, OK 73107
# 2               1901 Nw ExpyOklahoma City, OK 73118
# 3          2409 N Hudson AveOklahoma City, OK 73103
# 4            4011 NW 10th StOklahoma City, OK 73107
# 5         705 W Sheridan AveOklahoma City, OK 73102
# 6            1734 NW 16th StOklahoma City, OK 73106
# 7        3325 N Classen BlvdOklahoma City, OK 73118
# 8     1630 N Blackwelder AveOklahoma City, OK 73106
# 9         324 N Robinson AveOklahoma City, OK 73102
# 10        7300 N Western AveOklahoma City, OK 73116
# 11          6447 Avondale DrOklahoma City, OK 73116
# 12       1845 Northwest ExpyOklahoma City, OK 73118
# 13       2418 N Guernsey AveOklahoma City, OK 73103
# 14           1711 NW 16th StOklahoma City, OK 73106
# 15        705 W Sheridan AveOklahoma City, OK 73102
# 16           1117 N RobinsonOklahoma City, OK 73103
# ...
