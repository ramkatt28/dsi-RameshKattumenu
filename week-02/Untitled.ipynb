# %%
import numpy as np
import scipy as sp
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
one_sample_data = [177.3, 182.7, 169.6, 176.3, 180.3, 179.4, 178.5, 177.2, 176.5]

# %%
one_sample = stats.ttest_1samp(one_sample_data, 175.3)
print("The t-statistic is %.3f and the p-value is %.3f."% one_sample)
# Out:
# The t-statistic is 1.854 and the p-value is 0.101.

# %%
one_sample_data2 = [177.3, 182.7, 169.6, 176.3, 180.3, 179.4, 178.5, 177.2, 176.5,177.5]

# %%
one_sample = stats.ttest_1samp(one_sample_data2, 175.3)
print("The t-statistic is %.3f and the p-value is %.3f."% one_sample)
# Out:
# The t-statistic is 2.070 and the p-value is 0.068.

# %%
one_sample_data3 = [177.3, 182.7, 169.6, 176.3, 180.3, 179.4, 178.5, 177.2, 176.5,177.5,178,178,178
                   ]

# %%
one_sample = stats.ttest_1samp(one_sample_data3, 175.3)
print("The t-statistic is %.3f and the p-value is %.3f."% one_sample)
# Out:
# The t-statistic is 2.851 and the p-value is 0.015.

# %%
sns.distplot(one_sample_data)
plt.show()

# %%
stats.ttest_ind()

# %%
stats.ttest.rel()
