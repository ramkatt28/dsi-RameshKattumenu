# %% [markdown]
# # APIs Lab
# In this lab we will practice using APIs to retrieve and store data.

# %%
# Imports at the top
import json
import urllib
import pandas as pd
import numpy as np
import requests
import json
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1: Get Data From Sheetsu
#
# [Sheetsu](https://sheetsu.com/) is an online service that allows you to access any Google spreadsheet from an API. This can be a very powerful way to share a dataset with colleagues as well as to create a mini centralized data storage, that is simpler to edit than a database.
#
# A Google Spreadsheet with Wine data can be found [here]().
#
# It can be accessed through sheetsu API at this endpoint: https://sheetsu.com/apis/v1.0/dab55afd
#
# Questions:
#
# 1. Use the requests library to access the document. Inspect the response text. What kind of data is it?
# > Answer: it's a JSON string
# - Check the status code of the response object. What code is it?
# > 200
# - Use the appropriate libraries and read functions to read the response into a Pandas Dataframe
# > Possible answers include: pd.read_json and json.loads + pd.Dataframe
# - Once you've imported the data into a dataframe, check the value of the 5th line: what's the price?
# > 6

# %% [markdown]
# ### Exercise 2: Post Data to Sheetsu
# Now that we've learned how to read data, it'd be great if we could also write data. For this we will need to use a _POST_ request.
#
# 1. Use the post command to add the following data to the spreadsheet:

# %%
post_data = {
'Grape' : ''
, 'Name' : 'RameshK'
, 'Color' : 'R'
, 'Country' : 'US'
, 'Region' : 'Sonoma'
, 'Vinyard' : ''
, 'Score' : '10'
, 'Consumed In' : '2015'
, 'Vintage' : '1973'
, 'Price' : '200'
}

# %% [markdown]
# 1. What status did you get? How can you check that you actually added the data correctly?
# - In this exercise, your classmates are adding data to the same spreadsheet. What happens because of this? Is it a problem? How could you mitigate it?

# %%
pd.read_json("https://sheetsu.com/apis/v1.0/a4b517d6852e")
# Out:
#     Color Consumed In   Country  \
# 0       W        2015  Portugal
# 1       W        2015    France
# 2       W        2015    Oregon
# 3       W        2015     Spain
# 4       R        2015        US
# 5       R        2015        US
# 6       R        2015        US
# 7       R        2015    France
# 8       R        2015    France
# 9       R        2015        US
# 10      R        2015     Italy
# 11      R        2015
# 12      R        2015        US
# 13      R        2015     Italy
# 14      W        2013    France
# 15      R        2013        US
# 16      R        2013    France
# 17      R        2013    France
# 18      W        2014        US
# 19      W        2014        US
# 20      R        2014     Italy
# 21      P        2014        US
# 22      W        2014        US
# 23      R        2014    France
# 24      W        2015    France
# 25      W        2015
# 26      W        2015  Portugal
# 27      W        2015    France
# 28      W        2015     Spain
# 29      R        2015        US
# ..    ...         ...       ...
# 283     R        2015        US
# 284     R        2015        US
# 285     R        2015        US
# 286     R        2015        US
# 287     R        2015        US
# 288     R        2015        US
# 289     R        2015        US
# 290     R        2015        US
# 291     R                    FR
# 292     R        2015        US
# 293     R        2015        US
# 294     R        2015        US
# 295     R        2015        US
# 296     R        2015        US
# 297     R        2015        US
# 298     R        2015        US
# 299     R        2015        US
# 300     R        2015        US
# 301     R        2015        US
# 302     R        2015        US
# 303     R        2015        US
# 304     R        2015        US
# 305     R        2015        US
# 306     R        2015        US
# 307     R        2015        US
# 308     R        2015        US
# 309     R        2015        US
# 310     R        2015        US
# 311     R        2015        US
# 312     R        2015        US
#
#                                                  Grape  \
# 0
# 1
# 2
# 3                                            chardonay
# 4                                          chiraz, cab
# 5                                                  cab
# 6
# 7                                          merlot, cab
# 8                                          merlot, cab
# 9                                               merlot
# 10                                          sangiovese
# 11
# 12                                              chiraz
# 13                                          sangiovese
# 14                                     sauvignon blanc
# 15                                          pinot noir
# 16
# 17
# 18                                     sauvignon blanc
# 19                                     sauvignon blanc
# 20
# 21
# 22                                       pinot griogio
# 23
# 24                                  cabernet sauvignon
# 25                                     sauvignon blanc
# 26
# 27   Chablis, Vincent Dampt, Vaillons 1er (Burgundy...
# 28              Albarino, Granbazan (Rias Baixas) 2012
# 29
# ..                                                 ...
# 283
# 284
# 285
# 286
# 287
# 288
# 289                                                EMS
# 290
# 291                                         Pinot Noir
# 292
# 293
# 294                                            Chablis
# 295                                                EMS
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
#
#                                  Name  Price       Region Score Vintage  \
# 0                                                Portugal     4    2013
# 1                                       17.8       France     3    2013
# 2                                         20       Oregon     3    2013
# 3                                          7        Spain   2.5    2012
# 4                        Spice Trader      6                  3    2012
# 5                                         13   California   3.5    2012
# 6                                 #14     21       Oregon   2.5    2013
# 7                                         12     Bordeaux   3.5    2012
# 8                                      11.99        Medoc   3.5    2011
# 9                                         13   Washington     4    2011
# 10                    Rosso Dei Poggi     12      Tuscany     3    2012
# 11            Montepulciano D'Abruzzo     22      Tuscany   4.5    2013
# 12                                         7       Oregon   3.5    2010
# 13                Rosso Di Montalcino     15      Tuscany   3.5    2012
# 14   Sancerre Cuvee Des Moulins Bales     12        Loire     3    2012
# 15                             Meiomi     13         Napa     3    2012
# 16             Saint Drezery Prestige     13       France     3    2012
# 17             Saint Drezery Prestige     14       France     2    2011
# 18                    Sauvignon Blanc   14.5        Nappa     4    2012
# 19               Uppercut North Coast     11        Nappa     3    2012
# 20                       Nero d'Avola              Sicily          2011
# 21                         Cape Blush     10        Truro     4    2013
# 22                       Pinot Grigio     10        Truro     3    2013
# 23                         Cru Classe            Provence   3.5    2013
# 24                Domaine du Claouset            Bordeaux     3    2013
# 25                    Sauvignon Blanc                Napa   3.5    2012
# 26                        Vinho Verde            Portugal   3.5    2013
# 27                      Vincent Dampt     35     Burgundy     4    2012
# 28                           Albarino     15  Rias Baixas     4    2012
# 29                  My wonderful wine    200       Sonoma    10    1973
# ..                                ...    ...          ...   ...     ...
# 283                 My wonderful wine    200       Sonoma    10    1973
# 284                 My wonderful wine    200       Sonoma    10    1973
# 285                 My wonderful wine    200       Sonoma    10    1973
# 286                 My wonderful wine    200       Sonoma    10    1973
# 287          My wonderful wine - Juan    200       Sonoma    10    1973
# 288                 My wonderful wine    200       Sonoma    10    1973
# 289         My wonderful wine_EMS_EMS    200       Sonoma    10    1973
# 290                 My wonderful wine    200       Sonoma    10    1973
# 291                   Chateau Gregory   2000       Vosges    10    1978
# 292                 My wonderful wine    200       Sonoma    10    1973
# 293                 My wonderful wine    200       Sonoma    10    1973
# 294                 Expensive Chablis    200       Sonoma    10    1973
# 295         My wonderful wine_EMS_EMS    200       Sonoma    10    1973
# 296                 My wonderful wine    200       Sonoma    10    1973
# 297                 My wonderful wine    200       Sonoma    10    1973
# 298                 My wonderful wine    200       Sonoma    10    1973
# 299                 My wonderful wine    200       Sonoma    10    1973
# 300                 My wonderful wine    200       Sonoma    10    1973
# 301                 My wonderful wine    200       Sonoma    10    1973
# 302                 My wonderful wine    200       Sonoma    10    1973
# 303                 My wonderful wine    200       Sonoma    10    1973
# 304                 My wonderful wine    200       Sonoma    10    1973
# 305                 My wonderful wine    200       Sonoma    10    1973
# 306                 My wonderful wine    200       Sonoma    10    1973
# 307                 My wonderful wine    200       Sonoma    10    1973
# 308                 My wonderful wine    200       Sonoma    10    1973
# 309                 My wonderful wine    200       Sonoma    10    1973
# 310                 My wonderful wine    200       Sonoma    10    1973
# 311                           RameshK    200       Sonoma    10    1973
# 312                           RameshK    200       Sonoma    10    1973
#
#                     Vinyard
# 0               Vinho Verde
# 1                 Peyruchet
# 2                   Abacela
# 3                     Ochoa
# 4                 Heartland
# 5               Crow Canyon
# 6                   Abacela
# 7            David Beaulieu
# 8               Chantemerle
# 9                     Hyatt
# 10          Rosso Dei Poggi
# 11                Orizzonti
# 12                  Abacelo
# 13                  Ridolfi
# 14        Celestin Blobdeau
# 15               Belle Glos
# 16               Puech-Haut
# 17               Puech-Haut
# 18                    Honig
# 19               Provenance
# 20       Baglio Di Pianetto
# 21          Truro Vineyards
# 22          Truro Vineyards
# 23   Chateau de la Clapiere
# 24      Domaine du Claouset
# 25               Two Angels
# 26                  Mapreco
# 27                 Vaillons
# 28                Granbazan
# 29
# ..                      ...
# 283
# 284
# 285
# 286
# 287
# 288
# 289                     EMS
# 290
# 291                   Perso
# 292
# 293
# 294
# 295                     EMS
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
#
# [313 rows x 10 columns]

# %%
requests.post("https://sheetsu.com/apis/v1.0/a4b517d6852e",json=post_data)
# Out:
# <Response [201]>

# %% [markdown]
# ## Exercise 3: Data munging
#
# Get back to the dataframe you've created in the beginning. Let's do some data munging:
#
# 1. Search for missing data
#     - Is there any missing data? How do you deal with it?
#     - Is there any data you can just remove?
#     - Are the data types appropriate?
# - Summarize the data
#     - Try using describe, min, max, mean, var

# %%
data = pd.read_json("https://sheetsu.com/apis/v1.0/a4b517d6852e")

# %%
data
# Out:
#     Color Consumed In   Country  \
# 0       W        2015  Portugal
# 1       W        2015    France
# 2       W        2015    Oregon
# 3       W        2015     Spain
# 4       R        2015        US
# 5       R        2015        US
# 6       R        2015        US
# 7       R        2015    France
# 8       R        2015    France
# 9       R        2015        US
# 10      R        2015     Italy
# 11      R        2015
# 12      R        2015        US
# 13      R        2015     Italy
# 14      W        2013    France
# 15      R        2013        US
# 16      R        2013    France
# 17      R        2013    France
# 18      W        2014        US
# 19      W        2014        US
# 20      R        2014     Italy
# 21      P        2014        US
# 22      W        2014        US
# 23      R        2014    France
# 24      W        2015    France
# 25      W        2015
# 26      W        2015  Portugal
# 27      W        2015    France
# 28      W        2015     Spain
# 29      R        2015        US
# ..    ...         ...       ...
# 284     R        2015        US
# 285     R        2015        US
# 286     R        2015        US
# 287     R        2015        US
# 288     R        2015        US
# 289     R        2015        US
# 290     R        2015        US
# 291     R                    FR
# 292     R        2015        US
# 293     R        2015        US
# 294     R        2015        US
# 295     R        2015        US
# 296     R        2015        US
# 297     R        2015        US
# 298     R        2015        US
# 299     R        2015        US
# 300     R        2015        US
# 301     R        2015        US
# 302     R        2015        US
# 303     R        2015        US
# 304     R        2015        US
# 305     R        2015        US
# 306     R        2015        US
# 307     R        2015        US
# 308     R        2015        US
# 309     R        2015        US
# 310     R        2015        US
# 311     R        2015        US
# 312     R        2015        US
# 313     R        2015        US
#
#                                                  Grape  \
# 0
# 1
# 2
# 3                                            chardonay
# 4                                          chiraz, cab
# 5                                                  cab
# 6
# 7                                          merlot, cab
# 8                                          merlot, cab
# 9                                               merlot
# 10                                          sangiovese
# 11
# 12                                              chiraz
# 13                                          sangiovese
# 14                                     sauvignon blanc
# 15                                          pinot noir
# 16
# 17
# 18                                     sauvignon blanc
# 19                                     sauvignon blanc
# 20
# 21
# 22                                       pinot griogio
# 23
# 24                                  cabernet sauvignon
# 25                                     sauvignon blanc
# 26
# 27   Chablis, Vincent Dampt, Vaillons 1er (Burgundy...
# 28              Albarino, Granbazan (Rias Baixas) 2012
# 29
# ..                                                 ...
# 284
# 285
# 286
# 287
# 288
# 289                                                EMS
# 290
# 291                                         Pinot Noir
# 292
# 293
# 294                                            Chablis
# 295                                                EMS
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
#
#                                  Name  Price       Region Score Vintage  \
# 0                                                Portugal     4    2013
# 1                                       17.8       France     3    2013
# 2                                         20       Oregon     3    2013
# 3                                          7        Spain   2.5    2012
# 4                        Spice Trader      6                  3    2012
# 5                                         13   California   3.5    2012
# 6                                 #14     21       Oregon   2.5    2013
# 7                                         12     Bordeaux   3.5    2012
# 8                                      11.99        Medoc   3.5    2011
# 9                                         13   Washington     4    2011
# 10                    Rosso Dei Poggi     12      Tuscany     3    2012
# 11            Montepulciano D'Abruzzo     22      Tuscany   4.5    2013
# 12                                         7       Oregon   3.5    2010
# 13                Rosso Di Montalcino     15      Tuscany   3.5    2012
# 14   Sancerre Cuvee Des Moulins Bales     12        Loire     3    2012
# 15                             Meiomi     13         Napa     3    2012
# 16             Saint Drezery Prestige     13       France     3    2012
# 17             Saint Drezery Prestige     14       France     2    2011
# 18                    Sauvignon Blanc   14.5        Nappa     4    2012
# 19               Uppercut North Coast     11        Nappa     3    2012
# 20                       Nero d'Avola              Sicily          2011
# 21                         Cape Blush     10        Truro     4    2013
# 22                       Pinot Grigio     10        Truro     3    2013
# 23                         Cru Classe            Provence   3.5    2013
# 24                Domaine du Claouset            Bordeaux     3    2013
# 25                    Sauvignon Blanc                Napa   3.5    2012
# 26                        Vinho Verde            Portugal   3.5    2013
# 27                      Vincent Dampt     35     Burgundy     4    2012
# 28                           Albarino     15  Rias Baixas     4    2012
# 29                  My wonderful wine    200       Sonoma    10    1973
# ..                                ...    ...          ...   ...     ...
# 284                 My wonderful wine    200       Sonoma    10    1973
# 285                 My wonderful wine    200       Sonoma    10    1973
# 286                 My wonderful wine    200       Sonoma    10    1973
# 287          My wonderful wine - Juan    200       Sonoma    10    1973
# 288                 My wonderful wine    200       Sonoma    10    1973
# 289         My wonderful wine_EMS_EMS    200       Sonoma    10    1973
# 290                 My wonderful wine    200       Sonoma    10    1973
# 291                   Chateau Gregory   2000       Vosges    10    1978
# 292                 My wonderful wine    200       Sonoma    10    1973
# 293                 My wonderful wine    200       Sonoma    10    1973
# 294                 Expensive Chablis    200       Sonoma    10    1973
# 295         My wonderful wine_EMS_EMS    200       Sonoma    10    1973
# 296                 My wonderful wine    200       Sonoma    10    1973
# 297                 My wonderful wine    200       Sonoma    10    1973
# 298                 My wonderful wine    200       Sonoma    10    1973
# 299                 My wonderful wine    200       Sonoma    10    1973
# 300                 My wonderful wine    200       Sonoma    10    1973
# 301                 My wonderful wine    200       Sonoma    10    1973
# 302                 My wonderful wine    200       Sonoma    10    1973
# 303                 My wonderful wine    200       Sonoma    10    1973
# 304                 My wonderful wine    200       Sonoma    10    1973
# 305                 My wonderful wine    200       Sonoma    10    1973
# 306                 My wonderful wine    200       Sonoma    10    1973
# 307                 My wonderful wine    200       Sonoma    10    1973
# 308                 My wonderful wine    200       Sonoma    10    1973
# 309                 My wonderful wine    200       Sonoma    10    1973
# 310                 My wonderful wine    200       Sonoma    10    1973
# 311                           RameshK    200       Sonoma    10    1973
# 312                           RameshK    200       Sonoma    10    1973
# 313                           RameshK    200       Sonoma    10    1973
#
#                     Vinyard
# 0               Vinho Verde
# 1                 Peyruchet
# 2                   Abacela
# 3                     Ochoa
# 4                 Heartland
# 5               Crow Canyon
# 6                   Abacela
# 7            David Beaulieu
# 8               Chantemerle
# 9                     Hyatt
# 10          Rosso Dei Poggi
# 11                Orizzonti
# 12                  Abacelo
# 13                  Ridolfi
# 14        Celestin Blobdeau
# 15               Belle Glos
# 16               Puech-Haut
# 17               Puech-Haut
# 18                    Honig
# 19               Provenance
# 20       Baglio Di Pianetto
# 21          Truro Vineyards
# 22          Truro Vineyards
# 23   Chateau de la Clapiere
# 24      Domaine du Claouset
# 25               Two Angels
# 26                  Mapreco
# 27                 Vaillons
# 28                Granbazan
# 29
# ..                      ...
# 284
# 285
# 286
# 287
# 288
# 289                     EMS
# 290
# 291                   Perso
# 292
# 293
# 294
# 295                     EMS
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
#
# [314 rows x 10 columns]

# %%
data.isnull().any()
# Out:
# Color          False
# Consumed In    False
# Country        False
# Grape          False
# Name           False
# Price          False
# Region         False
# Score          False
# Vintage        False
# Vinyard        False
# dtype: bool

# %%
data.replace("",np.nan,inplace=True)
data.head()
# Out:
#   Color Consumed In   Country        Grape          Name Price    Region  \
# 0     W        2015  Portugal          NaN           NaN   NaN  Portugal
# 1     W        2015    France          NaN           NaN  17.8    France
# 2     W        2015    Oregon          NaN           NaN    20    Oregon
# 3     W        2015     Spain    chardonay           NaN     7     Spain
# 4     R        2015        US  chiraz, cab  Spice Trader     6       NaN
#
#   Score Vintage      Vinyard
# 0     4    2013  Vinho Verde
# 1     3    2013    Peyruchet
# 2     3    2013      Abacela
# 3   2.5    2012        Ochoa
# 4     3    2012    Heartland

# %%
data = data.drop_duplicates()
len(data)
# Out:
# 81

# %%
data.dtypes
# Out:
# Color          object
# Consumed In    object
# Country        object
# Grape          object
# Name           object
# Price          object
# Region         object
# Score          object
# Vintage        object
# Vinyard        object
# dtype: object

# %%
data['Score'] = pd.to_numeric(data["Score"],errors='coerce')
data['Price'] = pd.to_numeric(data["Price"],errors='coerce')
data
#data[["Score","Price"]]=data[["Score","Price"]].astype(float)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#     Color Consumed In   Country  \
# 0       W        2015  Portugal
# 1       W        2015    France
# 2       W        2015    Oregon
# 3       W        2015     Spain
# 4       R        2015        US
# 5       R        2015        US
# 6       R        2015        US
# 7       R        2015    France
# 8       R        2015    France
# 9       R        2015        US
# 10      R        2015     Italy
# 11      R        2015       NaN
# 12      R        2015        US
# 13      R        2015     Italy
# 14      W        2013    France
# 15      R        2013        US
# 16      R        2013    France
# 17      R        2013    France
# 18      W        2014        US
# 19      W        2014        US
# 20      R        2014     Italy
# 21      P        2014        US
# 22      W        2014        US
# 23      R        2014    France
# 24      W        2015    France
# 25      W        2015       NaN
# 26      W        2015  Portugal
# 27      W        2015    France
# 28      W        2015     Spain
# 29      R        2015        US
# ..    ...         ...       ...
# 91      R          15       666
# 92      R        2015        US
# 103     R        2015        US
# 106     R        2015        US
# 132     R        2015        US
# 145     R        2015        US
# 149     R        2015        US
# 152     R        2015        US
# 153     R       32910        US
# 155     R       32910        US
# 156     R        2017        US
# 161     R        2015        US
# 163     R        2015        US
# 174     R        2015  Ethiopia
# 175     R        2015    MEXICO
# 181     R        2015        US
# 186     R    My mouth        US
# 228     R        2022        US
# 232     B        2005        SE
# 266  Ruby        2015   Ireland
# 271     R        2015     India
# 276     R        2015        US
# 277     R        2015        US
# 279     R        2015        NL
# 281     R        2015        PT
# 287     R        2015        US
# 289     R        2015        US
# 291     R         NaN        FR
# 294     R        2015        US
# 311     R        2015        US
#
#                                                  Grape  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                            chardonay
# 4                                          chiraz, cab
# 5                                                  cab
# 6                                                  NaN
# 7                                          merlot, cab
# 8                                          merlot, cab
# 9                                               merlot
# 10                                          sangiovese
# 11                                                 NaN
# 12                                              chiraz
# 13                                          sangiovese
# 14                                     sauvignon blanc
# 15                                          pinot noir
# 16                                                 NaN
# 17                                                 NaN
# 18                                     sauvignon blanc
# 19                                     sauvignon blanc
# 20                                                 NaN
# 21                                                 NaN
# 22                                       pinot griogio
# 23                                                 NaN
# 24                                  cabernet sauvignon
# 25                                     sauvignon blanc
# 26                                                 NaN
# 27   Chablis, Vincent Dampt, Vaillons 1er (Burgundy...
# 28              Albarino, Granbazan (Rias Baixas) 2012
# 29                                                 NaN
# ..                                                 ...
# 91                                              GR8Pe!
# 92                                                 NaN
# 103                                                NaN
# 106                                                NaN
# 132                                                NaN
# 145                                                NaN
# 149                                                NaN
# 152                                                NaN
# 153                                                NaN
# 155                                                NaN
# 156                                                NaN
# 161                   Lenny's specific grape wine 1607
# 163                                                NaN
# 174                                                NaN
# 175                                                NaN
# 181                                                NaN
# 186                                                NaN
# 228                                                NaN
# 232                                                NaN
# 266                                                NaN
# 271                                                NaN
# 276                                                NaN
# 277                                               Jaye
# 279                                                NaN
# 281                                                NaN
# 287                                                NaN
# 289                                                EMS
# 291                                         Pinot Noir
# 294                                            Chablis
# 311                                                NaN
#
#                                  Name         Price       Region    Score  \
# 0                                 NaN           NaN     Portugal      4.0
# 1                                 NaN  1.780000e+01       France      3.0
# 2                                 NaN  2.000000e+01       Oregon      3.0
# 3                                 NaN  7.000000e+00        Spain      2.5
# 4                        Spice Trader  6.000000e+00          NaN      3.0
# 5                                 NaN  1.300000e+01   California      3.5
# 6                                 #14  2.100000e+01       Oregon      2.5
# 7                                 NaN  1.200000e+01     Bordeaux      3.5
# 8                                 NaN  1.199000e+01        Medoc      3.5
# 9                                 NaN  1.300000e+01   Washington      4.0
# 10                    Rosso Dei Poggi  1.200000e+01      Tuscany      3.0
# 11            Montepulciano D'Abruzzo  2.200000e+01      Tuscany      4.5
# 12                                NaN  7.000000e+00       Oregon      3.5
# 13                Rosso Di Montalcino  1.500000e+01      Tuscany      3.5
# 14   Sancerre Cuvee Des Moulins Bales  1.200000e+01        Loire      3.0
# 15                             Meiomi  1.300000e+01         Napa      3.0
# 16             Saint Drezery Prestige  1.300000e+01       France      3.0
# 17             Saint Drezery Prestige  1.400000e+01       France      2.0
# 18                    Sauvignon Blanc  1.450000e+01        Nappa      4.0
# 19               Uppercut North Coast  1.100000e+01        Nappa      3.0
# 20                       Nero d'Avola           NaN       Sicily      NaN
# 21                         Cape Blush  1.000000e+01        Truro      4.0
# 22                       Pinot Grigio  1.000000e+01        Truro      3.0
# 23                         Cru Classe           NaN     Provence      3.5
# 24                Domaine du Claouset           NaN     Bordeaux      3.0
# 25                    Sauvignon Blanc           NaN         Napa      3.5
# 26                        Vinho Verde           NaN     Portugal      3.5
# 27                      Vincent Dampt  3.500000e+01     Burgundy      4.0
# 28                           Albarino  1.500000e+01  Rias Baixas      4.0
# 29                  My wonderful wine  2.000000e+02       Sonoma     10.0
# ..                                ...           ...          ...      ...
# 91                $$ _ 5 seven ! _ $$           NaN  i like soup    112.0
# 92                            Beyhtar  2.000000e+02       Sonoma     10.0
# 103             Howies wonderful wine  2.000000e+02       Sonoma     10.0
# 106                 CK wonderful wine  2.000000e+02       Sonoma     10.0
# 132                My wonderful wine1  2.000000e+02       Sonoma     10.0
# 145                 My wonderful wine  2.000000e+04       Sonoma     10.0
# 149                     My wonderfine  2.000000e+02       Sonoma     10.0
# 152                       Blue Grapes  2.000000e+02       Sonoma     10.0
# 153                 My wonderful wine  1.000000e+19       Sonoma  10000.0
# 155                        BEAST MODE  1.000000e+19    HULKMANIA  10000.0
# 156                        BEAST MODE  1.000000e+05    HULKMANIA     10.0
# 161                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 163                      Purple Drank  2.000000e+02       Sonoma     10.0
# 174                My wonderful wine   2.000000e+02       Sonoma     10.0
# 175                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 181                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 186                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 228         My wonderful wine - kelly  2.000000e+02       Sonoma     10.0
# 232  some other not so wonderful wine  2.220000e+02    Stockholm     10.0
# 266                 My vonderful wine  2.000000e+02     Up North    100.0
# 271              My wonderful wine_rn  2.000000e+02       Sonoma     10.0
# 276                           My joke  3.141590e+00       Sonoma     42.0
# 277                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 279                           Vincent  2.000000e+02      Utrecht      NaN
# 281          AAAAAAAAAAAAAAAAAAAAAAAA  2.000000e+02           PT     10.0
# 287          My wonderful wine - Juan  2.000000e+02       Sonoma     10.0
# 289         My wonderful wine_EMS_EMS  2.000000e+02       Sonoma     10.0
# 291                   Chateau Gregory  2.000000e+03       Vosges     10.0
# 294                 Expensive Chablis  2.000000e+02       Sonoma     10.0
# 311                           RameshK  2.000000e+02       Sonoma     10.0
#
#          Vintage                 Vinyard
# 0           2013             Vinho Verde
# 1           2013               Peyruchet
# 2           2013                 Abacela
# 3           2012                   Ochoa
# 4           2012               Heartland
# 5           2012             Crow Canyon
# 6           2013                 Abacela
# 7           2012          David Beaulieu
# 8           2011             Chantemerle
# 9           2011                   Hyatt
# 10          2012         Rosso Dei Poggi
# 11          2013               Orizzonti
# 12          2010                 Abacelo
# 13          2012                 Ridolfi
# 14          2012       Celestin Blobdeau
# 15          2012              Belle Glos
# 16          2012              Puech-Haut
# 17          2011              Puech-Haut
# 18          2012                   Honig
# 19          2012              Provenance
# 20          2011      Baglio Di Pianetto
# 21          2013         Truro Vineyards
# 22          2013         Truro Vineyards
# 23          2013  Chateau de la Clapiere
# 24          2013     Domaine du Claouset
# 25          2012              Two Angels
# 26          2013                 Mapreco
# 27          2012                Vaillons
# 28          2012               Granbazan
# 29          1973                     NaN
# ..           ...                     ...
# 91   not an int!       THE BEST CHICKENS
# 92          1973                     NaN
# 103         1973                     NaN
# 106         1973                     NaN
# 132         1973                     NaN
# 145         1973                     NaN
# 149         1973                     NaN
# 152         1973                     NaN
# 153      2420410                     NaN
# 155      2420410                     NaN
# 156         1900                     NaN
# 161         1973                     NaN
# 163         1973                     NaN
# 174         1973                     NaN
# 175         1973                     NaN
# 181         1973         Playboy Mansion
# 186         1973                     NaN
# 228         1973                     NaN
# 232         1973                     NYB
# 266         1973                     NaN
# 271         1973                     NaN
# 276         1973                     NaN
# 277         1973                     NaN
# 279         1993                     NaN
# 281         1973                     NaN
# 287         1973                     NaN
# 289         1973                     EMS
# 291         1978                   Perso
# 294         1973                     NaN
# 311         1973                     NaN
#
# [81 rows x 10 columns]

# %%
data =data[~data['Score'].isnull()]
data
# Out:
#     Color Consumed In   Country  \
# 0       W        2015  Portugal
# 1       W        2015    France
# 2       W        2015    Oregon
# 3       W        2015     Spain
# 4       R        2015        US
# 5       R        2015        US
# 6       R        2015        US
# 7       R        2015    France
# 8       R        2015    France
# 9       R        2015        US
# 10      R        2015     Italy
# 11      R        2015       NaN
# 12      R        2015        US
# 13      R        2015     Italy
# 14      W        2013    France
# 15      R        2013        US
# 16      R        2013    France
# 17      R        2013    France
# 18      W        2014        US
# 19      W        2014        US
# 21      P        2014        US
# 22      W        2014        US
# 23      R        2014    France
# 24      W        2015    France
# 25      W        2015       NaN
# 26      W        2015  Portugal
# 27      W        2015    France
# 28      W        2015     Spain
# 29      R        2015        US
# 31      R        2015        US
# ..    ...         ...       ...
# 85      R        2015        US
# 91      R          15       666
# 92      R        2015        US
# 103     R        2015        US
# 106     R        2015        US
# 132     R        2015        US
# 145     R        2015        US
# 149     R        2015        US
# 152     R        2015        US
# 153     R       32910        US
# 155     R       32910        US
# 156     R        2017        US
# 161     R        2015        US
# 163     R        2015        US
# 174     R        2015  Ethiopia
# 175     R        2015    MEXICO
# 181     R        2015        US
# 186     R    My mouth        US
# 228     R        2022        US
# 232     B        2005        SE
# 266  Ruby        2015   Ireland
# 271     R        2015     India
# 276     R        2015        US
# 277     R        2015        US
# 281     R        2015        PT
# 287     R        2015        US
# 289     R        2015        US
# 291     R         NaN        FR
# 294     R        2015        US
# 311     R        2015        US
#
#                                                  Grape  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                            chardonay
# 4                                          chiraz, cab
# 5                                                  cab
# 6                                                  NaN
# 7                                          merlot, cab
# 8                                          merlot, cab
# 9                                               merlot
# 10                                          sangiovese
# 11                                                 NaN
# 12                                              chiraz
# 13                                          sangiovese
# 14                                     sauvignon blanc
# 15                                          pinot noir
# 16                                                 NaN
# 17                                                 NaN
# 18                                     sauvignon blanc
# 19                                     sauvignon blanc
# 21                                                 NaN
# 22                                       pinot griogio
# 23                                                 NaN
# 24                                  cabernet sauvignon
# 25                                     sauvignon blanc
# 26                                                 NaN
# 27   Chablis, Vincent Dampt, Vaillons 1er (Burgundy...
# 28              Albarino, Granbazan (Rias Baixas) 2012
# 29                                                 NaN
# 31                                                 BIG
# ..                                                 ...
# 85                                                 NaN
# 91                                              GR8Pe!
# 92                                                 NaN
# 103                                                NaN
# 106                                                NaN
# 132                                                NaN
# 145                                                NaN
# 149                                                NaN
# 152                                                NaN
# 153                                                NaN
# 155                                                NaN
# 156                                                NaN
# 161                   Lenny's specific grape wine 1607
# 163                                                NaN
# 174                                                NaN
# 175                                                NaN
# 181                                                NaN
# 186                                                NaN
# 228                                                NaN
# 232                                                NaN
# 266                                                NaN
# 271                                                NaN
# 276                                                NaN
# 277                                               Jaye
# 281                                                NaN
# 287                                                NaN
# 289                                                EMS
# 291                                         Pinot Noir
# 294                                            Chablis
# 311                                                NaN
#
#                                  Name         Price       Region    Score  \
# 0                                 NaN           NaN     Portugal      4.0
# 1                                 NaN  1.780000e+01       France      3.0
# 2                                 NaN  2.000000e+01       Oregon      3.0
# 3                                 NaN  7.000000e+00        Spain      2.5
# 4                        Spice Trader  6.000000e+00          NaN      3.0
# 5                                 NaN  1.300000e+01   California      3.5
# 6                                 #14  2.100000e+01       Oregon      2.5
# 7                                 NaN  1.200000e+01     Bordeaux      3.5
# 8                                 NaN  1.199000e+01        Medoc      3.5
# 9                                 NaN  1.300000e+01   Washington      4.0
# 10                    Rosso Dei Poggi  1.200000e+01      Tuscany      3.0
# 11            Montepulciano D'Abruzzo  2.200000e+01      Tuscany      4.5
# 12                                NaN  7.000000e+00       Oregon      3.5
# 13                Rosso Di Montalcino  1.500000e+01      Tuscany      3.5
# 14   Sancerre Cuvee Des Moulins Bales  1.200000e+01        Loire      3.0
# 15                             Meiomi  1.300000e+01         Napa      3.0
# 16             Saint Drezery Prestige  1.300000e+01       France      3.0
# 17             Saint Drezery Prestige  1.400000e+01       France      2.0
# 18                    Sauvignon Blanc  1.450000e+01        Nappa      4.0
# 19               Uppercut North Coast  1.100000e+01        Nappa      3.0
# 21                         Cape Blush  1.000000e+01        Truro      4.0
# 22                       Pinot Grigio  1.000000e+01        Truro      3.0
# 23                         Cru Classe           NaN     Provence      3.5
# 24                Domaine du Claouset           NaN     Bordeaux      3.0
# 25                    Sauvignon Blanc           NaN         Napa      3.5
# 26                        Vinho Verde           NaN     Portugal      3.5
# 27                      Vincent Dampt  3.500000e+01     Burgundy      4.0
# 28                           Albarino  1.500000e+01  Rias Baixas      4.0
# 29                  My wonderful wine  2.000000e+02       Sonoma     10.0
# 31                  My wonderful wine  9.999000e+03       Sonoma     10.0
# ..                                ...           ...          ...      ...
# 85                   christine's wine  2.000000e+02       Sonoma     10.0
# 91                $$ _ 5 seven ! _ $$           NaN  i like soup    112.0
# 92                            Beyhtar  2.000000e+02       Sonoma     10.0
# 103             Howies wonderful wine  2.000000e+02       Sonoma     10.0
# 106                 CK wonderful wine  2.000000e+02       Sonoma     10.0
# 132                My wonderful wine1  2.000000e+02       Sonoma     10.0
# 145                 My wonderful wine  2.000000e+04       Sonoma     10.0
# 149                     My wonderfine  2.000000e+02       Sonoma     10.0
# 152                       Blue Grapes  2.000000e+02       Sonoma     10.0
# 153                 My wonderful wine  1.000000e+19       Sonoma  10000.0
# 155                        BEAST MODE  1.000000e+19    HULKMANIA  10000.0
# 156                        BEAST MODE  1.000000e+05    HULKMANIA     10.0
# 161                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 163                      Purple Drank  2.000000e+02       Sonoma     10.0
# 174                My wonderful wine   2.000000e+02       Sonoma     10.0
# 175                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 181                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 186                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 228         My wonderful wine - kelly  2.000000e+02       Sonoma     10.0
# 232  some other not so wonderful wine  2.220000e+02    Stockholm     10.0
# 266                 My vonderful wine  2.000000e+02     Up North    100.0
# 271              My wonderful wine_rn  2.000000e+02       Sonoma     10.0
# 276                           My joke  3.141590e+00       Sonoma     42.0
# 277                 My wonderful wine  2.000000e+02       Sonoma     10.0
# 281          AAAAAAAAAAAAAAAAAAAAAAAA  2.000000e+02           PT     10.0
# 287          My wonderful wine - Juan  2.000000e+02       Sonoma     10.0
# 289         My wonderful wine_EMS_EMS  2.000000e+02       Sonoma     10.0
# 291                   Chateau Gregory  2.000000e+03       Vosges     10.0
# 294                 Expensive Chablis  2.000000e+02       Sonoma     10.0
# 311                           RameshK  2.000000e+02       Sonoma     10.0
#
#          Vintage                 Vinyard
# 0           2013             Vinho Verde
# 1           2013               Peyruchet
# 2           2013                 Abacela
# 3           2012                   Ochoa
# 4           2012               Heartland
# 5           2012             Crow Canyon
# 6           2013                 Abacela
# 7           2012          David Beaulieu
# 8           2011             Chantemerle
# 9           2011                   Hyatt
# 10          2012         Rosso Dei Poggi
# 11          2013               Orizzonti
# 12          2010                 Abacelo
# 13          2012                 Ridolfi
# 14          2012       Celestin Blobdeau
# 15          2012              Belle Glos
# 16          2012              Puech-Haut
# 17          2011              Puech-Haut
# 18          2012                   Honig
# 19          2012              Provenance
# 21          2013         Truro Vineyards
# 22          2013         Truro Vineyards
# 23          2013  Chateau de la Clapiere
# 24          2013     Domaine du Claouset
# 25          2012              Two Angels
# 26          2013                 Mapreco
# 27          2012                Vaillons
# 28          2012               Granbazan
# 29          1973                     NaN
# 31          1973                     NaN
# ..           ...                     ...
# 85          1973                     NaN
# 91   not an int!       THE BEST CHICKENS
# 92          1973                     NaN
# 103         1973                     NaN
# 106         1973                     NaN
# 132         1973                     NaN
# 145         1973                     NaN
# 149         1973                     NaN
# 152         1973                     NaN
# 153      2420410                     NaN
# 155      2420410                     NaN
# 156         1900                     NaN
# 161         1973                     NaN
# 163         1973                     NaN
# 174         1973                     NaN
# 175         1973                     NaN
# 181         1973         Playboy Mansion
# 186         1973                     NaN
# 228         1973                     NaN
# 232         1973                     NYB
# 266         1973                     NaN
# 271         1973                     NaN
# 276         1973                     NaN
# 277         1973                     NaN
# 281         1973                     NaN
# 287         1973                     NaN
# 289         1973                     EMS
# 291         1978                   Perso
# 294         1973                     NaN
# 311         1973                     NaN
#
# [78 rows x 10 columns]

# %%
data.dtypes
# Out:
# Color           object
# Consumed In     object
# Country         object
# Grape           object
# Name            object
# Price          float64
# Region          object
# Score          float64
# Vintage         object
# Vinyard         object
# dtype: object

# %%
data=data[data['Score']<=10]
data
# Out:
#           Color Consumed In   Country  \
# 0             W        2015  Portugal
# 1             W        2015    France
# 2             W        2015    Oregon
# 3             W        2015     Spain
# 4             R        2015        US
# 5             R        2015        US
# 6             R        2015        US
# 7             R        2015    France
# 8             R        2015    France
# 9             R        2015        US
# 10            R        2015     Italy
# 11            R        2015       NaN
# 12            R        2015        US
# 13            R        2015     Italy
# 14            W        2013    France
# 15            R        2013        US
# 16            R        2013    France
# 17            R        2013    France
# 18            W        2014        US
# 19            W        2014        US
# 21            P        2014        US
# 22            W        2014        US
# 23            R        2014    France
# 24            W        2015    France
# 25            W        2015       NaN
# 26            W        2015  Portugal
# 27            W        2015    France
# 28            W        2015     Spain
# 29            R        2015        US
# 31            R        2015        US
# ..          ...         ...       ...
# 74            R        2015        US
# 77            W        2015        US
# 79            W        2015        US
# 80   Robin Hood        2015        US
# 81            R        2015        US
# 85            R        2015        US
# 92            R        2015        US
# 103           R        2015        US
# 106           R        2015        US
# 132           R        2015        US
# 145           R        2015        US
# 149           R        2015        US
# 152           R        2015        US
# 156           R        2017        US
# 161           R        2015        US
# 163           R        2015        US
# 174           R        2015  Ethiopia
# 175           R        2015    MEXICO
# 181           R        2015        US
# 186           R    My mouth        US
# 228           R        2022        US
# 232           B        2005        SE
# 271           R        2015     India
# 277           R        2015        US
# 281           R        2015        PT
# 287           R        2015        US
# 289           R        2015        US
# 291           R         NaN        FR
# 294           R        2015        US
# 311           R        2015        US
#
#                                                  Grape  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                            chardonay
# 4                                          chiraz, cab
# 5                                                  cab
# 6                                                  NaN
# 7                                          merlot, cab
# 8                                          merlot, cab
# 9                                               merlot
# 10                                          sangiovese
# 11                                                 NaN
# 12                                              chiraz
# 13                                          sangiovese
# 14                                     sauvignon blanc
# 15                                          pinot noir
# 16                                                 NaN
# 17                                                 NaN
# 18                                     sauvignon blanc
# 19                                     sauvignon blanc
# 21                                                 NaN
# 22                                       pinot griogio
# 23                                                 NaN
# 24                                  cabernet sauvignon
# 25                                     sauvignon blanc
# 26                                                 NaN
# 27   Chablis, Vincent Dampt, Vaillons 1er (Burgundy...
# 28              Albarino, Granbazan (Rias Baixas) 2012
# 29                                                 NaN
# 31                                                 BIG
# ..                                                 ...
# 74                                                 NaN
# 77                                                 NaN
# 79                                                 NaN
# 80                                                 NaN
# 81                                                 NaN
# 85                                                 NaN
# 92                                                 NaN
# 103                                                NaN
# 106                                                NaN
# 132                                                NaN
# 145                                                NaN
# 149                                                NaN
# 152                                                NaN
# 156                                                NaN
# 161                   Lenny's specific grape wine 1607
# 163                                                NaN
# 174                                                NaN
# 175                                                NaN
# 181                                                NaN
# 186                                                NaN
# 228                                                NaN
# 232                                                NaN
# 271                                                NaN
# 277                                               Jaye
# 281                                                NaN
# 287                                                NaN
# 289                                                EMS
# 291                                         Pinot Noir
# 294                                            Chablis
# 311                                                NaN
#
#                                  Name      Price       Region  Score Vintage  \
# 0                                 NaN        NaN     Portugal    4.0    2013
# 1                                 NaN      17.80       France    3.0    2013
# 2                                 NaN      20.00       Oregon    3.0    2013
# 3                                 NaN       7.00        Spain    2.5    2012
# 4                        Spice Trader       6.00          NaN    3.0    2012
# 5                                 NaN      13.00   California    3.5    2012
# 6                                 #14      21.00       Oregon    2.5    2013
# 7                                 NaN      12.00     Bordeaux    3.5    2012
# 8                                 NaN      11.99        Medoc    3.5    2011
# 9                                 NaN      13.00   Washington    4.0    2011
# 10                    Rosso Dei Poggi      12.00      Tuscany    3.0    2012
# 11            Montepulciano D'Abruzzo      22.00      Tuscany    4.5    2013
# 12                                NaN       7.00       Oregon    3.5    2010
# 13                Rosso Di Montalcino      15.00      Tuscany    3.5    2012
# 14   Sancerre Cuvee Des Moulins Bales      12.00        Loire    3.0    2012
# 15                             Meiomi      13.00         Napa    3.0    2012
# 16             Saint Drezery Prestige      13.00       France    3.0    2012
# 17             Saint Drezery Prestige      14.00       France    2.0    2011
# 18                    Sauvignon Blanc      14.50        Nappa    4.0    2012
# 19               Uppercut North Coast      11.00        Nappa    3.0    2012
# 21                         Cape Blush      10.00        Truro    4.0    2013
# 22                       Pinot Grigio      10.00        Truro    3.0    2013
# 23                         Cru Classe        NaN     Provence    3.5    2013
# 24                Domaine du Claouset        NaN     Bordeaux    3.0    2013
# 25                    Sauvignon Blanc        NaN         Napa    3.5    2012
# 26                        Vinho Verde        NaN     Portugal    3.5    2013
# 27                      Vincent Dampt      35.00     Burgundy    4.0    2012
# 28                           Albarino      15.00  Rias Baixas    4.0    2012
# 29                  My wonderful wine     200.00       Sonoma   10.0    1973
# 31                  My wonderful wine    9999.00       Sonoma   10.0    1973
# ..                                ...        ...          ...    ...     ...
# 74                 Bretts happy juice     200.00       Sonoma   10.0    1973
# 77                         Ryans wine     200.00       Sonoma   10.0    1986
# 79                        Chez Wilson     200.00       Sonoma   10.0    1973
# 80                         Dope Wines     200.00       Sonoma   10.0    1973
# 81                  My wonderful wine     200.00       Sonoma   10.0    1973
# 85                   christine's wine     200.00       Sonoma   10.0    1973
# 92                            Beyhtar     200.00       Sonoma   10.0    1973
# 103             Howies wonderful wine     200.00       Sonoma   10.0    1973
# 106                 CK wonderful wine     200.00       Sonoma   10.0    1973
# 132                My wonderful wine1     200.00       Sonoma   10.0    1973
# 145                 My wonderful wine   20000.00       Sonoma   10.0    1973
# 149                     My wonderfine     200.00       Sonoma   10.0    1973
# 152                       Blue Grapes     200.00       Sonoma   10.0    1973
# 156                        BEAST MODE  100000.00    HULKMANIA   10.0    1900
# 161                 My wonderful wine     200.00       Sonoma   10.0    1973
# 163                      Purple Drank     200.00       Sonoma   10.0    1973
# 174                My wonderful wine      200.00       Sonoma   10.0    1973
# 175                 My wonderful wine     200.00       Sonoma   10.0    1973
# 181                 My wonderful wine     200.00       Sonoma   10.0    1973
# 186                 My wonderful wine     200.00       Sonoma   10.0    1973
# 228         My wonderful wine - kelly     200.00       Sonoma   10.0    1973
# 232  some other not so wonderful wine     222.00    Stockholm   10.0    1973
# 271              My wonderful wine_rn     200.00       Sonoma   10.0    1973
# 277                 My wonderful wine     200.00       Sonoma   10.0    1973
# 281          AAAAAAAAAAAAAAAAAAAAAAAA     200.00           PT   10.0    1973
# 287          My wonderful wine - Juan     200.00       Sonoma   10.0    1973
# 289         My wonderful wine_EMS_EMS     200.00       Sonoma   10.0    1973
# 291                   Chateau Gregory    2000.00       Vosges   10.0    1978
# 294                 Expensive Chablis     200.00       Sonoma   10.0    1973
# 311                           RameshK     200.00       Sonoma   10.0    1973
#
#                     Vinyard
# 0               Vinho Verde
# 1                 Peyruchet
# 2                   Abacela
# 3                     Ochoa
# 4                 Heartland
# 5               Crow Canyon
# 6                   Abacela
# 7            David Beaulieu
# 8               Chantemerle
# 9                     Hyatt
# 10          Rosso Dei Poggi
# 11                Orizzonti
# 12                  Abacelo
# 13                  Ridolfi
# 14        Celestin Blobdeau
# 15               Belle Glos
# 16               Puech-Haut
# 17               Puech-Haut
# 18                    Honig
# 19               Provenance
# 21          Truro Vineyards
# 22          Truro Vineyards
# 23   Chateau de la Clapiere
# 24      Domaine du Claouset
# 25               Two Angels
# 26                  Mapreco
# 27                 Vaillons
# 28                Granbazan
# 29                      NaN
# 31                      NaN
# ..                      ...
# 74                      NaN
# 77                      NaN
# 79                      NaN
# 80                      NaN
# 81             Sonoma Vines
# 85                      NaN
# 92                      NaN
# 103                     NaN
# 106                     NaN
# 132                     NaN
# 145                     NaN
# 149                     NaN
# 152                     NaN
# 156                     NaN
# 161                     NaN
# 163                     NaN
# 174                     NaN
# 175                     NaN
# 181         Playboy Mansion
# 186                     NaN
# 228                     NaN
# 232                     NYB
# 271                     NaN
# 277                     NaN
# 281                     NaN
# 287                     NaN
# 289                     EMS
# 291                   Perso
# 294                     NaN
# 311                     NaN
#
# [71 rows x 10 columns]

# %%
data['Consumed In'] = pd.to_numeric(data['Consumed In'], errors='coerce')
data['Vinatage'] = pd.to_numeric(data['Vintage'], errors='coerce')
data['Age'] = data['Consumed In']-data['Vinatage']
data['Age']
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# 0        2.0
# 1        2.0
# 2        2.0
# 3        3.0
# 4        3.0
# 5        3.0
# 6        2.0
# 7        3.0
# 8        4.0
# 9        4.0
# 10       3.0
# 11       2.0
# 12       5.0
# 13       3.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       2.0
# 18       2.0
# 19       2.0
# 21       1.0
# 22       1.0
# 23       1.0
# 24       2.0
# 25       3.0
# 26       2.0
# 27       3.0
# 28       3.0
# 29      42.0
# 31      42.0
#        ...
# 74      42.0
# 77      29.0
# 79      42.0
# 80      42.0
# 81      42.0
# 85      42.0
# 92      42.0
# 103     42.0
# 106     42.0
# 132     42.0
# 145     42.0
# 149     42.0
# 152     42.0
# 156    117.0
# 161     42.0
# 163     42.0
# 174     42.0
# 175     42.0
# 181     42.0
# 186      NaN
# 228     49.0
# 232     32.0
# 271     42.0
# 277     42.0
# 281     42.0
# 287     42.0
# 289     42.0
# 291      NaN
# 294     42.0
# 311     42.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Exercise 4: Feature Extraction
#
# We would like to use a regression tree to predict the score of a wine. In order to do that, we first need to select and engineer appropriate features.
#
# - Set the target to be the Score column, drop the rows with no score
# - Use pd.get_dummies to create dummy features for all the text columns
# - Fill the nan values in the numerical columns, using an appropriate method
# - Train a Decision tree regressor on the Score, using a train test split:
#         X_train, X_test, y_train, y_test, = train_test_split(X, y, test_size=0.3, random_state=42)
# - Plot the test values, the predicted values and the residuals
# - Calculate R^2 score
# - Discuss your findings

# %%
data.columns
# Out:
# Index([      u'Color', u'Consumed In',     u'Country',       u'Grape',
#               u'Name',       u'Price',      u'Region',       u'Score',
#            u'Vintage',     u'Vinyard',    u'Vinatage',         u'Age'],
#       dtype='object')

# %%
import patsy
y,X = patsy.dmatrices('Score~C(Country)+C(Grape)+C(Region)+C(Score)+C(Vintage)+C(Vinyard)+Age',data)

# %%
from sklearn.cross_validation import train_test_split

# %%
from sklearn.tree import DecisionTreeRegressor

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3, random_state=42)
dtr=DecisionTreeRegressor()
model=dtr.fit(X_train,y_train)
predictions=model.predict(X_test)
predictions
# Out:
# array([ 3.5,  3.5,  3. ,  4. ,  3. ,  4. ])

# %%
model.score(X_test,y_test)
# Out:
# 0.45454545454545447

# %% [markdown]
# ## Exercise 5: IMDB Movies
#
# Sometimes an API doesn't provide all the information we would like to get and we need to be creative.
# Here we will use a combination of scraping and API calls to investigate the ratings and gross earnings of famous movies.

# %% [markdown]
# ## 5.a Get top movies
#
# The Internet Movie Database contains data about movies. Unfortunately it does not have a public API.
#
# The page http://www.imdb.com/chart/top contains the list of the top 250 movies of all times. Retrieve the page using the requests library and then parse the html to obtain a list of the `movie_ids` for these movies. You can parse it with regular expression or using a library like `BeautifulSoup`.
#
# **Hint:** movie_ids look like this: `tt2582802`

# %%
# !pip install imdbpie
# Out:
# Collecting imdbpie
#   Downloading imdbpie-4.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six<2.0.0,>=1.0.0 in /anaconda/lib/python2.7/site-packages (from imdbpie)
# Requirement already satisfied: requests>=0.10 in /anaconda/lib/python2.7/site-packages (from imdbpie)
# Collecting cachecontrol[filecache] (from imdbpie)
#   Downloading CacheControl-0.11.7.tar.gz
# Requirement already satisfied: wheel in /anaconda/lib/python2.7/site-packages (from imdbpie)
# Collecting lockfile>=0.9 (from cachecontrol[filecache]->imdbpie)
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl
# Building wheels for collected packages: cachecontrol
# done
#   Stored in directory: /Users/samyuktha/Library/Caches/pip/wheels/9b/94/d2/1793b004461b5bc238a89e260cd2b9f770437c42424fdd0943
# Successfully built cachecontrol
# Installing collected packages: lockfile, cachecontrol, imdbpie
# Successfully installed cachecontrol-0.11.7 imdbpie-4.2.0 lockfile-0.12.2

# %%
import imdbpie

# %%
imdb=imdbpie.Imdb()
imdb.top_250()
# Out:
# [{u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_.jpg',
#    u'width': 933},
#   u'num_votes': 1734132,
#   u'rating': 9.3,
#   u'tconst': u'tt0111161',
#   u'title': u'The Shawshank Redemption',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1129,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTUxOTdjMDMtMWY1MC00MjkxLTgxYTMtYTM1MjU5ZTJlNTZjXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 798},
#   u'num_votes': 1184876,
#   u'rating': 9.2,
#   u'tconst': u'tt0068646',
#   u'title': u'The Godfather',
#   u'type': u'feature',
#   u'year': u'1972'},
#  {u'can_rate': True,
#   u'image': {u'height': 2999,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjZiNzIxNTQtNDc5Zi00YWY1LThkMTctMDgzYjY4YjI1YmQyL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 2106},
#   u'num_votes': 812632,
#   u'rating': 9,
#   u'tconst': u'tt0071562',
#   u'title': u'The Godfather: Part II',
#   u'type': u'feature',
#   u'year': u'1974'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg',
#    u'width': 1383},
#   u'num_votes': 1718813,
#   u'rating': 9,
#   u'tconst': u'tt0468569',
#   u'title': u'The Dark Knight',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODQwOTc5MDM2N15BMl5BanBnXkFtZTcwODQxNTEzNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 463144,
#   u'rating': 8.9,
#   u'tconst': u'tt0050083',
#   u'title': u'12 Angry Men',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 679,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzMwMTM4MDU2N15BMl5BanBnXkFtZTgwMzQ0MjMxMDE@._V1_.jpg',
#    u'width': 439},
#   u'num_votes': 888278,
#   u'rating': 8.9,
#   u'tconst': u'tt0108052',
#   u'title': u"Schindler's List",
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkxMTA5OTAzMl5BMl5BanBnXkFtZTgwNjA5MDc3NjE@._V1_.jpg',
#    u'width': 1010},
#   u'num_votes': 1358039,
#   u'rating': 8.9,
#   u'tconst': u'tt0110912',
#   u'title': u'Pulp Fiction',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 519,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjE4MjA1NTAyMV5BMl5BanBnXkFtZTcwNzM1NDQyMQ@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 1245440,
#   u'rating': 8.9,
#   u'tconst': u'tt0167260',
#   u'title': u'The Lord of the Rings: The Return of the King',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTQ5NDI3MTI4MF5BMl5BanBnXkFtZTgwNDQ4ODE5MDE@._V1_.jpg',
#    u'width': 1344},
#   u'num_votes': 516031,
#   u'rating': 8.9,
#   u'tconst': u'tt0060196',
#   u'title': u'The Good, the Bad and the Ugly',
#   u'type': u'feature',
#   u'year': u'1966'},
#  {u'can_rate': True,
#   u'image': {u'height': 2400,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGM2NjQxZTAtMmU5My00YTk5LWFmOWMtYjZlYzk4YzMwNjFlXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#    u'width': 1600},
#   u'num_votes': 1384565,
#   u'rating': 8.8,
#   u'tconst': u'tt0137523',
#   u'title': u'Fight Club',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTEyMjAwMDU1OV5BMl5BanBnXkFtZTcwNDQyNTkxMw@@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 1267869,
#   u'rating': 8.8,
#   u'tconst': u'tt0120737',
#   u'title': u'The Lord of the Rings: The Fellowship of the Ring',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 2125,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYmViY2M2MTYtY2MzOS00YjQ1LWIzYmEtOTBiNjhlMGM0NjZjXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 1369},
#   u'num_votes': 860246,
#   u'rating': 8.8,
#   u'tconst': u'tt0080684',
#   u'title': u'Star Wars: Episode V - The Empire Strikes Back',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYThjM2MwZGMtMzg3Ny00NGRkLWE4M2EtYTBiNWMzOTY0YTI4XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 1136},
#   u'num_votes': 1289751,
#   u'rating': 8.8,
#   u'tconst': u'tt0109830',
#   u'title': u'Forrest Gump',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1037,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_.jpg',
#    u'width': 700},
#   u'num_votes': 1509674,
#   u'rating': 8.8,
#   u'tconst': u'tt1375666',
#   u'title': u'Inception',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 512,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTAyNDU0NjY4NTheQTJeQWpwZ15BbWU2MDk4MTY2Nw@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 1128088,
#   u'rating': 8.7,
#   u'tconst': u'tt0167261',
#   u'title': u'The Lord of the Rings: The Two Towers',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 718,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYmJkODkwOTItZThjZC00MTE0LWIxNzQtYTM3MmQwMGI1OWFiXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_.jpg',
#    u'width': 473},
#   u'num_votes': 696339,
#   u'rating': 8.7,
#   u'tconst': u'tt0073486',
#   u'title': u"One Flew Over the Cuckoo's Nest",
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNThjMzczMjctZmIwOC00NTQ4LWJhZWItZDdhNTk5ZTdiMWFlXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 1004},
#   u'num_votes': 747586,
#   u'rating': 8.7,
#   u'tconst': u'tt0099685',
#   u'title': u'Goodfellas',
#   u'type': u'feature',
#   u'year': u'1990'},
#  {u'can_rate': True,
#   u'image': {u'height': 1383,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMDMyMmQ5YzgtYWMxOC00OTU0LWIwZjEtZWUwYTY5MjVkZjhhXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 1248725,
#   u'rating': 8.7,
#   u'tconst': u'tt0133093',
#   u'title': u'The Matrix',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 1900,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc5MDY1MjU5MF5BMl5BanBnXkFtZTgwNDM2OTE4MzE@._V1_.jpg',
#    u'width': 1354},
#   u'num_votes': 234855,
#   u'rating': 8.7,
#   u'tconst': u'tt0047478',
#   u'title': u'Seven Samurai',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 1150,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZGEzZTExMDEtNjg4OC00NjQxLTk5NTUtNjRkNjA3MmYwZjg1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 728},
#   u'num_votes': 933054,
#   u'rating': 8.7,
#   u'tconst': u'tt0076759',
#   u'title': u'Star Wars: Episode IV - A New Hope',
#   u'type': u'feature',
#   u'year': u'1977'},
#  {u'can_rate': True,
#   u'image': {u'height': 593,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4ODQ3ODkzNV5BMl5BanBnXkFtZTYwOTc4NDI3._V1_.jpg',
#    u'width': 400},
#   u'num_votes': 545946,
#   u'rating': 8.7,
#   u'tconst': u'tt0317248',
#   u'title': u'City of God',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQwNTU3MTE4NF5BMl5BanBnXkFtZTcwOTgxNDM2Mg@@._V1_.jpg',
#    u'width': 326},
#   u'num_votes': 1052838,
#   u'rating': 8.6,
#   u'tconst': u'tt0114369',
#   u'title': u'Se7en',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2NzkzMDI4OF5BMl5BanBnXkFtZTcwMDA0NzE1NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 913603,
#   u'rating': 8.6,
#   u'tconst': u'tt0102926',
#   u'title': u'The Silence of the Lambs',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTMzMzY5NDc4M15BMl5BanBnXkFtZTcwMzc4NjIxNw@@._V1_.jpg',
#    u'width': 1372},
#   u'num_votes': 282802,
#   u'rating': 8.6,
#   u'tconst': u'tt0038650',
#   u'title': u"It's a Wonderful Life",
#   u'type': u'feature',
#   u'year': u'1946'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzI1MjI5MDQyOV5BMl5BanBnXkFtZTcwNzE4Mjg3NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 760019,
#   u'rating': 8.6,
#   u'tconst': u'tt0114814',
#   u'title': u'The Usual Suspects',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYmJmM2Q4NmMtYThmNC00ZjRlLWEyZmItZTIwOTBlZDQ3NTQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1005},
#   u'num_votes': 434294,
#   u'rating': 8.6,
#   u'tconst': u'tt0118799',
#   u'title': u'Life Is Beautiful',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 2500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjdjMGU3MGYtN2Y5ZC00MTE4LWE4YWQtMTBhMjc3MTk0ZDUwXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 1660},
#   u'num_votes': 746346,
#   u'rating': 8.6,
#   u'tconst': u'tt0110413',
#   u'title': u'L\xe9on: The Professional',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 635,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjYxMDcyMzIzNl5BMl5BanBnXkFtZTYwNDg2MDU3._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 433198,
#   u'rating': 8.6,
#   u'tconst': u'tt0245429',
#   u'title': u'Spirited Away',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 1177,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZjhkMDM4MWItZTVjOC00ZDRhLThmYTAtM2I5NzBmNmNlMzI1XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 800},
#   u'num_votes': 906238,
#   u'rating': 8.6,
#   u'tconst': u'tt0120815',
#   u'title': u'Saving Private Ryan',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 2666,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYjFiOTlmMzgtOGZlYi00NjY0LThmMzEtNmQ0OTgxNGViOTZmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_.jpg',
#    u'width': 1755},
#   u'num_votes': 221945,
#   u'rating': 8.6,
#   u'tconst': u'tt0064116',
#   u'title': u'Once Upon a Time in the West',
#   u'type': u'feature',
#   u'year': u'1968'},
#  {u'can_rate': True,
#   u'image': {u'height': 736,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZjA0MTM4MTQtNzY5MC00NzY3LWI1ZTgtYzcxMjkyMzU4MDZiXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 497},
#   u'num_votes': 801970,
#   u'rating': 8.6,
#   u'tconst': u'tt0120586',
#   u'title': u'American History X',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIxNTU4MzY4MF5BMl5BanBnXkFtZTgwMzM4ODI3MjE@._V1_.jpg',
#    u'width': 1311},
#   u'num_votes': 971535,
#   u'rating': 8.6,
#   u'tconst': u'tt0816692',
#   u'title': u'Interstellar',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwNDYyNTk2N15BMl5BanBnXkFtZTgwMjQ0OTMyMjE@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 396355,
#   u'rating': 8.6,
#   u'tconst': u'tt0034583',
#   u'title': u'Casablanca',
#   u'type': u'feature',
#   u'year': u'1942'},
#  {u'can_rate': True,
#   u'image': {u'height': 1371,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMDI3OWRmOTEtOWJhYi00N2JkLTgwNGItMjdkN2U0NjFiZTYwXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 909},
#   u'num_votes': 434443,
#   u'rating': 8.5,
#   u'tconst': u'tt0054215',
#   u'title': u'Psycho',
#   u'type': u'feature',
#   u'year': u'1960'},
#  {u'can_rate': True,
#   u'image': {u'height': 476,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA3NDQ5MDMzOV5BMl5BanBnXkFtZTgwODY2MjcyMjE@._V1_.jpg',
#    u'width': 320},
#   u'num_votes': 111996,
#   u'rating': 8.6,
#   u'tconst': u'tt0021749',
#   u'title': u'City Lights',
#   u'type': u'feature',
#   u'year': u'1931'},
#  {u'can_rate': True,
#   u'image': {u'height': 1536,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA0ODEzMTc1Nl5BMl5BanBnXkFtZTcwODM2MjAxNA@@._V1_.jpg',
#    u'width': 1021},
#   u'num_votes': 676647,
#   u'rating': 8.5,
#   u'tconst': u'tt0082971',
#   u'title': u'Raiders of the Lost Ark',
#   u'type': u'feature',
#   u'year': u'1981'},
#  {u'can_rate': True,
#   u'image': {u'height': 740,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUxMzQyNjA5MF5BMl5BanBnXkFtZTYwOTU2NTY3._V1_.jpg',
#    u'width': 500},
#   u'num_votes': 809155,
#   u'rating': 8.5,
#   u'tconst': u'tt0120689',
#   u'title': u'The Green Mile',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYxNDA3MDQwNl5BMl5BanBnXkFtZTcwNTU4Mzc1Nw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 523530,
#   u'rating': 8.6,
#   u'tconst': u'tt1675434',
#   u'title': u'The Intouchables',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAyMTkxNjI5OF5BMl5BanBnXkFtZTYwMjI2MjA5._V1_.jpg',
#    u'width': 347},
#   u'num_votes': 148125,
#   u'rating': 8.5,
#   u'tconst': u'tt0027977',
#   u'title': u'Modern Times',
#   u'type': u'feature',
#   u'year': u'1936'},
#  {u'can_rate': True,
#   u'image': {u'height': 1351,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 923},
#   u'num_votes': 324690,
#   u'rating': 8.5,
#   u'tconst': u'tt0047396',
#   u'title': u'Rear Window',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 2500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZDM2YjYwYWMtMWZlNi00ZDQxLWExMDctMDAzNzQ0OTkzZjljXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1689},
#   u'num_votes': 762817,
#   u'rating': 8.5,
#   u'tconst': u'tt0103064',
#   u'title': u'Terminator 2: Judgment Day',
#   u'type': u'feature',
#   u'year': u'1991'},
#  {u'can_rate': True,
#   u'image': {u'height': 1087,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOWRiZDIxZjktMTA1NC00MDQ2LWEzMjUtMTliZmY3NjQ3ODJiXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 787},
#   u'num_votes': 514510,
#   u'rating': 8.5,
#   u'tconst': u'tt0253474',
#   u'title': u'The Pianist',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 665,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTI1MTY2OTIxNV5BMl5BanBnXkFtZTYwNjQ4NjY3._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 896813,
#   u'rating': 8.5,
#   u'tconst': u'tt0407887',
#   u'title': u'The Departed',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 1893,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZmU0M2Y1OGUtZjIxNi00ZjBkLTg1MjgtOWIyNThiZWIwYjRiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1218},
#   u'num_votes': 753715,
#   u'rating': 8.5,
#   u'tconst': u'tt0088763',
#   u'title': u'Back to the Future',
#   u'type': u'feature',
#   u'year': u'1985'},
#  {u'can_rate': True,
#   u'image': {u'height': 755,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU4OTQ3MDUyMV5BMl5BanBnXkFtZTgwOTA2MjU0MjE@._V1_.jpg',
#    u'width': 509},
#   u'num_votes': 426486,
#   u'rating': 8.5,
#   u'tconst': u'tt2582802',
#   u'title': u'Whiplash',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 1377,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgwMzQzNTQ1Ml5BMl5BanBnXkFtZTgwMDY2NTYxMTE@._V1_.jpg',
#    u'width': 930},
#   u'num_votes': 1008466,
#   u'rating': 8.5,
#   u'tconst': u'tt0172495',
#   u'title': u'Gladiator',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 1879,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNThiYjM3MzktMDg3Yy00ZWQ3LTk3YWEtN2M0YmNmNWEwYTE3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1280},
#   u'num_votes': 867356,
#   u'rating': 8.5,
#   u'tconst': u'tt0209144',
#   u'title': u'Memento',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 842,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYWNjNjZjYmMtOTRjOC00ZGIwLWI2YzEtMjkxNTAzODkzZDRlXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_.jpg',
#    u'width': 580},
#   u'num_votes': 460969,
#   u'rating': 8.5,
#   u'tconst': u'tt0078788',
#   u'title': u'Apocalypse Now',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 667,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4NDI0MTIxNF5BMl5BanBnXkFtZTYwNTM0MzY2._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 869120,
#   u'rating': 8.5,
#   u'tconst': u'tt0482571',
#   u'title': u'The Prestige',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 2964,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYTYxNGMyZTYtMjE3MS00MzNjLWFjNmYtMDk3N2FmM2JiM2M1XkEyXkFqcGdeQXVyNjY5NDU4NzI@._V1_.jpg',
#    u'width': 1995},
#   u'num_votes': 664794,
#   u'rating': 8.5,
#   u'tconst': u'tt0110357',
#   u'title': u'The Lion King',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 1342,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDNhN2IxZWItNGEwYS00ZDNhLThiM2UtODU3NWJlZjBkYjQxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 914},
#   u'num_votes': 579253,
#   u'rating': 8.5,
#   u'tconst': u'tt0078748',
#   u'title': u'Alien',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTFiM2RlOGUtYjExYy00YjFmLWFjYzgtM2YwNDU1NmEyMzRlXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 350635,
#   u'rating': 8.5,
#   u'tconst': u'tt0057012',
#   u'title': u'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   u'type': u'feature',
#   u'year': u'1964'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc3NDYzODAwNV5BMl5BanBnXkFtZTgwODg1MTczMTE@._V1_.jpg',
#    u'width': 332},
#   u'num_votes': 143171,
#   u'rating': 8.5,
#   u'tconst': u'tt0043014',
#   u'title': u'Sunset Blvd.',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ5NDAwMDgzOV5BMl5BanBnXkFtZTgwNDI2MjA0MjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 142085,
#   u'rating': 8.5,
#   u'tconst': u'tt0032553',
#   u'title': u'The Great Dictator',
#   u'type': u'feature',
#   u'year': u'1940'},
#  {u'can_rate': True,
#   u'image': {u'height': 675,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDUzNjYwNDYyNl5BMl5BanBnXkFtZTcwNjU3ODQ0MQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 266500,
#   u'rating': 8.5,
#   u'tconst': u'tt0405094',
#   u'title': u'The Lives of Others',
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 499,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIzMTgzOTEwOF5BMl5BanBnXkFtZTgwNTUxNjcxMTE@._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 157412,
#   u'rating': 8.5,
#   u'tconst': u'tt0095765',
#   u'title': u'Cinema Paradiso',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 1600,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTI5Nzc0OTMtYzBkMS00NjkxLThmM2UtNjM2ODgxN2M5NjNkXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_.jpg',
#    u'width': 1045},
#   u'num_votes': 124422,
#   u'rating': 8.5,
#   u'tconst': u'tt0050825',
#   u'title': u'Paths of Glory',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIyNTQ5NjQ1OV5BMl5BanBnXkFtZTcwODg1MDU4OA@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 985691,
#   u'rating': 8.4,
#   u'tconst': u'tt1853728',
#   u'title': u'Django Unchained',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODMxMjE3NTA4Ml5BMl5BanBnXkFtZTgwNDc0NTIxMDE@._V1_.jpg',
#    u'width': 1024},
#   u'num_votes': 628054,
#   u'rating': 8.4,
#   u'tconst': u'tt0081505',
#   u'title': u'The Shining',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgyMzUwMTMxMl5BMl5BanBnXkFtZTgwODYyMDk2MjE@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 144229,
#   u'rating': 8.5,
#   u'tconst': u'tt0095327',
#   u'title': u'Grave of the Fireflies',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjExMTg5OTU0NF5BMl5BanBnXkFtZTcwMjMxMzMzMw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 740044,
#   u'rating': 8.4,
#   u'tconst': u'tt0910970',
#   u'title': u'WALL\xb7E',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 720,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_.jpg',
#    u'width': 486},
#   u'num_votes': 1173638,
#   u'rating': 8.5,
#   u'tconst': u'tt1345836',
#   u'title': u'The Dark Knight Rises',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1377,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjM4NTI5NzYyNV5BMl5BanBnXkFtZTgwNTkxNTYxMTE@._V1_.jpg',
#    u'width': 930},
#   u'num_votes': 842246,
#   u'rating': 8.4,
#   u'tconst': u'tt0169547',
#   u'title': u'American Beauty',
#   u'type': u'feature',
#   u'year': u'1999'},
#  {u'can_rate': True,
#   u'image': {u'height': 513,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYTU2YjNmN2UtMTkyYS00YTFhLWJkM2QtODNhODE0OGQzMDQ3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 342},
#   u'num_votes': 229182,
#   u'rating': 8.4,
#   u'tconst': u'tt0119698',
#   u'title': u'Princess Mononoke',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 1425,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTYxZGJkNDUtOWRmMy00M2JjLWJiNjAtNTE0OWU0ODU1MDdiXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 914},
#   u'num_votes': 499555,
#   u'rating': 8.4,
#   u'tconst': u'tt0090605',
#   u'title': u'Aliens',
#   u'type': u'feature',
#   u'year': u'1986'},
#  {u'can_rate': True,
#   u'image': {u'height': 666,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTI3NTQyMzU5M15BMl5BanBnXkFtZTcwMTM2MjgyMQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 367186,
#   u'rating': 8.4,
#   u'tconst': u'tt0364569',
#   u'title': u'Oldboy',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 1422,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMGFkNWI4MTMtNGQ0OC00MWVmLTk3MTktOGYxN2Y2YWVkZWE2XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 910},
#   u'num_votes': 227146,
#   u'rating': 8.4,
#   u'tconst': u'tt0087843',
#   u'title': u'Once Upon a Time in America',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2Mjc1MDQwMl5BMl5BanBnXkFtZTcwNzUyOTUyMg@@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 304767,
#   u'rating': 8.4,
#   u'tconst': u'tt0033467',
#   u'title': u'Citizen Kane',
#   u'type': u'feature',
#   u'year': u'1941'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjE5Mzk5OTQ0Nl5BMl5BanBnXkFtZTYwNzUwMTQ5._V1_.jpg',
#    u'width': 297},
#   u'num_votes': 172104,
#   u'rating': 8.4,
#   u'tconst': u'tt0082096',
#   u'title': u'Das Boot',
#   u'type': u'feature',
#   u'year': u'1981'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc0MjgyNTUyNF5BMl5BanBnXkFtZTcwNDQzMDg0Nw@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 65710,
#   u'rating': 8.4,
#   u'tconst': u'tt0051201',
#   u'title': u'Witness for the Prosecution',
#   u'type': u'feature',
#   u'year': u'1957'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQwMTQ0MzgwNl5BMl5BanBnXkFtZTgwNjc4ODE4MzE@._V1_.jpg',
#    u'width': 1309},
#   u'num_votes': 225167,
#   u'rating': 8.4,
#   u'tconst': u'tt0053125',
#   u'title': u'North by Northwest',
#   u'type': u'feature',
#   u'year': u'1959'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNzY0NzQyNzQzOF5BMl5BanBnXkFtZTcwMTgwNTk4OQ@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 256268,
#   u'rating': 8.4,
#   u'tconst': u'tt0052357',
#   u'title': u'Vertigo',
#   u'type': u'feature',
#   u'year': u'1958'},
#  {u'can_rate': True,
#   u'image': {u'height': 1424,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODllZjg2YjUtNWEzNy00ZGY2LTgyZmQtYTkxNDYyOWM3OTUyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 908},
#   u'num_votes': 701478,
#   u'rating': 8.4,
#   u'tconst': u'tt0086190',
#   u'title': u'Star Wars: Episode VI - Return of the Jedi',
#   u'type': u'feature',
#   u'year': u'1983'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQyNjA5NzU5MV5BMl5BanBnXkFtZTgwMDk1MTA5MTE@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 101614,
#   u'rating': 8.4,
#   u'tconst': u'tt0022100',
#   u'title': u'M',
#   u'type': u'feature',
#   u'year': u'1931'},
#  {u'can_rate': True,
#   u'image': {u'height': 1351,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNjE5ZDJiZTQtOGE2YS00ZTc5LTk0OGUtOTg2NjdjZmVlYzE2XkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_.jpg',
#    u'width': 936},
#   u'num_votes': 682411,
#   u'rating': 8.4,
#   u'tconst': u'tt0105236',
#   u'title': u'Reservoir Dogs',
#   u'type': u'feature',
#   u'year': u'1992'},
#  {u'can_rate': True,
#   u'image': {u'height': 1891,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTMyNGE1ODQtYTNiNS00ZTUyLThhZjktMTgyOGZkZThlYTc3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1280},
#   u'num_votes': 754582,
#   u'rating': 8.4,
#   u'tconst': u'tt0112573',
#   u'title': u'Braveheart',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1900,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA3MjVkMWMtYTQ4ZC00ODczLWFjYmQtMDFkZDQ2Y2M0NDVmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1278},
#   u'num_votes': 548052,
#   u'rating': 8.4,
#   u'tconst': u'tt0211915',
#   u'title': u'Am\xe9lie',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 433,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkzODMzODYwOF5BMl5BanBnXkFtZTcwODM2NjA2NQ@@._V1_.jpg',
#    u'width': 300},
#   u'num_votes': 587712,
#   u'rating': 8.4,
#   u'tconst': u'tt0180093',
#   u'title': u'Requiem for a Dream',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 647,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTI1NTQ3MjEyM15BMl5BanBnXkFtZTcwMzUxMzIzMQ@@._V1_.jpg',
#    u'width': 450},
#   u'num_votes': 37890,
#   u'rating': 8.7,
#   u'tconst': u'tt0476735',
#   u'title': u'My Father and My Son',
#   u'type': u'feature',
#   u'year': u'2005'},
#  {u'can_rate': True,
#   u'image': {u'height': 1300,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY3MjM1Mzc4N15BMl5BanBnXkFtZTgwODM0NzAxMDE@._V1_.jpg',
#    u'width': 878},
#   u'num_votes': 573348,
#   u'rating': 8.3,
#   u'tconst': u'tt0066921',
#   u'title': u'A Clockwork Orange',
#   u'type': u'feature',
#   u'year': u'1971'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU4NzYwNjYzNV5BMl5BanBnXkFtZTcwNjE4MjA3Mg@@._V1_.jpg',
#    u'width': 350},
#   u'num_votes': 89774,
#   u'rating': 8.5,
#   u'tconst': u'tt0986264',
#   u'title': u'Like Stars on Earth',
#   u'type': u'feature',
#   u'year': u'2007'},
#  {u'can_rate': True,
#   u'image': {u'height': 2886,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGQxNDgzZWQtZTNjNi00M2RkLWExZmEtNmE1NjEyZDEwMzA5XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1889},
#   u'num_votes': 521543,
#   u'rating': 8.3,
#   u'tconst': u'tt0075314',
#   u'title': u'Taxi Driver',
#   u'type': u'feature',
#   u'year': u'1976'},
#  {u'can_rate': True,
#   u'image': {u'height': 2767,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYWY5ZjhjNGYtZmI2Ny00ODM0LWFkNzgtZmI1YzA2N2MxMzA0XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_.jpg',
#    u'width': 1920},
#   u'num_votes': 197726,
#   u'rating': 8.4,
#   u'tconst': u'tt0056172',
#   u'title': u'Lawrence of Arabia',
#   u'type': u'feature',
#   u'year': u'1962'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZmRmYmZkZTktZDc5ZC00ZjZmLTg4NWMtYjM3MjcyNTVjNGQ5L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_.jpg',
#    u'width': 998},
#   u'num_votes': 100456,
#   u'rating': 8.4,
#   u'tconst': u'tt0036775',
#   u'title': u'Double Indemnity',
#   u'type': u'feature',
#   u'year': u'1944'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4MzI1NDY2Nl5BMl5BanBnXkFtZTcwMTcyODc5Mw@@._V1_.jpg',
#    u'width': 328},
#   u'num_votes': 221000,
#   u'rating': 8.3,
#   u'tconst': u'tt0056592',
#   u'title': u'To Kill a Mockingbird',
#   u'type': u'feature',
#   u'year': u'1962'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTgxOTY4Mjc0MF5BMl5BanBnXkFtZTcwNTA4MDQyMw@@._V1_.jpg',
#    u'width': 1448},
#   u'num_votes': 560149,
#   u'rating': 8.3,
#   u'tconst': u'tt0435761',
#   u'title': u'Toy Story 3',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY4NzcwODg3Nl5BMl5BanBnXkFtZTcwNTEwOTMyMw@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 685485,
#   u'rating': 8.3,
#   u'tconst': u'tt0338013',
#   u'title': u'Eternal Sunshine of the Spotless Mind',
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 704,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg5NDkwMTk5N15BMl5BanBnXkFtZTYwODg3MDk2._V1_.jpg',
#    u'width': 475},
#   u'num_votes': 277818,
#   u'rating': 8.3,
#   u'tconst': u'tt0086879',
#   u'title': u'Amadeus',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4NzY4ODk4Nl5BMl5BanBnXkFtZTgwOTcxNTYxMTE@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 498733,
#   u'rating': 8.3,
#   u'tconst': u'tt0093058',
#   u'title': u'Full Metal Jacket',
#   u'type': u'feature',
#   u'year': u'1987'},
#  {u'can_rate': True,
#   u'image': {u'height': 1388,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY5MjM1OTAyOV5BMl5BanBnXkFtZTgwMDkwODg4MDE@._V1._CR52,57,915,1388_.jpg',
#    u'width': 915},
#   u'num_votes': 180201,
#   u'rating': 8.3,
#   u'tconst': u'tt0070735',
#   u'title': u'The Sting',
#   u'type': u'feature',
#   u'year': u'1973'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjQ1NjM3MTUxNV5BMl5BanBnXkFtZTgwMDc5MTY5OTE@._V1_.jpg',
#    u'width': 971},
#   u'num_votes': 28213,
#   u'rating': 8.6,
#   u'tconst': u'tt2119532',
#   u'title': u'Hacksaw Ridge',
#   u'type': u'feature',
#   u'year': u'2016'},
#  {u'can_rate': True,
#   u'image': {u'height': 1600,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZkZTBhYmUtMTIzNy00YTViLTg1OWItNGUwMmVlN2FjZTVkXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 1080},
#   u'num_votes': 439310,
#   u'rating': 8.3,
#   u'tconst': u'tt0062622',
#   u'title': u'2001: A Space Odyssey',
#   u'type': u'feature',
#   u'year': u'1968'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTExMzU0ODcxNDheQTJeQWpwZ15BbWU4MDE1OTI4MzAy._V1_.jpg',
#    u'width': 1311},
#   u'num_votes': 62711,
#   u'rating': 8.4,
#   u'tconst': u'tt2543164',
#   u'title': u'Arrival',
#   u'type': u'feature',
#   u'year': u'2016'},
#  {u'can_rate': True,
#   u'image': {u'height': 3300,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIzMzAyMzg1Nl5BMl5BanBnXkFtZTgwMzMyNzk0MTE@._V1_.jpg',
#    u'width': 2285},
#   u'num_votes': 97679,
#   u'rating': 8.3,
#   u'tconst': u'tt0040522',
#   u'title': u'Bicycle Thieves',
#   u'type': u'feature',
#   u'year': u'1948'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_.jpg',
#    u'width': 1005},
#   u'num_votes': 642101,
#   u'rating': 8.3,
#   u'tconst': u'tt0114709',
#   u'title': u'Toy Story',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTA2NDYxOGYtYjU1Mi00Y2QzLTgxMTQtMWI1MGI0ZGQ5MmU4XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#    u'width': 1026},
#   u'num_votes': 614980,
#   u'rating': 8.3,
#   u'tconst': u'tt0208092',
#   u'title': u'Snatch',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMWUyNjQ5MTAtNDJhYS00MWQ0LTk2ZTAtZmE4MWNlMjMwMzg3XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 154068,
#   u'rating': 8.3,
#   u'tconst': u'tt0045152',
#   u'title': u"Singin' in the Rain",
#   u'type': u'feature',
#   u'year': u'1952'},
#  {u'can_rate': True,
#   u'image': {u'height': 3000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTJiNDEzOWYtMTVjOC00ZjlmLWE0NGMtZmE1OWVmZDQ2OWJhXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_.jpg',
#    u'width': 2025},
#   u'num_votes': 911798,
#   u'rating': 8.3,
#   u'tconst': u'tt0361748',
#   u'title': u'Inglourious Basterds',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 1161,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZjhhMThhNDItNTY2MC00MmU1LTliNDEtNDdhZjdlNTY5ZDQ1XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_.jpg',
#    u'width': 771},
#   u'num_votes': 70402,
#   u'rating': 8.3,
#   u'tconst': u'tt0012349',
#   u'title': u'The Kid',
#   u'type': u'feature',
#   u'year': u'1921'},
#  {u'can_rate': True,
#   u'image': {u'height': 858,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BYzgyYzc4Y2QtNDcyZS00NDdmLWI5ZTYtMTQ2YWU5MWFhOTE4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 580},
#   u'num_votes': 390867,
#   u'rating': 8.3,
#   u'tconst': u'tt0071853',
#   u'title': u'Monty Python and the Holy Grail',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 858,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMDBlYzAwZDktNzM2MS00YzBlLWI4ODQtZTlkNmMxZDc3NGRkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 580},
#   u'num_votes': 423570,
#   u'rating': 8.3,
#   u'tconst': u'tt0119488',
#   u'title': u'L.A. Confidential',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQzMjIzOTEzMF5BMl5BanBnXkFtZTcwMTUzNTk3NA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 162374,
#   u'rating': 8.3,
#   u'tconst': u'tt0059578',
#   u'title': u'For a Few Dollars More',
#   u'type': u'feature',
#   u'year': u'1965'},
#  {u'can_rate': True,
#   u'image': {u'height': 1485,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZWRlNDdkNzItMzhlZC00YTdmLWIwNjktYjY5NjQ1ZmQ3N2FkXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 1110},
#   u'num_votes': 218706,
#   u'rating': 8.4,
#   u'tconst': u'tt1187043',
#   u'title': u'3 Idiots',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 683,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjEzMzA4NDE2OF5BMl5BanBnXkFtZTcwNTc5MDI2NQ@@._V1._CR0,0,503,683_.jpg',
#    u'width': 503},
#   u'num_votes': 105649,
#   u'rating': 8.3,
#   u'tconst': u'tt0042876',
#   u'title': u'Rashomon',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAzOTM4MzEwNl5BMl5BanBnXkFtZTgwMzU1OTc1MDE@._V1_.jpg',
#    u'width': 675},
#   u'num_votes': 551301,
#   u'rating': 8.3,
#   u'tconst': u'tt0086250',
#   u'title': u'Scarface',
#   u'type': u'feature',
#   u'year': u'1983'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM1OTc4MzgzNl5BMl5BanBnXkFtZTcwNTE2NjgyMw@@._V1_.jpg',
#    u'width': 1234},
#   u'num_votes': 112497,
#   u'rating': 8.3,
#   u'tconst': u'tt0053604',
#   u'title': u'The Apartment',
#   u'type': u'feature',
#   u'year': u'1960'},
#  {u'can_rate': True,
#   u'image': {u'height': 2212,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjNkMzc2N2QtNjVlNS00ZTk5LTg0MTgtODY2MDAwNTMwZjBjXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#    u'width': 1500},
#   u'num_votes': 528367,
#   u'rating': 8.3,
#   u'tconst': u'tt0097576',
#   u'title': u'Indiana Jones and the Last Crusade',
#   u'type': u'feature',
#   u'year': u'1989'},
#  {u'can_rate': True,
#   u'image': {u'height': 5906,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg2NDg3ODg4NF5BMl5BanBnXkFtZTcwNzk3NTc3Nw@@._V1_.jpg',
#    u'width': 4134},
#   u'num_votes': 178143,
#   u'rating': 8.3,
#   u'tconst': u'tt2106476',
#   u'title': u'The Hunt',
#   u'type': u'feature',
#   u'year': u'2012'},
#  {u'can_rate': True,
#   u'image': {u'height': 1323,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTYzMzU4NDUwOF5BMl5BanBnXkFtZTcwMTM5MjA5Ng@@._V1_.jpg',
#    u'width': 893},
#   u'num_votes': 156643,
#   u'rating': 8.4,
#   u'tconst': u'tt1832382',
#   u'title': u'A Separation',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDAzNTkyODg1MF5BMl5BanBnXkFtZTgwMDA3NDkwMDE@._V1_.jpg',
#    u'width': 323},
#   u'num_votes': 114936,
#   u'rating': 8.3,
#   u'tconst': u'tt0017136',
#   u'title': u'Metropolis',
#   u'type': u'feature',
#   u'year': u'1927'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTI0MzcxMTYtZDVkMy00NjY1LTgyMTYtZmUxN2M3NmQ2NWJhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 983},
#   u'num_votes': 623108,
#   u'rating': 8.3,
#   u'tconst': u'tt0119217',
#   u'title': u'Good Will Hunting',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2MTAzODI5NV5BMl5BanBnXkFtZTgwMjM4NzQ0MjE@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 84926,
#   u'rating': 8.3,
#   u'tconst': u'tt0042192',
#   u'title': u'All About Eve',
#   u'type': u'feature',
#   u'year': u'1950'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAwNTQ3ODUyMl5BMl5BanBnXkFtZTgwNDg5ODQyNjE@._V1_.jpg',
#    u'width': 345},
#   u'num_votes': 76029,
#   u'rating': 8.3,
#   u'tconst': u'tt0055630',
#   u'title': u'Yojimbo',
#   u'type': u'feature',
#   u'year': u'1961'},
#  {u'can_rate': True,
#   u'image': {u'height': 721,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTM3OTc0MzM2OV5BMl5BanBnXkFtZTYwNzUwMTI3._V1_.jpg',
#    u'width': 485},
#   u'num_votes': 1006426,
#   u'rating': 8.3,
#   u'tconst': u'tt0372784',
#   u'title': u'Batman Begins',
#   u'type': u'feature',
#   u'year': u'2005'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ4MzUzOTYwOV5BMl5BanBnXkFtZTgwNDA4MzgyMjE@._V1_.jpg',
#    u'width': 338},
#   u'num_votes': 81261,
#   u'rating': 8.3,
#   u'tconst': u'tt0040897',
#   u'title': u'The Treasure of the Sierra Madre',
#   u'type': u'feature',
#   u'year': u'1948'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNzYzMDkzNDQ0N15BMl5BanBnXkFtZTcwNzQ0NDQyNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 179353,
#   u'rating': 8.3,
#   u'tconst': u'tt0053291',
#   u'title': u'Some Like It Hot',
#   u'type': u'feature',
#   u'year': u'1959'},
#  {u'can_rate': True,
#   u'image': {u'height': 1060,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk3NDE2NzI4NF5BMl5BanBnXkFtZTgwNzE1MzEyMTE@._V1_.jpg',
#    u'width': 704},
#   u'num_votes': 686510,
#   u'rating': 8.3,
#   u'tconst': u'tt1049413',
#   u'title': u'Up',
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 3155,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODM3YWY4NmQtN2Y3Ni00OTg0LWFhZGQtZWE3ZWY4MTJlOWU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 2100},
#   u'num_votes': 284513,
#   u'rating': 8.3,
#   u'tconst': u'tt0105695',
#   u'title': u'Unforgiven',
#   u'type': u'feature',
#   u'year': u'1992'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNWEzN2U1NWEtZThkOC00YWYyLWE0YzEtMWU3ZWQ0ZTk1NzgxXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_.jpg',
#    u'width': 742},
#   u'num_votes': 33551,
#   u'rating': 8.6,
#   u'tconst': u'tt0109117',
#   u'title': u'Andaz Apna Apna',
#   u'type': u'feature',
#   u'year': u'1994'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM1OTI1MjE2Nl5BMl5BanBnXkFtZTcwMTEwMzc4NA@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 254351,
#   u'rating': 8.3,
#   u'tconst': u'tt0363163',
#   u'title': u'Downfall',
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 1193,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZjQxYmRkMjgtMmZkZi00ZDYyLTk5OTktZWZjZTEzNGZlMWEwXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_.jpg',
#    u'width': 800},
#   u'num_votes': 116541,
#   u'rating': 8.3,
#   u'tconst': u'tt0041959',
#   u'title': u'The Third Man',
#   u'type': u'feature',
#   u'year': u'1949'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjIxOTg3OTc5MF5BMl5BanBnXkFtZTcwNzkwNjMwNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 240637,
#   u'rating': 8.3,
#   u'tconst': u'tt0081398',
#   u'title': u'Raging Bull',
#   u'type': u'feature',
#   u'year': u'1980'},
#  {u'can_rate': True,
#   u'image': {u'height': 859,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzNmY2IwYzAtNDQ1NC00MmI4LThkOTgtZmVhYmExOTVhMWRkXkEyXkFqcGdeQXVyMTk5NDA3Nw@@._V1_.jpg',
#    u'width': 580},
#   u'num_votes': 606026,
#   u'rating': 8.2,
#   u'tconst': u'tt0095016',
#   u'title': u'Die Hard',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0OTk4MDEwMV5BMl5BanBnXkFtZTYwNzMwNzI5._V1_.jpg',
#    u'width': 331},
#   u'num_votes': 30607,
#   u'rating': 8.4,
#   u'tconst': u'tt0118849',
#   u'title': u'Children of Heaven',
#   u'type': u'feature',
#   u'year': u'1997'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjI2MTQwNDI3Nl5BMl5BanBnXkFtZTcwNDk4MTkzNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 169896,
#   u'rating': 8.3,
#   u'tconst': u'tt0057115',
#   u'title': u'The Great Escape',
#   u'type': u'feature',
#   u'year': u'1963'},
#  {u'can_rate': True,
#   u'image': {u'height': 2850,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGMwNzUwNjYtZWM5NS00YzMyLWI4NjAtNjM0ZDBiMzE1YWExXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#    u'width': 1935},
#   u'num_votes': 441071,
#   u'rating': 8.2,
#   u'tconst': u'tt0113277',
#   u'title': u'Heat',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1596,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTZiZTA5MWItNTgyMy00ZGZkLThjNGQtOWI0MTU5ZDI4NmJmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_.jpg',
#    u'width': 1077},
#   u'num_votes': 221919,
#   u'rating': 8.2,
#   u'tconst': u'tt0071315',
#   u'title': u'Chinatown',
#   u'type': u'feature',
#   u'year': u'1974'},
#  {u'can_rate': True,
#   u'image': {u'height': 1609,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTgxMDQwMDk0OF5BMl5BanBnXkFtZTgwNjU5OTg2NDE@._V1_.jpg',
#    u'width': 1086},
#   u'num_votes': 373570,
#   u'rating': 8.2,
#   u'tconst': u'tt2096673',
#   u'title': u'Inside Out',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 800,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOGQ4ZjFmYjktOGNkNS00OWYyLWIyZjgtMGJjM2U1ZTA0ZTlhXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 566},
#   u'num_votes': 36115,
#   u'rating': 8.5,
#   u'tconst': u'tt0116231',
#   u'title': u'The Bandit',
#   u'type': u'feature',
#   u'year': u'1996'},
#  {u'can_rate': True,
#   u'image': {u'height': 1014,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU3ODg2NjQ5NF5BMl5BanBnXkFtZTcwMDEwODgzMQ@@._V1_.jpg',
#    u'width': 689},
#   u'num_votes': 479318,
#   u'rating': 8.2,
#   u'tconst': u'tt0457430',
#   u'title': u"Pan's Labyrinth",
#   u'type': u'feature',
#   u'year': u'2006'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZTYwNDdmNmEtOGZhYS00MjRiLWIzOWUtNDQxNzg4ZTVjMGE1XkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_.jpg',
#    u'width': 1050},
#   u'num_votes': 32198,
#   u'rating': 8.5,
#   u'tconst': u'tt0242519',
#   u'title': u'Hera Pheri',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 984,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTAzODEzMjE1MTJeQTJeQWpwZ15BbWU3MDE3NjQ5Mzk@._V1_.jpg',
#    u'width': 648},
#   u'num_votes': 44852,
#   u'rating': 8.4,
#   u'tconst': u'tt1280558',
#   u'title': u'A Wednesday',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 650,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BY2QxNTgzZGEtY2M5Ny00NjllLWE2MTAtYWU2N2NkYjE3NjVmXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_.jpg',
#    u'width': 464},
#   u'num_votes': 43667,
#   u'rating': 8.3,
#   u'tconst': u'tt0044741',
#   u'title': u'Ikiru',
#   u'type': u'feature',
#   u'year': u'1952'},
#  {u'can_rate': True,
#   u'image': {u'height': 690,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjE3NzY5ODQwMV5BMl5BanBnXkFtZTcwNzY1NzcxNw@@._V1_.jpg',
#    u'width': 500},
#   u'num_votes': 179388,
#   u'rating': 8.2,
#   u'tconst': u'tt0096283',
#   u'title': u'My Neighbor Totoro',
#   u'type': u'feature',
#   u'year': u'1988'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTcwMTU3MjI1OV5BMl5BanBnXkFtZTgwNjE2OTI3MjE@._V1_.jpg',
#    u'width': 357},
#   u'num_votes': 103431,
#   u'rating': 8.2,
#   u'tconst': u'tt0047296',
#   u'title': u'On the Waterfront',
#   u'type': u'feature',
#   u'year': u'1954'},
#  {u'can_rate': True,
#   u'image': {u'height': 1440,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjE4NzgzNzEwMl5BMl5BanBnXkFtZTgwMTMzMDE0NjE@._V1_.jpg',
#    u'width': 972},
#   u'num_votes': 187088,
#   u'rating': 8.2,
#   u'tconst': u'tt3170832',
#   u'title': u'Room',
#   u'type': u'feature',
#   u'year': u'2015'},
#  {u'can_rate': True,
#   u'image': {u'height': 938,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNTEyNjg0MDM4OF5BMl5BanBnXkFtZTgwODI0NjUxODE@._V1_.jpg',
#    u'width': 654},
#   u'num_votes': 79783,
#   u'rating': 8.3,
#   u'tconst': u'tt0089881',
# ...
#   u'type': u'feature',
#   u'year': u'1959'},
#  {u'can_rate': True,
#   u'image': {u'height': 2000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzM5NjUxOTEyMl5BMl5BanBnXkFtZTgwNjEyMDM0MDE@._V1_.jpg',
#    u'width': 1350},
#   u'num_votes': 496546,
#   u'rating': 8.1,
#   u'tconst': u'tt2278388',
#   u'title': u'The Grand Budapest Hotel',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTkxNzA1NDQxOV5BMl5BanBnXkFtZTcwNTkyMTIzMw@@._V1_.jpg',
#    u'width': 1390},
#   u'num_votes': 494068,
#   u'rating': 8.1,
#   u'tconst': u'tt0405159',
#   u'title': u'Million Dollar Baby',
#   u'type': u'feature',
#   u'year': u'2004'},
#  {u'can_rate': True,
#   u'image': {u'height': 838,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZjYwYzliYTktMzk3MS00MzE0LTllM2QtMDk3MTFmOGQ2MjE0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 564},
#   u'num_votes': 177378,
#   u'rating': 8.1,
#   u'tconst': u'tt0245712',
#   u'title': u'Amores Perros',
#   u'type': u'feature',
#   u'year': u'2000'},
#  {u'can_rate': True,
#   u'image': {u'height': 867,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNzgxMzExMzUwNV5BMl5BanBnXkFtZTcwMDc2MjUwNA@@._V1_.jpg',
#    u'width': 600},
#   u'num_votes': 30914,
#   u'rating': 8.3,
#   u'tconst': u'tt1639426',
#   u'title': u'Udaan',
#   u'type': u'feature',
#   u'year': u'2010'},
#  {u'can_rate': True,
#   u'image': {u'height': 1600,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMGM4M2Q5N2MtNThkZS00NTc1LTk1NTItNWEyZjJjNDRmNDk5XkEyXkFqcGdeQXVyMjA0MDQ0Mjc@._V1_.jpg',
#    u'width': 1083},
#   u'num_votes': 301135,
#   u'rating': 8.1,
#   u'tconst': u'tt0093779',
#   u'title': u'The Princess Bride',
#   u'type': u'feature',
#   u'year': u'1987'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjM2MDgxMDg0Nl5BMl5BanBnXkFtZTgwNTM2OTM5NDE@._V1_.jpg',
#    u'width': 667},
#   u'num_votes': 632109,
#   u'rating': 8.1,
#   u'tconst': u'tt0107290',
#   u'title': u'Jurassic Park',
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 430,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTAxMDA2MjM4NDReQTJeQWpwZ15BbWU3MDE0NTgxMTM@._V1_.jpg',
#    u'width': 300},
#   u'num_votes': 163430,
#   u'rating': 8.1,
#   u'tconst': u'tt1028532',
#   u'title': u"Hachi: A Dog's Tale",
#   u'type': u'feature',
#   u'year': u'2009'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOWU0NzY2YjktYmY2Ni00ODZmLWJjYjctOWY1MzBkOWM4M2MwXkEyXkFqcGdeQXVyMzM4MjM0Nzg@._V1_.jpg',
#    u'width': 1050},
#   u'num_votes': 99558,
#   u'rating': 8.1,
#   u'tconst': u'tt0087544',
#   u'title': u'Nausica\xe4 of the Valley of the Wind',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 1426,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNWEyMThjODktYjJjZC00YzUxLTk1YmQtOGUwNjM3MGMzZTRhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 70537,
#   u'rating': 8.1,
#   u'tconst': u'tt0353969',
#   u'title': u'Memories of Murder',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDY2NjU0NDAxOF5BMl5BanBnXkFtZTgwNjQ4MTI2MTE@._V1_.jpg',
#    u'width': 351},
#   u'num_votes': 70814,
#   u'rating': 8.1,
#   u'tconst': u'tt0079944',
#   u'title': u'Stalker',
#   u'type': u'feature',
#   u'year': u'1979'},
#  {u'can_rate': True,
#   u'image': {u'height': 1984,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTBlNGM0MjMtMDBhNi00NGJhLTliOTUtNDdlNjUwMTBkOTE1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1280},
#   u'num_votes': 74759,
#   u'rating': 8.1,
#   u'tconst': u'tt0052311',
#   u'title': u'Touch of Evil',
#   u'type': u'feature',
#   u'year': u'1958'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzgzNjcxNjg2M15BMl5BanBnXkFtZTcwMjQxNDQ3Mg@@._V1_.jpg',
#    u'width': 671},
#   u'num_votes': 64863,
#   u'rating': 8.1,
#   u'tconst': u'tt0032551',
#   u'title': u'The Grapes of Wrath',
#   u'type': u'feature',
#   u'year': u'1940'},
#  {u'can_rate': True,
#   u'image': {u'height': 2500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMDIzODcyY2EtMmY2MC00ZWVlLTgwMzAtMjQwOWUyNmJjNTYyXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#    u'width': 1685},
#   u'num_votes': 687367,
#   u'rating': 8.1,
#   u'tconst': u'tt0120382',
#   u'title': u'The Truman Show',
#   u'type': u'feature',
#   u'year': u'1998'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU1NDM2MjkwM15BMl5BanBnXkFtZTcwODU3OTYwNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 198384,
#   u'rating': 8.1,
#   u'tconst': u'tt0075686',
#   u'title': u'Annie Hall',
#   u'type': u'feature',
#   u'year': u'1977'},
#  {u'can_rate': True,
#   u'image': {u'height': 3160,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZDdiZTAwYzAtMDI3Ni00OTRjLTkzN2UtMGE3MDMyZmU4NTU4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 2124},
#   u'num_votes': 189518,
#   u'rating': 8.1,
#   u'tconst': u'tt0112471',
#   u'title': u'Before Sunrise',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM2MjgyNDE5Nl5BMl5BanBnXkFtZTcwMzM1MDc4MQ@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 49325,
#   u'rating': 8.4,
#   u'tconst': u'tt0871510',
#   u'title': u'Chak de! India',
#   u'type': u'feature',
#   u'year': u'2007'},
#  {u'can_rate': True,
#   u'image': {u'height': 1600,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BOTMyMjEyNzIzMV5BMl5BanBnXkFtZTgwNzIyNjU0NzE@._V1_.jpg',
#    u'width': 1080},
#   u'num_votes': 226039,
#   u'rating': 8.1,
#   u'tconst': u'tt2948356',
#   u'title': u'Zootopia',
#   u'type': u'feature',
#   u'year': u'2016'},
#  {u'can_rate': True,
#   u'image': {u'height': 755,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMzJiZDRmOWUtYjE2MS00Mjc1LTg1ZDYtNTQxYWJkZTg1OTM4XkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_.jpg',
#    u'width': 482},
#   u'num_votes': 175846,
#   u'rating': 8.1,
#   u'tconst': u'tt0083987',
#   u'title': u'Gandhi',
#   u'type': u'feature',
#   u'year': u'1982'},
#  {u'can_rate': True,
#   u'image': {u'height': 3000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNGNiNmU2YTMtZmU4OS00MjM0LTlmYWUtMjVlYjAzYjE2N2RjXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_.jpg',
#    u'width': 2025},
#   u'num_votes': 505521,
#   u'rating': 8.1,
#   u'tconst': u'tt0440963',
#   u'title': u'The Bourne Ultimatum',
#   u'type': u'feature',
#   u'year': u'2007'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTcwNzc5MjI5Nl5BMl5BanBnXkFtZTYwNjIwMzc5._V1_.jpg',
#    u'width': 337},
#   u'num_votes': 43387,
#   u'rating': 8.1,
#   u'tconst': u'tt0046911',
#   u'title': u'Diabolique',
#   u'type': u'feature',
#   u'year': u'1955'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY5MDMzODUyOF5BMl5BanBnXkFtZTcwMTQ3NTMyNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 386212,
#   u'rating': 8.1,
#   u'tconst': u'tt0075148',
#   u'title': u'Rocky',
#   u'type': u'feature',
#   u'year': u'1976'},
#  {u'can_rate': True,
#   u'image': {u'height': 2294,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BZWQyN2ZkODktMTBkNS00OTBjLWJhOGYtNGU4YWVkNTY0ZDZkXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 1568},
#   u'num_votes': 594805,
#   u'rating': 8.1,
#   u'tconst': u'tt0246578',
#   u'title': u'Donnie Darko',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 2000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY2MTk3MDQ1N15BMl5BanBnXkFtZTcwMzI4NzA2NQ@@._V1_.jpg',
#    u'width': 1350},
#   u'num_votes': 559936,
#   u'rating': 8.1,
#   u'tconst': u'tt1201607',
#   u'title': u'Harry Potter and the Deathly Hallows: Part 2',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 1748,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ4MTA0NjEzMF5BMl5BanBnXkFtZTgwMDg4NDYxMzE@._V1_.jpg',
#    u'width': 1258},
#   u'num_votes': 80618,
#   u'rating': 8.1,
#   u'tconst': u'tt0056801',
#   u'title': u'8\xbd',
#   u'type': u'feature',
#   u'year': u'1963'},
#  {u'can_rate': True,
#   u'image': {u'height': 1000,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY1NTI0ODUyOF5BMl5BanBnXkFtZTgwNTEyNjQ0MDE@._V1_.jpg',
#    u'width': 675},
#   u'num_votes': 603544,
#   u'rating': 8.1,
#   u'tconst': u'tt0198781',
#   u'title': u'Monsters, Inc.',
#   u'type': u'feature',
#   u'year': u'2001'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4NjE1MjM2Ml5BMl5BanBnXkFtZTgwODgzMjM5MzE@._V1_.jpg',
#    u'width': 340},
#   u'num_votes': 298323,
#   u'rating': 8.1,
#   u'tconst': u'tt0032138',
#   u'title': u'The Wizard of Oz',
#   u'type': u'feature',
#   u'year': u'1939'},
#  {u'can_rate': True,
#   u'image': {u'height': 1023,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODE1MDczNTUxOV5BMl5BanBnXkFtZTcwMTA0NDQyNA@@._V1_.jpg',
#    u'width': 682},
#   u'num_votes': 615338,
#   u'rating': 8,
#   u'tconst': u'tt0088247',
#   u'title': u'The Terminator',
#   u'type': u'feature',
#   u'year': u'1984'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTU0MzQyNTExMV5BMl5BanBnXkFtZTgwMjA0Njk1MDE@._V1_.jpg',
#    u'width': 335},
#   u'num_votes': 448871,
#   u'rating': 8.1,
#   u'tconst': u'tt0107048',
#   u'title': u'Groundhog Day',
#   u'type': u'feature',
#   u'year': u'1993'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTg0NTIzMjQ1NV5BMl5BanBnXkFtZTcwNDc3MzM5OQ@@._V1_.jpg',
#    u'width': 1384},
#   u'num_votes': 400838,
#   u'rating': 8.1,
#   u'tconst': u'tt1392214',
#   u'title': u'Prisoners',
#   u'type': u'feature',
#   u'year': u'2013'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BN2Y2OWU4MWMtNmIyMy00YzMyLWI0Y2ItMTcyZDc3MTdmZDU4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 1007},
#   u'num_votes': 472994,
#   u'rating': 8,
#   u'tconst': u'tt0114746',
#   u'title': u'Twelve Monkeys',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 1500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDcxODkyMjY4MF5BMl5BanBnXkFtZTgwOTk5NTc5MDE@._V1_.jpg',
#    u'width': 1000},
#   u'num_votes': 423333,
#   u'rating': 8,
#   u'tconst': u'tt0073195',
#   u'title': u'Jaws',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 719,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY5MzYzNjc5NV5BMl5BanBnXkFtZTYwNTUyNTc2._V1_.jpg',
#    u'width': 485},
#   u'num_votes': 548118,
#   u'rating': 8,
#   u'tconst': u'tt0264464',
#   u'title': u'Catch Me If You Can',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTczNzkyMjQ4N15BMl5BanBnXkFtZTcwOTQ2NjU4Mw@@._V1_.jpg',
#    u'width': 333},
#   u'num_votes': 104520,
#   u'rating': 8.1,
#   u'tconst': u'tt0072684',
#   u'title': u'Barry Lyndon',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTY3OTAyOTMyM15BMl5BanBnXkFtZTcwNTMxMTI0MQ@@._V1_.jpg',
#    u'width': 354},
#   u'num_votes': 106714,
#   u'rating': 8.1,
#   u'tconst': u'tt0113247',
#   u'title': u'La Haine',
#   u'type': u'feature',
#   u'year': u'1995'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc0Mjg2OTY3OV5BMl5BanBnXkFtZTcwNDA3Njk3OA@@._V1_.jpg',
#    u'width': 375},
#   u'num_votes': 93952,
#   u'rating': 8.1,
#   u'tconst': u'tt0338564',
#   u'title': u'Infernal Affairs',
#   u'type': u'feature',
#   u'year': u'2002'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTk1NTAxNzg3Nl5BMl5BanBnXkFtZTcwNjU4OTQwNw@@._V1_.jpg',
#    u'width': 334},
#   u'num_votes': 41304,
#   u'rating': 8.1,
#   u'tconst': u'tt0036868',
#   u'title': u'The Best Years of Our Lives',
#   u'type': u'feature',
#   u'year': u'1946'},
#  {u'can_rate': True,
#   u'image': {u'height': 500,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTcwNzk0MTQxMF5BMl5BanBnXkFtZTcwNjM5NTIwNA@@._V1_.jpg',
#    u'width': 303},
#   u'num_votes': 99049,
#   u'rating': 8.1,
#   u'tconst': u'tt0044079',
#   u'title': u'Strangers on a Train',
#   u'type': u'feature',
#   u'year': u'1951'},
#  {u'can_rate': True,
#   u'image': {u'height': 866,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODZmYjMwNzEtNzVhNC00ZTRmLTk2M2UtNzE1MTQ2ZDAxNjc2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_.jpg',
#    u'width': 580},
#   u'num_votes': 668130,
#   u'rating': 8,
#   u'tconst': u'tt0401792',
#   u'title': u'Sin City',
#   u'type': u'feature',
#   u'year': u'2005'},
#  {u'can_rate': True,
#   u'image': {u'height': 1200,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUyNTA3NTQ4OF5BMl5BanBnXkFtZTgwNDkzMjIwMDI@._V1_.jpg',
#    u'width': 808},
#   u'num_votes': 38646,
#   u'rating': 8.1,
#   u'tconst': u'tt0058946',
#   u'title': u'The Battle of Algiers',
#   u'type': u'feature',
#   u'year': u'1966'},
#  {u'can_rate': True,
#   u'image': {u'height': 2942,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BODExZmE2ZWItYTIzOC00MzI1LTgyNTktMDBhNmFhY2Y4OTQ3XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_.jpg',
#    u'width': 1960},
#   u'num_votes': 186847,
#   u'rating': 8,
#   u'tconst': u'tt0072890',
#   u'title': u'Dog Day Afternoon',
#   u'type': u'feature',
#   u'year': u'1975'},
#  {u'can_rate': True,
#   u'image': {u'height': 469,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTUyMzg2MTQ2NV5BMl5BanBnXkFtZTcwMTQxODEzMQ@@._V1._CR10,26,332,469_.jpg',
#    u'width': 332},
#   u'num_votes': 27580,
#   u'rating': 8.1,
#   u'tconst': u'tt0041546',
#   u'title': u'Kind Hearts and Coronets',
#   u'type': u'feature',
#   u'year': u'1949'},
#  {u'can_rate': True,
#   u'image': {u'height': 475,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3._V1_.jpg',
#    u'width': 321},
#   u'num_votes': 828414,
#   u'rating': 8,
#   u'tconst': u'tt0325980',
#   u'title': u'Pirates of the Caribbean: The Curse of the Black Pearl',
#   u'type': u'feature',
#   u'year': u'2003'},
#  {u'can_rate': True,
#   u'image': {u'height': 2048,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTM5OTMyMjIxOV5BMl5BanBnXkFtZTcwNzU4MjIwNQ@@._V1_.jpg',
#    u'width': 1382},
#   u'num_votes': 327026,
#   u'rating': 8.1,
#   u'tconst': u'tt1454029',
#   u'title': u'The Help',
#   u'type': u'feature',
#   u'year': u'2011'},
#  {u'can_rate': True,
#   u'image': {u'height': 681,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BNDkwNTEyMzkzNl5BMl5BanBnXkFtZTgwNTAwNzk3MjE@._V1_.jpg',
#    u'width': 460},
#   u'num_votes': 495321,
#   u'rating': 8.1,
#   u'tconst': u'tt2084970',
#   u'title': u'The Imitation Game',
#   u'type': u'feature',
#   u'year': u'2014'},
#  {u'can_rate': True,
#   u'image': {u'height': 2686,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMjE0NDUzMDcyOF5BMl5BanBnXkFtZTcwNzAxMTA2Mw@@._V1_.jpg',
#    u'width': 1860},
#   u'num_votes': 174947,
#   u'rating': 8.1,
#   u'tconst': u'tt1220719',
#   u'title': u'Ip Man',
#   u'type': u'feature',
#   u'year': u'2008'},
#  {u'can_rate': True,
#   u'image': {u'height': 2370,
#    u'url': u'https://images-na.ssl-images-amazon.com/images/M/MV5BMTc5NjY4MjUwNF5BMl5BanBnXkFtZTgwODM3NzM5MzE@._V1_.jpg',
#    u'width': 1600},
#   u'num_votes': 48985,
#   u'rating': 8.3,
#   u'tconst': u'tt1954470',
#   u'title': u'Gangs of Wasseypur',
#   u'type': u'feature',
#   u'year': u'2012'}]

# %%
type(imdb.top_250())
# Out:
# list

# %%
df = pd.DataFrame(imdb.top_250())
df
# Out:
#     can_rate                                              image  num_votes  \
# 0       True  {u'url': u'https://images-na.ssl-images-amazon...    1734132
# 1       True  {u'url': u'https://images-na.ssl-images-amazon...    1184876
# 2       True  {u'url': u'https://images-na.ssl-images-amazon...     812632
# 3       True  {u'url': u'https://images-na.ssl-images-amazon...    1718813
# 4       True  {u'url': u'https://images-na.ssl-images-amazon...     463144
# 5       True  {u'url': u'https://images-na.ssl-images-amazon...     888278
# 6       True  {u'url': u'https://images-na.ssl-images-amazon...    1358039
# 7       True  {u'url': u'https://images-na.ssl-images-amazon...    1245440
# 8       True  {u'url': u'https://images-na.ssl-images-amazon...     516031
# 9       True  {u'url': u'https://images-na.ssl-images-amazon...    1384565
# 10      True  {u'url': u'https://images-na.ssl-images-amazon...    1267869
# 11      True  {u'url': u'https://images-na.ssl-images-amazon...     860246
# 12      True  {u'url': u'https://images-na.ssl-images-amazon...    1289751
# 13      True  {u'url': u'https://images-na.ssl-images-amazon...    1509674
# 14      True  {u'url': u'https://images-na.ssl-images-amazon...    1128088
# 15      True  {u'url': u'https://images-na.ssl-images-amazon...     696339
# 16      True  {u'url': u'https://images-na.ssl-images-amazon...     747586
# 17      True  {u'url': u'https://images-na.ssl-images-amazon...    1248725
# 18      True  {u'url': u'https://images-na.ssl-images-amazon...     234855
# 19      True  {u'url': u'https://images-na.ssl-images-amazon...     933054
# 20      True  {u'url': u'https://images-na.ssl-images-amazon...     545946
# 21      True  {u'url': u'https://images-na.ssl-images-amazon...    1052838
# 22      True  {u'url': u'https://images-na.ssl-images-amazon...     913603
# 23      True  {u'url': u'https://images-na.ssl-images-amazon...     282802
# 24      True  {u'url': u'https://images-na.ssl-images-amazon...     760019
# 25      True  {u'url': u'https://images-na.ssl-images-amazon...     434294
# 26      True  {u'url': u'https://images-na.ssl-images-amazon...     746346
# 27      True  {u'url': u'https://images-na.ssl-images-amazon...     433198
# 28      True  {u'url': u'https://images-na.ssl-images-amazon...     906238
# 29      True  {u'url': u'https://images-na.ssl-images-amazon...     221945
# ..       ...                                                ...        ...
# 220     True  {u'url': u'https://images-na.ssl-images-amazon...     226039
# 221     True  {u'url': u'https://images-na.ssl-images-amazon...     175846
# 222     True  {u'url': u'https://images-na.ssl-images-amazon...     505521
# 223     True  {u'url': u'https://images-na.ssl-images-amazon...      43387
# 224     True  {u'url': u'https://images-na.ssl-images-amazon...     386212
# 225     True  {u'url': u'https://images-na.ssl-images-amazon...     594805
# 226     True  {u'url': u'https://images-na.ssl-images-amazon...     559936
# 227     True  {u'url': u'https://images-na.ssl-images-amazon...      80618
# 228     True  {u'url': u'https://images-na.ssl-images-amazon...     603544
# 229     True  {u'url': u'https://images-na.ssl-images-amazon...     298323
# 230     True  {u'url': u'https://images-na.ssl-images-amazon...     615338
# 231     True  {u'url': u'https://images-na.ssl-images-amazon...     448871
# 232     True  {u'url': u'https://images-na.ssl-images-amazon...     400838
# 233     True  {u'url': u'https://images-na.ssl-images-amazon...     472994
# 234     True  {u'url': u'https://images-na.ssl-images-amazon...     423333
# 235     True  {u'url': u'https://images-na.ssl-images-amazon...     548118
# 236     True  {u'url': u'https://images-na.ssl-images-amazon...     104520
# 237     True  {u'url': u'https://images-na.ssl-images-amazon...     106714
# 238     True  {u'url': u'https://images-na.ssl-images-amazon...      93952
# 239     True  {u'url': u'https://images-na.ssl-images-amazon...      41304
# 240     True  {u'url': u'https://images-na.ssl-images-amazon...      99049
# 241     True  {u'url': u'https://images-na.ssl-images-amazon...     668130
# 242     True  {u'url': u'https://images-na.ssl-images-amazon...      38646
# 243     True  {u'url': u'https://images-na.ssl-images-amazon...     186847
# 244     True  {u'url': u'https://images-na.ssl-images-amazon...      27580
# 245     True  {u'url': u'https://images-na.ssl-images-amazon...     828414
# 246     True  {u'url': u'https://images-na.ssl-images-amazon...     327026
# 247     True  {u'url': u'https://images-na.ssl-images-amazon...     495321
# 248     True  {u'url': u'https://images-na.ssl-images-amazon...     174947
# 249     True  {u'url': u'https://images-na.ssl-images-amazon...      48985
#
#      rating     tconst                                              title  \
# 0       9.3  tt0111161                           The Shawshank Redemption
# 1       9.2  tt0068646                                      The Godfather
# 2       9.0  tt0071562                             The Godfather: Part II
# 3       9.0  tt0468569                                    The Dark Knight
# 4       8.9  tt0050083                                       12 Angry Men
# 5       8.9  tt0108052                                   Schindler's List
# 6       8.9  tt0110912                                       Pulp Fiction
# 7       8.9  tt0167260      The Lord of the Rings: The Return of the King
# 8       8.9  tt0060196                     The Good, the Bad and the Ugly
# 9       8.8  tt0137523                                         Fight Club
# 10      8.8  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 11      8.8  tt0080684     Star Wars: Episode V - The Empire Strikes Back
# 12      8.8  tt0109830                                       Forrest Gump
# 13      8.8  tt1375666                                          Inception
# 14      8.7  tt0167261              The Lord of the Rings: The Two Towers
# 15      8.7  tt0073486                    One Flew Over the Cuckoo's Nest
# 16      8.7  tt0099685                                         Goodfellas
# 17      8.7  tt0133093                                         The Matrix
# 18      8.7  tt0047478                                      Seven Samurai
# 19      8.7  tt0076759                 Star Wars: Episode IV - A New Hope
# 20      8.7  tt0317248                                        City of God
# 21      8.6  tt0114369                                              Se7en
# 22      8.6  tt0102926                           The Silence of the Lambs
# 23      8.6  tt0038650                              It's a Wonderful Life
# 24      8.6  tt0114814                                 The Usual Suspects
# 25      8.6  tt0118799                                  Life Is Beautiful
# 26      8.6  tt0110413                             Léon: The Professional
# 27      8.6  tt0245429                                      Spirited Away
# 28      8.6  tt0120815                                Saving Private Ryan
# 29      8.6  tt0064116                       Once Upon a Time in the West
# ..      ...        ...                                                ...
# 220     8.1  tt2948356                                           Zootopia
# 221     8.1  tt0083987                                             Gandhi
# 222     8.1  tt0440963                               The Bourne Ultimatum
# 223     8.1  tt0046911                                         Diabolique
# 224     8.1  tt0075148                                              Rocky
# 225     8.1  tt0246578                                       Donnie Darko
# 226     8.1  tt1201607       Harry Potter and the Deathly Hallows: Part 2
# 227     8.1  tt0056801                                                 8½
# 228     8.1  tt0198781                                     Monsters, Inc.
# 229     8.1  tt0032138                                   The Wizard of Oz
# 230     8.0  tt0088247                                     The Terminator
# 231     8.1  tt0107048                                      Groundhog Day
# 232     8.1  tt1392214                                          Prisoners
# 233     8.0  tt0114746                                     Twelve Monkeys
# 234     8.0  tt0073195                                               Jaws
# 235     8.0  tt0264464                                Catch Me If You Can
# 236     8.1  tt0072684                                       Barry Lyndon
# 237     8.1  tt0113247                                           La Haine
# 238     8.1  tt0338564                                   Infernal Affairs
# 239     8.1  tt0036868                        The Best Years of Our Lives
# 240     8.1  tt0044079                               Strangers on a Train
# 241     8.0  tt0401792                                           Sin City
# 242     8.1  tt0058946                              The Battle of Algiers
# 243     8.0  tt0072890                                  Dog Day Afternoon
# 244     8.1  tt0041546                           Kind Hearts and Coronets
# 245     8.0  tt0325980  Pirates of the Caribbean: The Curse of the Bla...
# 246     8.1  tt1454029                                           The Help
# 247     8.1  tt2084970                                 The Imitation Game
# 248     8.1  tt1220719                                             Ip Man
# 249     8.3  tt1954470                                 Gangs of Wasseypur
#
#         type  year
# 0    feature  1994
# 1    feature  1972
# 2    feature  1974
# 3    feature  2008
# 4    feature  1957
# 5    feature  1993
# 6    feature  1994
# 7    feature  2003
# 8    feature  1966
# 9    feature  1999
# 10   feature  2001
# 11   feature  1980
# 12   feature  1994
# 13   feature  2010
# 14   feature  2002
# 15   feature  1975
# 16   feature  1990
# 17   feature  1999
# 18   feature  1954
# 19   feature  1977
# 20   feature  2002
# 21   feature  1995
# 22   feature  1991
# 23   feature  1946
# 24   feature  1995
# 25   feature  1997
# 26   feature  1994
# 27   feature  2001
# 28   feature  1998
# 29   feature  1968
# ..       ...   ...
# 220  feature  2016
# 221  feature  1982
# 222  feature  2007
# 223  feature  1955
# 224  feature  1976
# 225  feature  2001
# 226  feature  2011
# 227  feature  1963
# 228  feature  2001
# 229  feature  1939
# 230  feature  1984
# 231  feature  1993
# 232  feature  2013
# 233  feature  1995
# 234  feature  1975
# 235  feature  2002
# 236  feature  1975
# 237  feature  1995
# 238  feature  2002
# 239  feature  1946
# 240  feature  1951
# 241  feature  2005
# 242  feature  1966
# 243  feature  1975
# 244  feature  1949
# 245  feature  2003
# 246  feature  2011
# 247  feature  2014
# 248  feature  2008
# 249  feature  2012
#
# [250 rows x 8 columns]

# %%
imdb.get_title_reviews("tt0167260")
# Out:
# [<Review: u'\nPeter Jackson has d'>,
#  <Review: u'\nSaying that this fi'>,
#  <Review: u'I am, I admit, an un'>,
#  <Review: u'\nAs a movie watcher,'>,
#  <Review: u"Obviously, I'm aware">,
#  <Review: u'\nFrodo and Sam conti'>,
#  <Review: u'\nThis is the final m'>,
#  <Review: u'\nFeeling weary and b'>,
#  <Review: u'***SPOILERS*** ***SP'>,
#  <Review: u'\nThousands of commen'>]

# %%
imdb.get_title_reviews("tt0167260")[0]
# Out:
# <Review: u'\nPeter Jackson has d'>

# %%
review=imdb.get_title_reviews("tt0167260")[0]

# %%
review.text
# Out:
# u'\nPeter Jackson has done it.  He has created an all-encompassing epic saga of Tolkien\'s Lord of the Rings books, and after coming away from the final chapter, how does this rate not only as a film on its own, but as a part of the whole?\n\nPerfect.\n\nI\'ve never seen a series like this.  A trilogy of movies created with such love and care and utter perfection of craft that you can\'t help but walk away and wonder how did Peter Jackson make this possible?  I have always loved the original "Star Wars" and "Indiana Jones" series for their epic storytelling, and just for just fitting in as a great moment in cinema. This should be, will be, remembered with as much revered fondness for generations to come.  They do not make films like these anymore.\n\nAs a stand alone film, it picks up immediately where "Two Towers" ends, so brush up before seeing it.  I\'ve read the books, and the anticipation of seeing some of the more profound moments in this film made me kind of view it with a rushed sense of perspective.  I wanted to make sure everything in this film was done "right".  And when it happened, it was.  I will need to see this again to enjoy everything on a more casual level.\n\nThe cast comes through once more.  The musical score retains its beauty, elegance and power.  The special effects, notably Gollum again, are nothing less than breathtaking, and simply move the story along.  The battles are monumentally huge and exciting.  There are some liberties taken with the story, especially during the end with the homecoming, and yet, everything that needed to be covered regarding the main characters was handled. After the greatest moment of the series resolves itself, the story provided a breather.  And gives a good-bye to friends seen on screen for the last three years.  It was truly a bittersweet feeling in realizing that there will be no "Rings" movie in 2004.  I will miss this talented group of actors.\n\nAs with the first two, the film is very long, but goes by without you ever truly realizing it.  This film is so much more than a simple "fantasy" epic. It\'s a story about strength of character, friendship, loyalty and love. And while every member of the Fellowship has their part to play, I finally understood why some critics have said this series is a story about Sam. It\'s his unwavering resolve that led the quest to its victory.  Sean Astin is a true credit for adding the inspirational heart to this epic.  As as far as the ending goes, they ended it the way that it had to be ended. Jackson ended this film the way it should have been.\n\nI will miss looking forward to a new "Rings" movie, but these movies provide hope that high-quality films can still be made without special effects taking over a story, bathroom humor, or a "Top 40" soundtrack.  George Lucas could learn a lot from these films about how not to alienate the fanbase.\n\nEach film has earned a "10" from me for the last two years, which for me to give is a rarity.  This one, however, is as equally deserving as its two predecessors.  The Academy had better not look over this film for "Best Picture" of 2003.  To do so would be greatly disrespectful of the craft and care that anyone involved with these films put into them.'

# %%
from bs4 import BeautifulSoup
import requests

# %%
req = requests.get("http://www.imdb.com/chart/top")

# %%
soup = BeautifulSoup(req.content,"lxml")
soup.prettify()
# Out:
# u'<!DOCTYPE html>\n<html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>\n  <script type="text/javascript">\n   var ue_t0=window.ue_t0||+new Date();\n  </script>\n  <script type="text/javascript">\n   var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "1M70EKBD5H3JM6HAWSXM";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-11e51f253e8ad9d145f4ed644b40f692._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);\n                if (!(\'CS\' in window)) { window.CS = {}; }\n                    window.CS.loginLocation = "https://www.imdb.com/registration/signin?u=%2Fchart%2Ftop";\n  </script>\n  <script type="text/javascript">\n   var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};\n  </script>\n  <script>\n   (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);\n  </script>\n  <title>\n   IMDb Top 250 - IMDb\n  </title>\n  <script>\n   (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);\n  </script>\n  <link href="http://www.imdb.com/chart/top" rel="canonical"/>\n  <meta content="http://www.imdb.com/chart/top" property="og:url"/>\n  <script>\n   (function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);\n  </script>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB527136930_.svg" mask="" rel="icon" sizes="any"/>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB527169355_.ico" rel="icon" type="image/ico"/>\n  <meta content="#000000" name="theme-color"/>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB527096465_.ico" rel="shortcut icon" type="image/x-icon"/>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB526935900_.png" rel="apple-touch-icon"/>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB527107445_.png" rel="apple-touch-icon" sizes="76x76"/>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB527124988_.png" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB526935551_.png" rel="apple-touch-icon" sizes="152x152"/ ...

# %%
minisoup=soup.find("tbody",{"class":"lister-list"})
rowlist=minisoup.find_all("tr")
for rows in rowlist:
    print rows
# Out:
# <tr>
# <td class="posterColumn">
# <span data-value="1" name="rk"></span>
# <span data-value="9.21478547000337" name="ir"></span>
# <span data-value="7.791552E11" name="us"></span>
# <span data-value="1734151" name="nv"></span>
# <span data-value="-1.7852145299966296" name="ur"></span>
# <a href="/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_1"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       1.
#       <a href="/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_1" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.2 based on 1,734,151 user ratings">9.2</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="2" name="rk"></span>
# <span data-value="9.16171359873207" name="ir"></span>
# <span data-value="6.93792E10" name="us"></span>
# <span data-value="1184887" name="nv"></span>
# <span data-value="-1.8382864012679292" name="ur"></span>
# <a href="/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_2"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNTUxOTdjMDMtMWY1MC00MjkxLTgxYTMtYTM1MjU5ZTJlNTZjXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       2.
#       <a href="/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_2" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
# <span class="secondaryInfo">(1972)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.2 based on 1,184,887 user ratings">9.2</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0068646 pending" data-titleid="tt0068646">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0068646"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="3" name="rk"></span>
# <span data-value="8.999690055899075" name="ir"></span>
# <span data-value="1.560384E11" name="us"></span>
# <span data-value="812641" name="nv"></span>
# <span data-value="-2.000309944100925" name="ur"></span>
# <a href="/title/tt0071562/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_3"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjZiNzIxNTQtNDc5Zi00YWY1LThkMTctMDgzYjY4YjI1YmQyL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       3.
#       <a href="/title/tt0071562/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_3" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather: Part II</a>
# <span class="secondaryInfo">(1974)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.0 based on 812,641 user ratings">9.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0071562 pending" data-titleid="tt0071562">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0071562"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="4" name="rk"></span>
# <span data-value="8.94599080795847" name="ir"></span>
# <span data-value="1.2159936E12" name="us"></span>
# <span data-value="1718828" name="nv"></span>
# <span data-value="-2.05400919204153" name="ur"></span>
# <a href="/title/tt0468569/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_4"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       4.
#       <a href="/title/tt0468569/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_4" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
# <span class="secondaryInfo">(2008)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 1,718,828 user ratings">8.9</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0468569 pending" data-titleid="tt0468569">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0468569"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="5" name="rk"></span>
# <span data-value="8.894667286658557" name="ir"></span>
# <span data-value="-4.016736E11" name="us"></span>
# <span data-value="463154" name="nv"></span>
# <span data-value="-2.1053327133414435" name="ur"></span>
# <a href="/title/tt0050083/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_5"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BODQwOTc5MDM2N15BMl5BanBnXkFtZTcwODQxNTEzNA@@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       5.
#       <a href="/title/tt0050083/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_5" title="Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb">12 Angry Men</a>
# <span class="secondaryInfo">(1957)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 463,154 user ratings">8.9</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0050083 pending" data-titleid="tt0050083">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0050083"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="6" name="rk"></span>
# <span data-value="8.894320310538513" name="ir"></span>
# <span data-value="7.546176E11" name="us"></span>
# <span data-value="888288" name="nv"></span>
# <span data-value="-2.1056796894614873" name="ur"></span>
# <a href="/title/tt0108052/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_6"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMzMwMTM4MDU2N15BMl5BanBnXkFtZTgwMzQ0MjMxMDE@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       6.
#       <a href="/title/tt0108052/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_6" title="Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes">Schindler's List</a>
# <span class="secondaryInfo">(1993)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 888,288 user ratings">8.9</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0108052 pending" data-titleid="tt0108052">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0108052"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="7" name="rk"></span>
# <span data-value="8.880688702826902" name="ir"></span>
# <span data-value="7.694784E11" name="us"></span>
# <span data-value="1358053" name="nv"></span>
# <span data-value="-2.1193112971730983" name="ur"></span>
# <a href="/title/tt0110912/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_7"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTkxMTA5OTAzMl5BMl5BanBnXkFtZTgwNjA5MDc3NjE@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       7.
#       <a href="/title/tt0110912/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_7" title="Quentin Tarantino (dir.), John Travolta, Uma Thurman">Pulp Fiction</a>
# <span class="secondaryInfo">(1994)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 1,358,053 user ratings">8.9</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0110912 pending" data-titleid="tt0110912">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0110912"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="8" name="rk"></span>
# <span data-value="8.866278176454554" name="ir"></span>
# <span data-value="1.0702368E12" name="us"></span>
# <span data-value="1245457" name="nv"></span>
# <span data-value="-2.1337218235454465" name="ur"></span>
# <a href="/title/tt0167260/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_8"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjE4MjA1NTAyMV5BMl5BanBnXkFtZTcwNzM1NDQyMQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       8.
#       <a href="/title/tt0167260/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_8" title="Peter Jackson (dir.), Elijah Wood, Viggo Mortensen">The Lord of the Rings: The Return of the King</a>
# <span class="secondaryInfo">(2003)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 1,245,457 user ratings">8.9</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0167260 pending" data-titleid="tt0167260">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0167260"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="9" name="rk"></span>
# <span data-value="8.850149488245037" name="ir"></span>
# <span data-value="-9.5472E10" name="us"></span>
# <span data-value="516039" name="nv"></span>
# <span data-value="-2.1498505117549627" name="ur"></span>
# <a href="/title/tt0060196/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_9"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BOTQ5NDI3MTI4MF5BMl5BanBnXkFtZTgwNDQ4ODE5MDE@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       9.
#       <a href="/title/tt0060196/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_9" title="Sergio Leone (dir.), Clint Eastwood, Eli Wallach">The Good, the Bad and the Ugly</a>
# <span class="secondaryInfo">(1966)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 516,039 user ratings">8.9</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0060196 pending" data-titleid="tt0060196">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0060196"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="10" name="rk"></span>
# <span data-value="8.80122237763827" name="ir"></span>
# <span data-value="9.369216E11" name="us"></span>
# <span data-value="1384584" name="nv"></span>
# <span data-value="-2.19877762236173" name="ur"></span>
# <a href="/title/tt0137523/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_10"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNGM2NjQxZTAtMmU5My00YTk5LWFmOWMtYjZlYzk4YzMwNjFlXkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       10.
#       <a href="/title/tt0137523/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_10" title="David Fincher (dir.), Brad Pitt, Edward Norton">Fight Club</a>
# <span class="secondaryInfo">(1999)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.8 based on 1,384,584 user ratings">8.8</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0137523 pending" data-titleid="tt0137523">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0137523"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="11" name="rk"></span>
# <span data-value="8.769643685897213" name="ir"></span>
# <span data-value="1.0079424E12" name="us"></span>
# <span data-value="1267886" name="nv"></span>
# <span data-value="-2.230356314102787" name="ur"></span>
# <a href="/title/tt0120737/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_11"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNTEyMjAwMDU1OV5BMl5BanBnXkFtZTcwNDQyNTkxMw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       11.
#       <a href="/title/tt0120737/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_11" title="Peter Jackson (dir.), Elijah Wood, Ian McKellen">The Lord of the Rings: The Fellowship of the Ring</a>
# <span class="secondaryInfo">(2001)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.8 based on 1,267,886 user ratings">8.8</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0120737 pending" data-titleid="tt0120737">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0120737"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="12" name="rk"></span>
# <span data-value="8.735396764485342" name="ir"></span>
# <span data-value="3.273696E11" name="us"></span>
# <span data-value="860262" name="nv"></span>
# <span data-value="-2.2646032355146577" name="ur"></span>
# <a href="/title/tt0080684/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_12"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYmViY2M2MTYtY2MzOS00YjQ1LWIzYmEtOTBiNjhlMGM0NjZjXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       12.
#       <a href="/title/tt0080684/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_12" title="Irvin Kershner (dir.), Mark Hamill, Harrison Ford">Star Wars: Episode V - The Empire Strikes Back</a>
# <span class="secondaryInfo">(1980)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 860,262 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0080684 pending" data-titleid="tt0080684">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0080684"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="13" name="rk"></span>
# <span data-value="8.731141091411383" name="ir"></span>
# <span data-value="7.723296E11" name="us"></span>
# <span data-value="1289770" name="nv"></span>
# <span data-value="-2.2688589085886175" name="ur"></span>
# <a href="/title/tt0109830/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_13"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYThjM2MwZGMtMzg3Ny00NGRkLWE4M2EtYTBiNWMzOTY0YTI4XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY67_CR3,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       13.
#       <a href="/title/tt0109830/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_13" title="Robert Zemeckis (dir.), Tom Hanks, Robin Wright">Forrest Gump</a>
# <span class="secondaryInfo">(1994)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 1,289,770 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0109830 pending" data-titleid="tt0109830">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0109830"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="14" name="rk"></span>
# <span data-value="8.725468405675942" name="ir"></span>
# <span data-value="1.2785472E12" name="us"></span>
# <span data-value="1509689" name="nv"></span>
# <span data-value="-2.274531594324058" name="ur"></span>
# <a href="/title/tt1375666/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_14"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       14.
#       <a href="/title/tt1375666/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_14" title="Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt">Inception</a>
# <span class="secondaryInfo">(2010)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 1,509,689 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1375666 pending" data-titleid="tt1375666">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1375666"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="15" name="rk"></span>
# <span data-value="8.686809564070298" name="ir"></span>
# <span data-value="1.0390464E12" name="us"></span>
# <span data-value="1128104" name="nv"></span>
# <span data-value="-2.3131904359297017" name="ur"></span>
# <a href="/title/tt0167261/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_15"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTAyNDU0NjY4NTheQTJeQWpwZ15BbWU2MDk4MTY2Nw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       15.
#       <a href="/title/tt0167261/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_15" title="Peter Jackson (dir.), Elijah Wood, Ian McKellen">The Lord of the Rings: The Two Towers</a>
# <span class="secondaryInfo">(2002)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 1,128,104 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0167261 pending" data-titleid="tt0167261">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0167261"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="16" name="rk"></span>
# <span data-value="8.682000547778742" name="ir"></span>
# <span data-value="1.855872E11" name="us"></span>
# <span data-value="696345" name="nv"></span>
# <span data-value="-2.317999452221258" name="ur"></span>
# <a href="/title/tt0073486/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_16"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYmJkODkwOTItZThjZC00MTE0LWIxNzQtYTM3MmQwMGI1OWFiXkEyXkFqcGdeQXVyNjUwNzk3NDc@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       16.
#       <a href="/title/tt0073486/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_16" title="Milos Forman (dir.), Jack Nicholson, Louise Fletcher">One Flew Over the Cuckoo's Nest</a>
# <span class="secondaryInfo">(1975)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 696,345 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0073486 pending" data-titleid="tt0073486">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0073486"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="17" name="rk"></span>
# <span data-value="8.672527837189605" name="ir"></span>
# <span data-value="6.528384E11" name="us"></span>
# <span data-value="747597" name="nv"></span>
# <span data-value="-2.3274721628103947" name="ur"></span>
# <a href="/title/tt0099685/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_17"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNThjMzczMjctZmIwOC00NTQ4LWJhZWItZDdhNTk5ZTdiMWFlXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       17.
#       <a href="/title/tt0099685/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_17" title="Martin Scorsese (dir.), Robert De Niro, Ray Liotta">Goodfellas</a>
# <span class="secondaryInfo">(1990)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 747,597 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0099685 pending" data-titleid="tt0099685">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0099685"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="18" name="rk"></span>
# <span data-value="8.657592555265214" name="ir"></span>
# <span data-value="9.222336E11" name="us"></span>
# <span data-value="1248738" name="nv"></span>
# <span data-value="-2.3424074447347856" name="ur"></span>
# <a href="/title/tt0133093/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_18"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMDMyMmQ5YzgtYWMxOC00OTU0LWIwZjEtZWUwYTY5MjVkZjhhXkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       18.
#       <a href="/title/tt0133093/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_18" title="Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne">The Matrix</a>
# <span class="secondaryInfo">(1999)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.7 based on 1,248,738 user ratings">8.7</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0133093 pending" data-titleid="tt0133093">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0133093"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="19" name="rk"></span>
# <span data-value="8.645796984269943" name="ir"></span>
# <span data-value="-4.949856E11" name="us"></span>
# <span data-value="234862" name="nv"></span>
# <span data-value="-2.3542030157300573" name="ur"></span>
# <a href="/title/tt0047478/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_19"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTc5MDY1MjU5MF5BMl5BanBnXkFtZTgwNDM2OTE4MzE@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       19.
#       <a href="/title/tt0047478/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_19" title="Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura">Seven Samurai</a>
# <span class="secondaryInfo">(1954)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 234,862 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0047478 pending" data-titleid="tt0047478">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0047478"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="20" name="rk"></span>
# <span data-value="8.625980063529099" name="ir"></span>
# <span data-value="2.333664E11" name="us"></span>
# <span data-value="933067" name="nv"></span>
# <span data-value="-2.3740199364709014" name="ur"></span>
# <a href="/title/tt0076759/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_20"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BZGEzZTExMDEtNjg4OC00NjQxLTk5NTUtNjRkNjA3MmYwZjg1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       20.
#       <a href="/title/tt0076759/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_20" title="George Lucas (dir.), Mark Hamill, Harrison Ford">Star Wars: Episode IV - A New Hope</a>
# <span class="secondaryInfo">(1977)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 933,067 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0076759 pending" data-titleid="tt0076759">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0076759"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="21" name="rk"></span>
# <span data-value="8.620515762325109" name="ir"></span>
# <span data-value="1.02168E12" name="us"></span>
# <span data-value="545952" name="nv"></span>
# <span data-value="-2.379484237674891" name="ur"></span>
# <a href="/title/tt0317248/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_21"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjA4ODQ3ODkzNV5BMl5BanBnXkFtZTYwOTc4NDI3._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       21.
#       <a href="/title/tt0317248/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_21" title="Fernando Meirelles (dir.), Alexandre Rodrigues, Matheus Nachtergaele">City of God</a>
# <span class="secondaryInfo">(2002)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 545,952 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0317248 pending" data-titleid="tt0317248">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0317248"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="22" name="rk"></span>
# <span data-value="8.610110894788049" name="ir"></span>
# <span data-value="8.111232E11" name="us"></span>
# <span data-value="1052846" name="nv"></span>
# <span data-value="-2.3898891052119513" name="ur"></span>
# <a href="/title/tt0114369/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_22"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTQwNTU3MTE4NF5BMl5BanBnXkFtZTcwOTgxNDM2Mg@@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       22.
#       <a href="/title/tt0114369/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_22" title="David Fincher (dir.), Morgan Freeman, Brad Pitt">Se7en</a>
# <span class="secondaryInfo">(1995)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 1,052,846 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0114369 pending" data-titleid="tt0114369">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0114369"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="23" name="rk"></span>
# <span data-value="8.590499287167898" name="ir"></span>
# <span data-value="6.651936E11" name="us"></span>
# <span data-value="913610" name="nv"></span>
# <span data-value="-2.409500712832102" name="ur"></span>
# <a href="/title/tt0102926/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_23"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTQ2NzkzMDI4OF5BMl5BanBnXkFtZTcwMDA0NzE1NA@@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       23.
#       <a href="/title/tt0102926/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_23" title="Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins">The Silence of the Lambs</a>
# <span class="secondaryInfo">(1991)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 913,610 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0102926 pending" data-titleid="tt0102926">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0102926"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="24" name="rk"></span>
# <span data-value="8.578523980155328" name="ir"></span>
# <span data-value="-7.267968E11" name="us"></span>
# <span data-value="282808" name="nv"></span>
# <span data-value="-2.421476019844672" name="ur"></span>
# <a href="/title/tt0038650/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_24"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTMzMzY5NDc4M15BMl5BanBnXkFtZTcwMzc4NjIxNw@@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       24.
#       <a href="/title/tt0038650/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_24" title="Frank Capra (dir.), James Stewart, Donna Reed">It's a Wonderful Life</a>
# <span class="secondaryInfo">(1946)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 282,808 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0038650 pending" data-titleid="tt0038650">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0038650"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="25" name="rk"></span>
# <span data-value="8.575198075043065" name="ir"></span>
# <span data-value="7.90992E11" name="us"></span>
# <span data-value="760029" name="nv"></span>
# <span data-value="-2.4248019249569346" name="ur"></span>
# <a href="/title/tt0114814/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_25"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMzI1MjI5MDQyOV5BMl5BanBnXkFtZTcwNzE4Mjg3NA@@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       25.
#       <a href="/title/tt0114814/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_25" title="Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne">The Usual Suspects</a>
# <span class="secondaryInfo">(1995)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 760,029 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0114814 pending" data-titleid="tt0114814">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0114814"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="26" name="rk"></span>
# <span data-value="8.568869650804496" name="ir"></span>
# <span data-value="8.82576E11" name="us"></span>
# <span data-value="434311" name="nv"></span>
# <span data-value="-2.431130349195504" name="ur"></span>
# <a href="/title/tt0118799/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_26"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BYmJmM2Q4NmMtYThmNC00ZjRlLWEyZmItZTIwOTBlZDQ3NTQ1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       26.
#       <a href="/title/tt0118799/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_26" title="Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi">Life Is Beautiful</a>
# <span class="secondaryInfo">(1997)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 434,311 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0118799 pending" data-titleid="tt0118799">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0118799"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="27" name="rk"></span>
# <span data-value="8.548276659286843" name="ir"></span>
# <span data-value="7.795008E11" name="us"></span>
# <span data-value="746357" name="nv"></span>
# <span data-value="-2.4517233407131567" name="ur"></span>
# <a href="/title/tt0110413/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_27"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjdjMGU3MGYtN2Y5ZC00MTE4LWE4YWQtMTBhMjc3MTk0ZDUwXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       27.
#       <a href="/title/tt0110413/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_27" title="Luc Besson (dir.), Jean Reno, Gary Oldman">Léon: The Professional</a>
# <span class="secondaryInfo">(1994)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 746,357 user ratings">8.5</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0110413 pending" data-titleid="tt0110413">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0110413"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="28" name="rk"></span>
# <span data-value="8.535498527827967" name="ir"></span>
# <span data-value="9.955872E11" name="us"></span>
# <span data-value="433210" name="nv"></span>
# <span data-value="-2.4645014721720333" name="ur"></span>
# <a href="/title/tt0245429/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_28"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjYxMDcyMzIzNl5BMl5BanBnXkFtZTYwNDg2MDU3._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       28.
#       <a href="/title/tt0245429/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_28" title="Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette">Spirited Away</a>
# <span class="secondaryInfo">(2001)</span>
# </td>
# <td class="ratingColumn imdbRating">
# ...
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0044079"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="242" name="rk"></span>
# <span data-value="8.016316533394114" name="ir"></span>
# <span data-value="1.111968E12" name="us"></span>
# <span data-value="668139" name="nv"></span>
# <span data-value="-2.9836834666058856" name="ur"></span>
# <a href="/title/tt0401792/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_242"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BODZmYjMwNzEtNzVhNC00ZTRmLTk2M2UtNzE1MTQ2ZDAxNjc2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       242.
#       <a href="/title/tt0401792/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_242" title="Frank Miller (dir.), Mickey Rourke, Clive Owen">Sin City</a>
# <span class="secondaryInfo">(2005)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 668,139 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0401792 pending" data-titleid="tt0401792">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0401792"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="243" name="rk"></span>
# <span data-value="8.015477537149007" name="ir"></span>
# <span data-value="-1.053216E11" name="us"></span>
# <span data-value="38646" name="nv"></span>
# <span data-value="-2.984522462850993" name="ur"></span>
# <a href="/title/tt0058946/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_243"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTUyNTA3NTQ4OF5BMl5BanBnXkFtZTgwNDkzMjIwMDI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       243.
#       <a href="/title/tt0058946/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_243" title="Gillo Pontecorvo (dir.), Brahim Hadjadj, Jean Martin">The Battle of Algiers</a>
# <span class="secondaryInfo">(1966)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 38,646 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0058946 pending" data-titleid="tt0058946">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0058946"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="244" name="rk"></span>
# <span data-value="8.014607004535081" name="ir"></span>
# <span data-value="1.804032E11" name="us"></span>
# <span data-value="186850" name="nv"></span>
# <span data-value="-2.9853929954649185" name="ur"></span>
# <a href="/title/tt0072890/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_244"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BODExZmE2ZWItYTIzOC00MzI1LTgyNTktMDBhNmFhY2Y4OTQ3XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       244.
#       <a href="/title/tt0072890/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_244" title="Sidney Lumet (dir.), Al Pacino, John Cazale">Dog Day Afternoon</a>
# <span class="secondaryInfo">(1975)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 186,850 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0072890 pending" data-titleid="tt0072890">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0072890"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="245" name="rk"></span>
# <span data-value="8.011895413350347" name="ir"></span>
# <span data-value="-6.479136E11" name="us"></span>
# <span data-value="27581" name="nv"></span>
# <span data-value="-2.988104586649653" name="ur"></span>
# <a href="/title/tt0041546/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_245"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTUyMzg2MTQ2NV5BMl5BanBnXkFtZTcwMTQxODEzMQ@@._V1._CR10,26,332,469_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       245.
#       <a href="/title/tt0041546/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_245" title="Robert Hamer (dir.), Dennis Price, Alec Guinness">Kind Hearts and Coronets</a>
# <span class="secondaryInfo">(1949)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 27,581 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0041546 pending" data-titleid="tt0041546">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0041546"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="246" name="rk"></span>
# <span data-value="8.009954158843685" name="ir"></span>
# <span data-value="1.0567584E12" name="us"></span>
# <span data-value="828427" name="nv"></span>
# <span data-value="-2.9900458411563147" name="ur"></span>
# <a href="/title/tt0325980/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_246"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjAyNDM4MTc2N15BMl5BanBnXkFtZTYwNDk0Mjc3._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       246.
#       <a href="/title/tt0325980/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_246" title="Gore Verbinski (dir.), Johnny Depp, Geoffrey Rush">Pirates of the Caribbean: The Curse of the Black Pearl</a>
# <span class="secondaryInfo">(2003)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 828,427 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0325980 pending" data-titleid="tt0325980">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0325980"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="247" name="rk"></span>
# <span data-value="8.009760778685873" name="ir"></span>
# <span data-value="1.312848E12" name="us"></span>
# <span data-value="327029" name="nv"></span>
# <span data-value="-2.990239221314127" name="ur"></span>
# <a href="/title/tt1454029/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_247"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTM5OTMyMjIxOV5BMl5BanBnXkFtZTcwNzU4MjIwNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       247.
#       <a href="/title/tt1454029/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_247" title="Tate Taylor (dir.), Emma Stone, Viola Davis">The Help</a>
# <span class="secondaryInfo">(2011)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 327,029 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1454029 pending" data-titleid="tt1454029">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1454029"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="248" name="rk"></span>
# <span data-value="8.009494837218156" name="ir"></span>
# <span data-value="1.4092704E12" name="us"></span>
# <span data-value="495333" name="nv"></span>
# <span data-value="-2.9905051627818438" name="ur"></span>
# <a href="/title/tt2084970/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_248"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BNDkwNTEyMzkzNl5BMl5BanBnXkFtZTgwNTAwNzk3MjE@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       248.
#       <a href="/title/tt2084970/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_248" title="Morten Tyldum (dir.), Benedict Cumberbatch, Keira Knightley">The Imitation Game</a>
# <span class="secondaryInfo">(2014)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 495,333 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt2084970 pending" data-titleid="tt2084970">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt2084970"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="249" name="rk"></span>
# <span data-value="8.008401621905355" name="ir"></span>
# <span data-value="1.22904E12" name="us"></span>
# <span data-value="174950" name="nv"></span>
# <span data-value="-2.991598378094645" name="ur"></span>
# <a href="/title/tt1220719/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_249"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMjE0NDUzMDcyOF5BMl5BanBnXkFtZTcwNzAxMTA2Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       249.
#       <a href="/title/tt1220719/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_249" title="Wilson Yip (dir.), Donnie Yen, Simon Yam">Yip Man</a>
# <span class="secondaryInfo">(2008)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 174,950 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1220719 pending" data-titleid="tt1220719">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1220719"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="250" name="rk"></span>
# <span data-value="8.008130235969883" name="ir"></span>
# <span data-value="1.3376448E12" name="us"></span>
# <span data-value="48988" name="nv"></span>
# <span data-value="-2.991869764030117" name="ur"></span>
# <a href="/title/tt1954470/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_250"> <img height="67" src="https://images-na.ssl-images-amazon.com/images/M/MV5BMTc5NjY4MjUwNF5BMl5BanBnXkFtZTgwODM3NzM5MzE@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       250.
#       <a href="/title/tt1954470/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2398042102&amp;pf_rd_r=1M70EKBD5H3JM6HAWSXM&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_250" title="Anurag Kashyap (dir.), Manoj Bajpayee, Richa Chadha">Gangs of Wasseypur</a>
# <span class="secondaryInfo">(2012)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 48,988 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1954470 pending" data-titleid="tt1954470">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1</li><li>2</li><li>3</li><li>4</li><li>5</li><li>6</li><li>7</li><li>8</li><li>9</li><li>10</li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1954470"></div>
# </td>
# </tr>

# %% [markdown]
# ## 5.b Get top movies data
#
# Although the Internet Movie Database does not have a public API, an open API exists at http://www.omdbapi.com.
#
# Use this API to retrieve information about each of the 250 movies you have extracted in the previous step.
# - Check the documentation of omdbapi.com to learn how to request movie data by id
# - Define a function that returns a python object with all the information for a given id
# - Iterate on all the IDs and store the results in a list of such objects
# - Create a Pandas Dataframe from the list

# %% [markdown]
# ## 5.c Get gross data
#
# The OMDB API is great, but it does not provide information about Gross Revenue of the movie. We'll revert back to scraping for this.
#
# - Write a function that retrieves the gross revenue from the entry page at imdb.com
# - The function should handle the exception of when the page doesn't report gross revenue
# - Retrieve the gross revenue for each movie and store it in a separate dataframe

# %% [markdown]
# ## 5.d Data munging
#
# - Now that you have movie information and gross revenue information, let's clean the two datasets.
# - Check if there are null values. Be careful they may appear to be valid strings.
# - Convert the columns to the appropriate formats. In particular handle:
#     - Released
#     - Runtime
#     - year
#     - imdbRating
#     - imdbVotes
# - Merge the data from the two datasets into a single one

# %% [markdown]
# ## 5.d Text vectorization
#
# There are several columns in the data that contain a comma separated list of items, for example the Genre column and the Actors column. Let's transform those to binary columns using the count vectorizer from scikit learn.
#
# Append these columns to the merged dataframe.
#
# **Hint:** In order to get the actors name right, you'll have to modify the `token_pattern` in the `CountVectorizer`.

# %% [markdown]
# ## Bonus:
#
# - What are the top 10 grossing movies?
# - Who are the 10 actors that appear in the most movies?
# - What's the average grossing of the movies in which each of these actors appear?
# - What genre is the oldest movie?
